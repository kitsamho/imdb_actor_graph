# %%
from tmdb_modules import (TMDBCastCrewScraper,
                         TMDBMovieScraper, 
                         get_movie_payload, 
                         MultiThreading)
import tmdbsimple as tmdb
import concurrent.futures

# %% [markdown]
# # API Key

# %%
# put your API key here
# tmdb.API_KEY =

# %% [markdown]
# # Get Movies

# %%
# instantiate class with the years you want to query
movies = TMDBMovieScraper(years_check=[1990,2023])

# %%
# get the movie data
df_movies = movies.get_movies()
# Out:
# Getting data for [1990, 2023]
# Getting movie data for 289 movies..
# Done

# %%
df_movies.head().T
# Out:
# id                                                               968051  \
# movie                                                        The Nun II
# overview              In 1956 France, a priest is violently murdered...
# popularity                                                     3660.338
# release_date                                                 2023-09-06
# vote_average                                                        7.0
# poster_path                            /5gzzkR7y3hnY8AD1wXjCnVlHba5.jpg
# release_year                                                       2023
# keywords              [france, bullying, sequel, religion, demon, go...
# results                                                              []
# budget                                                       38500000.0
# genres                                      [Horror, Mystery, Thriller]
# production_countries                         [United States of America]
# revenue                                                     231200000.0
# tagline                                              Confess your sins.
#
# id                                                               678512  \
# movie                                                  Sound of Freedom
# overview              The story of Tim Ballard, a former US governme...
# popularity                                                     3627.783
# release_date                                                 2023-07-03
# vote_average                                                        8.0
# poster_path                            /qA5kPYZA7FkVvqcEfJRoOy4kpHg.jpg
# release_year                                                       2023
# keywords              [kidnapping, human trafficking, child kidnappi...
# results               [As someone who was a victim of child sexual a...
# budget                                                       15000000.0
# genres                                                  [Action, Drama]
# production_countries                         [United States of America]
# revenue                                                     230953510.0
# tagline                      Fight for the light. Silence the darkness.
#
# id                                                               980489  \
# movie                                                      Gran Turismo
# overview              The ultimate wish-fulfillment tale of a teenag...
# popularity                                                     2625.075
# release_date                                                 2023-08-09
# vote_average                                                        8.0
# poster_path                            /51tqzRtKMMZEYUpSYkrUE7v9ehm.jpg
# release_year                                                       2023
# keywords              [based on true story, racing, based on video g...
# results               [Movie is really good, but there is one obviou...
# budget                                                       60000000.0
# genres                                       [Adventure, Action, Drama]
# production_countries                         [United States of America]
# revenue                                                     114800000.0
# tagline                                            From gamer to racer.
#
# id                                                               565770  \
# movie                                                       Blue Beetle
# overview              Recent college grad Jaime Reyes returns home f...
# popularity                                                     1652.788
# release_date                                                 2023-08-16
# vote_average                                                        7.1
# poster_path                            /mXLOHHc1Zeuwsl4xYKjKh2280oL.jpg
# release_year                                                       2023
# keywords              [armor, superhero, family relationships, famil...
# results               [MORE SPOILER-FREE MINI-REVIEWS @ https://www....
# budget                                                      120000000.0
# genres                             [Action, Science Fiction, Adventure]
# production_countries                         [United States of America]
# revenue                                                     126800000.0
# tagline               Jaime Reyes is a superhero whether he likes it...
#
# id                                                               615656
# movie                                                 Meg 2: The Trench
# overview              An exploratory dive into the deepest depths of...
# popularity                                                     1142.891
# release_date                                                 2023-08-02
# vote_average                                                        6.9
# poster_path                            /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg
# release_year                                                       2023
# keywords              [based on novel or book, sequel, kaiju, civil ...
# results               [Now the "Meg" (2018) itself could never be ca...
# budget                                                      129000000.0
# genres                                [Action, Science Fiction, Horror]
# production_countries                  [China, United States of America]
# revenue                                                     384056482.0
# tagline                                               Back for seconds.

# %% [markdown]
# # Get Cast

# %%
cast = TMDBCastCrewScraper(df_movies.index)

# %%
# get the movie data
df_cast = cast.get_cast_crew()

# %%
df_cast.head()
# Out:
#       adult  gender       id  ...                 credit_id order  tmdb_id
# 0     False       2  1179651  ...  63ac60f91f748b008236aca2     0  1041513
# 1     False       1   968367  ...  635c12a09ba86a007d777b73     1  1041513
# 2     False       1  1489764  ...  635c12ba0f526500799ed5c4     3  1041513
# 3     False       1  2489411  ...  635c12c2a39d0b007a8eee92     4  1041513
# 4     False       1  1010157  ...  635c12c9a39d0b0082620f7c     5  1041513
# ...     ...     ...      ...  ...                       ...   ...      ...
# 6769  False       1  2354142  ...  62f0ce3a1f748b00811603ed     6   818612
# 6770  False       2   153789  ...  62f0ce7385b105007df0d276     8   818612
# 6771  False       1  1723913  ...  62f0ce8fa1074b00920f8336     9   818612
# 6772  False       2    57563  ...  62405e350f365500965f0750     0   950445
# 6773  False       2  3546204  ...  627cd17b20e6a513bbe6d6b3     4   950445
#
# [6774 rows x 13 columns]
