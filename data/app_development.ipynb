# %%
import pandas as pd
from d3blocks import D3Blocks

# %% [markdown]
# # Load - Data

# %%
def read_data(path):
    return pd.read_pickle(path)

# %%
df_cast = read_data('/Users/saho/Documents/sam/imdb_actor_graph/streamlit_app/cached_data/cast.pickle')

# %%
df_movies = read_data('/Users/saho/Documents/sam/imdb_actor_graph/streamlit_app/cached_data/movies.pickle')

# %% [markdown]
# # Transform - Select Data

# %%
def _mask_range(df,col,start,end):
    return df[(df[col] >= start) & (df[col] <= end)]

# %%
def _mask_value(df,col,value):
    return df[(df[col] == value)]

# %%
# df_movies = read_data('/Users/saho/Documents/sam/imdb_actor_graph/cached_data/movies.pickle')
year_start, year_end = 1990,2023

# %%
df_movies = _mask_range(df_movies,'m_release_year',year_start,year_end)

# %%
df_movies
# Out:
#       m_tmdb_id                                       m_movie  \
# 0         12445  Harry Potter and the Deathly Hallows: Part 2
# 1         49013                                        Cars 2
# 2         50014                                      The Help
# 3          1865   Pirates of the Caribbean: On Stranger Tides
# 4         39254                                    Real Steel
# ...         ...                                           ...
# 9808     818612                                Wedding Season
# 9809     973164                    Ricky Gervais: SuperNature
# 9810     957258                              What is a Woman?
# 9811     971961                   Gabriel's Rapture: Part III
# 9812    1019836                    Christmas Bloody Christmas
#
#                                              m_overview  m_popularity  \
# 0     Harry, Ron and Hermione continue their quest t...       182.818
# 1     Star race car Lightning McQueen and his pal Ma...       169.573
# 2     Aibileen Clark is a middle-aged African-Americ...       168.317
# 3     Captain Jack Sparrow crosses paths with a woma...       160.529
# 4     Charlie Kenton is a washed-up fighter who reti...       130.738
# ...                                                 ...           ...
# 9808  Pressured by their immigrant parents to find s...        11.387
# 9809  With his signature pitch-black sense of humor,...        10.436
# 9810  Political commentator Matt Walsh explores the ...        10.299
# 9811  In the sixth installment of the Gabriel's Infe...         9.950
# 9812  It's Christmas Eve and Tori just wants to get ...         8.670
#
#      m_release_date  m_vote_average                     m_poster_path  \
# 0        2011-07-07             8.1  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg
# 1        2011-06-11             6.1  /okIz1HyxeVOMzYwwHUjH2pHi74I.jpg
# 2        2011-08-09             8.2  /3kmfoWWEc9Vtyuaf9v5VipRgdjx.jpg
# 3        2011-05-14             6.5  /keGfSvCmYj7CvdRx36OdVrAEibE.jpg
# 4        2011-09-28             7.0  /4GIeI5K5YdDUkR3mNQBoScpSFEf.jpg
# ...             ...             ...                               ...
# 9808     2022-08-04             6.3  /mFeXAZ1oOECPqEu8c2i4L5LmNyY.jpg
# 9809     2022-05-24             7.3  /ry2HDP5KyEV3R7htXlFAeQbbXgf.jpg
# 9810     2022-06-01             6.9  /iiP8Sq7yWoYsKx9EVfyRPno8Un9.jpg
# 9811     2022-08-12             8.1  /vyLRyHRrPy9zTf6t0sS4aTbF9gl.jpg
# 9812     2022-10-05             5.8  /97PaQ7r4H3y0x9RTXusfedmzf86.jpg
#
#       m_release_year                                         m_keywords  \
# 0               2011  ['saving the world', 'witch', 'self sacrifice'...
# 1               2011  ['car race', 'sequel', 'anthropomorphism', 'be...
# 2               2011  ['mississippi river', 'based on novel or book'...
# 3               2011  ['england', 'spain', 'sea', 'captain', 'mutiny...
# 4               2011  ['parent child relationship', 'fight', 'future...
# ...              ...                                                ...
# 9808            2022                                                 []
# 9809            2022                                ['stand-up comedy']
# 9810            2022  ['womanhood', 'gender', 'social documentary', ...
# 9811            2022                                                 []
# 9812            2022  ['sheriff', 'mass murder', 'murder', 'car cras...
#
#                                               m_results     m_budget  \
# 0     ["It is the quality of one's convictions that ...  125000000.0
# 1     ['Lasseter is smart enough to tell us a comple...  200000000.0
# 2     ['Great setting, cast, story and performances....   25000000.0
# 3     ['More of the same ... but it is not funny any...  380000000.0
# 4     ['No splitting this Atom, it has got a rock so...  110000000.0
# ...                                                 ...          ...
# 9808                                                 []          0.0
# 9809                                                 []          0.0
# 9810                                                 []          0.0
# 9811                                                 []          0.0
# 9812  ['_Christmas Bloody Christmas_ should not be m...          0.0
#
#                                             m_genres  \
# 0                           ['Fantasy', 'Adventure']
# 1     ['Animation', 'Family', 'Adventure', 'Comedy']
# 2                                          ['Drama']
# 3                 ['Adventure', 'Action', 'Fantasy']
# 4             ['Action', 'Science Fiction', 'Drama']
# ...                                              ...
# 9808                           ['Romance', 'Comedy']
# 9809                                      ['Comedy']
# 9810                                 ['Documentary']
# 9811                                     ['Romance']
# 9812                                      ['Horror']
#
#                               m_production_countries     m_revenue  \
# 0     ['United Kingdom', 'United States of America']  1.341511e+09
# 1                       ['United States of America']  5.598524e+08
# 2                       ['United States of America']  2.166391e+08
# 3     ['United Kingdom', 'United States of America']  1.045714e+09
# 4              ['United States of America', 'India']  2.992685e+08
# ...                                              ...           ...
# 9808          ['Canada', 'United States of America']  0.000000e+00
# 9809                              ['United Kingdom']  0.000000e+00
# 9810                    ['United States of America']  0.000000e+00
# 9811                                              []  0.000000e+00
# 9812                    ['United States of America']  0.000000e+00
#
#                                               m_tagline
# 0                                     It all ends here.
# 1                                              Ka-ciao!
# 2                         Change begins with a whisper.
# 3                           Live Forever Or Die Trying.
# 4                    If you get one shot, make it real.
# ...                                                 ...
# 9808                                                NaN
# 9809                                                NaN
# 9810  One man's journey to answer the question of a ...
# 9811                                                NaN
# 9812                                You better not cry.
#
# [9813 rows x 15 columns]

# %%
def _select_movie_data(df_movies,
                          revenue_low,revenue_high,
                          budget_low,budget_high,
                         vote_low, vote_high):
    
    if year_start:
        df_movies = _mask_range(df_movies,'m_release_year',year_start,year_end)
    if revenue_low:
        df_movies = _mask_range(df_movies,'m_revenue',revenue_low, revenue_high)
    if budget_low:
        df_movies = _mask_range(df_movies,'m_budget',budget_low, budget_high)
    if vote_low:
        df_movies = _mask_range(df_movies,'m_vote_average',vote_low, vote_high)
    
    return df_movies

# %%
revenue_low = df_movies.m_revenue.min()
revenue_high = df_movies.m_revenue.max()
budget_low = df_movies.m_budget.min()
budget_high = df_movies.m_budget.max()
vote_low = df_movies.m_vote_average.min()
vote_high = df_movies.m_vote_average.max()

# %%
df_masked_movies = _select_movie_data(df_movies,
                                      revenue_low,
                                      revenue_high,
                                      budget_low,
                                      budget_high,
                                      vote_low,
                                      vote_high)

# %%
def _select_cast_data(df_cast,popularity_low=None,popularity_high=None):
    if popularity_low:
        df_cast = _mask_range(df_cast,'c_popularity',popularity_low, popularity_high)
    return df_cast

# %%
popularity_low=5
popularity_high=100

df_masked_cast = _select_cast_data(df_cast,popularity_low,popularity_high)
df_masked_cast.shape
# Out:
# (11373, 13)

# %% [markdown]
# # Transform - Join Movie and Cast Data

# %%
def join_movies_cast(df_masked_cast, df_masked_movies):
    df_cast_movies = pd.merge(df_masked_cast,df_masked_movies,how='inner',left_on='c_tmdb_id',right_on='m_tmdb_id')
    return df_cast_movies

# %%
df_cast_movies = join_movies_cast(df_masked_cast, df_masked_movies)
df_cast_movies.shape
# Out:
# (11373, 28)

# %%
df_cast_movies.head()
# Out:
#    c_id c_known_for_department         c_name c_original_name  c_popularity  \
# 0    85                 Acting    Johnny Depp     Johnny Depp        35.463
# 1   955                 Acting  Penélope Cruz   Penélope Cruz        27.880
# 2  6972                 Acting    Ian McShane     Ian McShane        40.512
# 3    64                 Acting    Gary Oldman     Gary Oldman        46.498
# 4  6383                 Acting  Aaron Eckhart   Aaron Eckhart        26.468
#
#                      c_profile_path  c_cast_id                c_character  \
# 0  /ilPBHd3r3ahlipNQtjr4E3G04jJ.jpg         15               Jack Sparrow
# 1  /tU2ATiHHBAKn4SHqKOagYqdpHiy.jpg          7                   Angelica
# 2  /q9qKbux5Jo76Sj8g3luxBt6rYtz.jpg          2  Edward "Blackbeard" Teach
# 3  /2v9FVVBUrrkW2m3QOcYkuhq9A6o.jpg         16               James Gordon
# 4  /5EFQvRHlpP1Iaw2e6vjOaBny6DV.jpg         15     Harvey Dent / Two-Face
#
#                 c_credit_id  c_order  ...  m_vote_average  \
# 0  52fe431cc3a36847f803af13        0  ...             6.5
# 1  52fe431cc3a36847f803aef5        1  ...             6.5
# 2  52fe431cc3a36847f803aed9        3  ...             6.5
# 3  52fe4220c3a36847f8005cf5        3  ...             8.5
# 4  52fe4220c3a36847f8005cf1        4  ...             8.5
#
#                       m_poster_path  m_release_year  \
# 0  /keGfSvCmYj7CvdRx36OdVrAEibE.jpg            2011
# 1  /keGfSvCmYj7CvdRx36OdVrAEibE.jpg            2011
# 2  /keGfSvCmYj7CvdRx36OdVrAEibE.jpg            2011
# 3  /qJ2tW6WMUDux911r6m7haRef0WH.jpg            2008
# 4  /qJ2tW6WMUDux911r6m7haRef0WH.jpg            2008
#
#                                           m_keywords  \
# 0  ['england', 'spain', 'sea', 'captain', 'mutiny...
# 1  ['england', 'spain', 'sea', 'captain', 'mutiny...
# 2  ['england', 'spain', 'sea', 'captain', 'mutiny...
# 3  ['crime fighter', 'secret identity', 'anti her...
# 4  ['crime fighter', 'secret identity', 'anti her...
#
#                                            m_results     m_budget  \
# 0  ['More of the same ... but it is not funny any...  380000000.0
# 1  ['More of the same ... but it is not funny any...  380000000.0
# 2  ['More of the same ... but it is not funny any...  380000000.0
# 3  ['Excellent movie. Best of the trilogy. Lovely...  185000000.0
# 4  ['Excellent movie. Best of the trilogy. Lovely...  185000000.0
#
#                                    m_genres  \
# 0        ['Adventure', 'Action', 'Fantasy']
# 1        ['Adventure', 'Action', 'Fantasy']
# 2        ['Adventure', 'Action', 'Fantasy']
# 3  ['Drama', 'Action', 'Crime', 'Thriller']
# 4  ['Drama', 'Action', 'Crime', 'Thriller']
#
#                            m_production_countries     m_revenue  \
# 0  ['United Kingdom', 'United States of America']  1.045714e+09
# 1  ['United Kingdom', 'United States of America']  1.045714e+09
# 2  ['United Kingdom', 'United States of America']  1.045714e+09
# 3  ['United Kingdom', 'United States of America']  1.004558e+09
# 4  ['United Kingdom', 'United States of America']  1.004558e+09
#
#                            m_tagline
# 0        Live Forever Or Die Trying.
# 1        Live Forever Or Die Trying.
# 2        Live Forever Or Die Trying.
# 3  Welcome to a world without rules.
# 4  Welcome to a world without rules.
#
# [5 rows x 28 columns]

# %% [markdown]
# # Transform Cast Data

# %%
import itertools

# %%
def _get_nested_cast(df_cast_movies):
    df_nested = pd.DataFrame(df_cast_movies.groupby('m_movie')['c_name'].agg(lambda x: list(x)))
    solo_cast_mask = df_nested.c_name.apply(lambda x: len(x)>=2)
    df_nested = df_nested[solo_cast_mask]
    return df_nested

# %%
df_nested = _get_nested_cast(df_cast_movies)

# %%
df_nested
# Out:
#                                                                        c_name
# m_movie
# (500) Days of Summer                    [Zooey Deschanel, Chloë Grace Moretz]
# 10 Cloverfield Lane         [Mary Elizabeth Winstead, John Goodman, Bradle...
# 10 Items or Less                               [Morgan Freeman, Danny DeVito]
# 10 Years                    [Channing Tatum, Oscar Isaac, Chris Pratt, Aub...
# 10,000 Saints                                [Hailee Steinfeld, Emile Hirsch]
# ...                                                                       ...
# eXistenZ                                             [Jude Law, Willem Dafoe]
# xXx                                           [Vin Diesel, Samuel L. Jackson]
# xXx: Return of Xander Cage  [Vin Diesel, Donnie Yen, Nina Dobrev, Samuel L...
# xXx: State of the Union                     [Samuel L. Jackson, Willem Dafoe]
# Æon Flux                                 [Charlize Theron, Frances McDormand]
#
# [3025 rows x 1 columns]

# %%
def _get_nested_cast_combinations(cast):
    if len(cast) > 1:
        actor_combinations = itertools.combinations(cast, 2)
        actor_combinations_sorted = [tuple(sorted(combination)) for combination in actor_combinations]
        return actor_combinations_sorted
    else:
        return cast

# %%
df_nested['all_combinations'] = df_nested.c_name.apply(_get_nested_cast_combinations)

# %%
df_nested.loc['Wonder Woman 1984']['all_combinations']
# Out:
# [('Chris Pine', 'Gal Gadot'),
#  ('Connie Nielsen', 'Gal Gadot'),
#  ('Chris Pine', 'Connie Nielsen')]

# %%
def _flatten_nested_cast_combinations(df_nested):
    flattened_combination_tuples = []
    for combinations_in_film in df_nested.all_combinations.values:
        for combination in combinations_in_film:
            flattened_combination_tuples.append(combination)
    return flattened_combination_tuples

# %%
flattened_combination_tuples = _flatten_nested_cast_combinations(df_nested)

# %%
flattened_combination_tuples
# Out:
# [('Chloë Grace Moretz', 'Zooey Deschanel'),
#  ('John Goodman', 'Mary Elizabeth Winstead'),
#  ('Bradley Cooper', 'Mary Elizabeth Winstead'),
#  ('Bradley Cooper', 'John Goodman'),
#  ('Danny DeVito', 'Morgan Freeman'),
#  ('Channing Tatum', 'Oscar Isaac'),
#  ('Channing Tatum', 'Chris Pratt'),
#  ('Aubrey Plaza', 'Channing Tatum'),
#  ('Channing Tatum', 'Rosario Dawson'),
#  ('Chris Pratt', 'Oscar Isaac'),
#  ('Aubrey Plaza', 'Oscar Isaac'),
#  ('Oscar Isaac', 'Rosario Dawson'),
#  ('Aubrey Plaza', 'Chris Pratt'),
#  ('Chris Pratt', 'Rosario Dawson'),
#  ('Aubrey Plaza', 'Rosario Dawson'),
#  ('Emile Hirsch', 'Hailee Steinfeld'),
#  ('Gemma Arterton', 'Idris Elba'),
#  ('Kelly Reilly', 'Luke Evans'),
#  ('Chris Hemsworth', 'Elsa Pataky'),
#  ('Chris Hemsworth', 'Taylor Sheridan'),
#  ('Chris Hemsworth', 'William Fichtner'),
#  ('Elsa Pataky', 'Taylor Sheridan'),
#  ('Elsa Pataky', 'William Fichtner'),
#  ('Taylor Sheridan', 'William Fichtner'),
#  ('Benedict Cumberbatch', 'Michael Fassbender'),
#  ('Michael Fassbender', 'Paul Dano'),
#  ('Brad Pitt', 'Michael Fassbender'),
#  ('Benedict Cumberbatch', 'Paul Dano'),
#  ('Benedict Cumberbatch', 'Brad Pitt'),
#  ('Brad Pitt', 'Paul Dano'),
#  ('Andy Serkis', 'Jennifer Garner'),
#  ('Brie Larson', 'Jennifer Garner'),
#  ('Andy Serkis', 'Brie Larson'),
#  ('Gérard Depardieu', 'Sigourney Weaver'),
#  ('Charlize Theron', 'Robert De Niro'),
#  ('Robert De Niro', 'Vera Farmiga'),
#  ('Charlize Theron', 'Vera Farmiga'),
#  ('Leslie Mann', 'Zac Efron'),
#  ('Mark Strong', 'Richard Madden'),
#  ('Benedict Cumberbatch', 'Mark Strong'),
#  ('Benedict Cumberbatch', 'Richard Madden'),
#  ('Charlize Theron', 'James Spader'),
#  ('Cole Hauser', 'Paul Walker'),
#  ('Denzel Washington', 'Mark Wahlberg'),
#  ('Denzel Washington', 'Paula Patton'),
#  ('Denzel Washington', 'James Marsden'),
#  ('Mark Wahlberg', 'Paula Patton'),
#  ('James Marsden', 'Mark Wahlberg'),
#  ('James Marsden', 'Paula Patton'),
#  ('Christina Ricci', 'Kate Hudson'),
#  ('Kate Hudson', 'Paul Rudd'),
#  ('Christina Ricci', 'Paul Rudd'),
#  ('Eve Harlow', 'Woody Harrelson'),
#  ('Kate Bosworth', 'Laurence Fishburne'),
#  ('J.K. Simmons', 'Taylor Kitsch'),
#  ('J.K. Simmons', 'Keith David'),
#  ('Keith David', 'Taylor Kitsch'),
#  ('Brie Larson', 'Channing Tatum'),
#  ('Channing Tatum', 'Dakota Johnson'),
#  ('Channing Tatum', 'Johnny Depp'),
#  ('Brie Larson', 'Dakota Johnson'),
#  ('Brie Larson', 'Johnny Depp'),
#  ('Dakota Johnson', 'Johnny Depp'),
#  ('Channing Tatum', 'Peter Stormare'),
#  ('Brian Cox', 'Rosario Dawson'),
#  ('James Marsden', 'Peyton List'),
#  ('Sandra Bullock', 'Viggo Mortensen'),
#  ('Brendan Gleeson', 'Cillian Murphy'),
#  ('Idris Elba', 'Jeremy Renner'),
#  ('Hailee Steinfeld', 'Kevin Costner'),
#  ('Connie Nielsen', 'Kevin Costner'),
#  ('Amber Heard', 'Kevin Costner'),
#  ('Connie Nielsen', 'Hailee Steinfeld'),
#  ('Amber Heard', 'Hailee Steinfeld'),
#  ('Amber Heard', 'Connie Nielsen'),
#  ('Elle Fanning', 'Susan Sarandon'),
#  ('Gerard Butler', 'Lena Headey'),
#  ('Gerard Butler', 'Michael Fassbender'),
#  ('Lena Headey', 'Michael Fassbender'),
#  ('Kevin Costner', 'Kurt Russell'),
#  ('Courteney Cox', 'Kurt Russell'),
#  ('Christian Slater', 'Kurt Russell'),
#  ('Courteney Cox', 'Kevin Costner'),
#  ('Christian Slater', 'Kevin Costner'),
#  ('Christian Slater', 'Courteney Cox'),
#  ('Eva Green', 'Lena Headey'),
#  ('Jude Law', 'Rachel Weisz'),
#  ('Hiroyuki Sanada', 'Keanu Reeves'),
#  ('Heather Graham', 'Val Kilmer'),
#  ('Adam Sandler', 'Drew Barrymore'),
#  ('Adam Sandler', 'Jackie Sandler'),
#  ('Adam Sandler', 'Katheryn Winnick'),
#  ('Drew Barrymore', 'Jackie Sandler'),
#  ('Drew Barrymore', 'Katheryn Winnick'),
#  ('Jackie Sandler', 'Katheryn Winnick'),
#  ('Daniel Radcliffe', 'Emma Watson'),
#  ('Daniel Radcliffe', 'Rupert Grint'),
#  ('Emma Watson', 'Rupert Grint'),
#  ('Anna Kendrick', 'Bryce Dallas Howard'),
#  ('Ryan Phillippe', 'Salma Hayek'),
#  ('Nicolas Cage', 'Peter Stormare'),
#  ('Nicolas Cage', 'Norman Reedus'),
#  ('Norman Reedus', 'Peter Stormare'),
#  ('Elijah Wood', 'Jennifer Connelly'),
#  ('Gina Gershon', 'Jacqueline Bisset'),
#  ('Hayden Christensen', 'Kate Bosworth'),
#  ('Andrew Garfield', 'Clancy Brown'),
#  ('Kathryn Hahn', 'Mila Kunis'),
#  ('Mila Kunis', 'Susan Sarandon'),
#  ('Ariana Greenblatt', 'Mila Kunis'),
#  ('Kathryn Hahn', 'Susan Sarandon'),
#  ('Ariana Greenblatt', 'Kathryn Hahn'),
#  ('Ariana Greenblatt', 'Susan Sarandon'),
#  ('Jennifer Connelly', 'Russell Crowe'),
#  ('Paul Bettany', 'Russell Crowe'),
#  ('Bryce Dallas Howard', 'Russell Crowe'),
#  ('Jennifer Connelly', 'Paul Bettany'),
#  ('Bryce Dallas Howard', 'Jennifer Connelly'),
#  ('Bryce Dallas Howard', 'Paul Bettany'),
#  ('Ralph Fiennes', 'Tilda Swinton'),
#  ('Dakota Johnson', 'Tilda Swinton'),
#  ('Dakota Johnson', 'Ralph Fiennes'),
#  ('Brooke Shields', 'Drew Barrymore'),
#  ('Andy Serkis', 'Gary Oldman'),
#  ('Michael Fassbender', 'Viggo Mortensen'),
#  ('Sarah Gadon', 'Viggo Mortensen'),
#  ('Michael Fassbender', 'Sarah Gadon'),
#  ('Bruce Willis', 'Frank Grillo'),
#  ('Britt Robertson', 'Dennis Quaid'),
#  ('Gerard Butler', 'Willem Dafoe'),
#  ('Alison Brie', 'Gerard Butler'),
#  ('Alison Brie', 'Willem Dafoe'),
#  ('Kevin Bacon', 'Tom Cruise'),
#  ('Kiefer Sutherland', 'Tom Cruise'),
#  ('Kevin Bacon', 'Kiefer Sutherland'),
#  ('Emmy Rossum', 'Paul Rudd'),
#  ('Bruce Willis', 'Mary Elizabeth Winstead'),
#  ('Bruce Willis', 'Cole Hauser'),
#  ('Cole Hauser', 'Mary Elizabeth Winstead'),
#  ('Helen Hunt', 'Scarlett Johansson'),
#  ('Channing Tatum', 'Shia LaBeouf'),
#  ('Robert Downey Jr.', 'Shia LaBeouf'),
#  ('Rosario Dawson', 'Shia LaBeouf'),
#  ('Channing Tatum', 'Robert Downey Jr.'),
#  ('Channing Tatum', 'Rosario Dawson'),
#  ('Robert Downey Jr.', 'Rosario Dawson'),
#  ('Maria Bello', 'Viggo Mortensen'),
#  ('Daniel Craig', 'Kate Winslet'),
#  ('Bill Pullman', 'Tom Hanks'),
#  ('Kate Hudson', 'Peter Dinklage'),
#  ('Aaron Paul', 'Pierce Brosnan'),
#  ('Pierce Brosnan', 'Sam Neill'),
#  ('Pierce Brosnan', 'Rosamund Pike'),
#  ('Enrique Arce', 'Pierce Brosnan'),
#  ('Aaron Paul', 'Sam Neill'),
#  ('Aaron Paul', 'Rosamund Pike'),
#  ('Aaron Paul', 'Enrique Arce'),
#  ('Rosamund Pike', 'Sam Neill'),
#  ('Enrique Arce', 'Sam Neill'),
#  ('Enrique Arce', 'Rosamund Pike'),
#  ('Aimee Garcia', 'Kathryn Hahn'),
#  ('Kathryn Hahn', 'Sarah Shahi'),
#  ('Aimee Garcia', 'Sarah Shahi'),
#  ('John Travolta', 'Scarlett Johansson'),
#  ('Michelle Pfeiffer', 'Sophie Marceau'),
#  ('Charlize Theron', 'Seth MacFarlane'),
#  ('Amanda Seyfried', 'Seth MacFarlane'),
#  ('Giovanni Ribisi', 'Seth MacFarlane'),
#  ('Ewan McGregor', 'Seth MacFarlane'),
#  ('Christopher Lloyd', 'Seth MacFarlane'),
#  ('Ryan Reynolds', 'Seth MacFarlane'),
#  ('Amanda Seyfried', 'Charlize Theron'),
#  ('Charlize Theron', 'Giovanni Ribisi'),
#  ('Charlize Theron', 'Ewan McGregor'),
#  ('Charlize Theron', 'Christopher Lloyd'),
#  ('Charlize Theron', 'Ryan Reynolds'),
#  ('Amanda Seyfried', 'Giovanni Ribisi'),
#  ('Amanda Seyfried', 'Ewan McGregor'),
#  ('Amanda Seyfried', 'Christopher Lloyd'),
#  ('Amanda Seyfried', 'Ryan Reynolds'),
#  ('Ewan McGregor', 'Giovanni Ribisi'),
#  ('Christopher Lloyd', 'Giovanni Ribisi'),
#  ('Giovanni Ribisi', 'Ryan Reynolds'),
#  ('Christopher Lloyd', 'Ewan McGregor'),
#  ('Ewan McGregor', 'Ryan Reynolds'),
#  ('Christopher Lloyd', 'Ryan Reynolds'),
#  ('Clancy Brown', 'Rooney Mara'),
#  ('Milla Jovovich', 'Steve Zahn'),
#  ('Chris Hemsworth', 'Steve Zahn'),
#  ('Chris Hemsworth', 'Milla Jovovich'),
#  ('Clint Eastwood', 'Kevin Costner'),
#  ('Tommy Lee Jones', 'Woody Harrelson'),
#  ('Emily Blunt', 'John Krasinski'),
#  ('Emily Blunt', 'Noah Jupe'),
#  ('John Krasinski', 'Noah Jupe'),
#  ('Cillian Murphy', 'Emily Blunt'),
#  ('Cillian Murphy', 'Noah Jupe'),
#  ('Cillian Murphy', 'Djimon Hounsou'),
#  ('Cillian Murphy', 'John Krasinski'),
#  ('Emily Blunt', 'Noah Jupe'),
#  ('Djimon Hounsou', 'Emily Blunt'),
#  ('Emily Blunt', 'John Krasinski'),
#  ('Djimon Hounsou', 'Noah Jupe'),
#  ('John Krasinski', 'Noah Jupe'),
#  ('Djimon Hounsou', 'John Krasinski'),
#  ('Elle Fanning', 'Timothée Chalamet'),
#  ('Jude Law', 'Timothée Chalamet'),
#  ('Elle Fanning', 'Jude Law'),
#  ('Keanu Reeves', 'Robert Downey Jr.'),
#  ('Keanu Reeves', 'Woody Harrelson'),
#  ('Keanu Reeves', 'Winona Ryder'),
#  ('Robert Downey Jr.', 'Woody Harrelson'),
#  ('Robert Downey Jr.', 'Winona Ryder'),
#  ('Winona Ryder', 'Woody Harrelson'),
#  ('Anna Kendrick', 'Linda Cardellini'),
#  ('Bradley Cooper', 'Sam Elliott'),
#  ('Matthew McConaughey', 'Sandra Bullock'),
#  ('Matthew McConaughey', 'Samuel L. Jackson'),
#  ('Donald Sutherland', 'Matthew McConaughey'),
#  ('Kiefer Sutherland', 'Matthew McConaughey'),
#  ('Samuel L. Jackson', 'Sandra Bullock'),
#  ('Donald Sutherland', 'Sandra Bullock'),
#  ('Kiefer Sutherland', 'Sandra Bullock'),
#  ('Donald Sutherland', 'Samuel L. Jackson'),
#  ('Kiefer Sutherland', 'Samuel L. Jackson'),
#  ('Donald Sutherland', 'Kiefer Sutherland'),
#  ('Hassie Harrison', 'Thomas Jane'),
#  ('Haley Joel Osment', 'Jude Law'),
#  ('Brendan Gleeson', 'Haley Joel Osment'),
#  ('Brendan Gleeson', 'Jude Law'),
#  ('Charlie Hunnam', 'Zooey Deschanel'),
#  ('Charlie Hunnam', 'Melanie Lynskey'),
#  ('Melanie Lynskey', 'Zooey Deschanel'),
#  ('Emma Roberts', 'Mimi Rogers'),
#  ('Maria Bello', 'Sigourney Weaver'),
#  ('Dermot Mulroney', 'Sigourney Weaver'),
#  ('Dermot Mulroney', 'Maria Bello'),
#  ('Britt Robertson', 'Emma Roberts'),
#  ('Kevin Hart', 'Paula Patton'),
#  ('Bill Nighy', 'Margot Robbie'),
#  ('Bill Nighy', 'Vanessa Kirby'),
#  ('Margot Robbie', 'Vanessa Kirby'),
#  ('Nicholas Hoult', 'Rachel Weisz'),
#  ('Clint Eastwood', 'Gene Hackman'),
#  ('Jake Gyllenhaal', 'James Marsden'),
#  ('Bruce Willis', 'Cole Hauser'),
#  ('Brad Pitt', 'Tommy Lee Jones'),
#  ('Brad Pitt', 'Liv Tyler'),
#  ('Brad Pitt', 'Donald Sutherland'),
#  ('Liv Tyler', 'Tommy Lee Jones'),
#  ('Donald Sutherland', 'Tommy Lee Jones'),
#  ('Donald Sutherland', 'Liv Tyler'),
#  ('Nicolas Cage', 'Tilda Swinton'),
#  ('Brian Cox', 'Nicolas Cage'),
#  ('Brian Cox', 'Tilda Swinton'),
#  ('Christina Ricci', 'Christopher Lloyd'),
#  ('Emma Roberts', 'Evan Peters'),
#  ('Kristen Stewart', 'Ryan Reynolds'),
#  ('Lucy Liu', 'Samuel L. Jackson'),
#  ('Samuel L. Jackson', 'Zachary Gordon'),
#  ('Lucy Liu', 'Zachary Gordon'),
#  ('Ginger Lynn Allen', 'Lisa Ann'),
#  ('Ariana Marie', 'Ginger Lynn Allen'),
#  ('Ariana Marie', 'Lisa Ann'),
#  ('Mila Kunis', 'Noel Fisher'),
#  ('Noel Fisher', 'Zoe Saldaña'),
#  ('Mila Kunis', 'Zoe Saldaña'),
#  ('Pierce Brosnan', 'Salma Hayek'),
#  ('Pierce Brosnan', 'Woody Harrelson'),
#  ('Salma Hayek', 'Woody Harrelson'),
#  ('Juno Temple', 'Kathryn Hahn'),
#  ('Ian McShane', 'Keith David'),
#  ('Keith David', 'Noel Fisher'),
#  ('Ian McShane', 'Noel Fisher'),
#  ('Oscar Isaac', 'Rachel Weisz'),
#  ('Rami Malek', 'Rooney Mara'),
#  ('Djimon Hounsou', 'Norman Reedus'),
#  ('Mel Gibson', 'Robert Downey Jr.'),
#  ('Gary Oldman', 'Harrison Ford'),
#  ('Adrien Brody', 'Bruce Willis'),
#  ('Keke Palmer', 'Laurence Fishburne'),
#  ('Angela Bassett', 'Keke Palmer'),
#  ('Angela Bassett', 'Laurence Fishburne'),
#  ('Aaron Taylor-Johnson', 'Brendan Gleeson'),
#  ('Viggo Mortensen', 'William Fichtner'),
#  ('Skeet Ulrich', 'William Fichtner'),
#  ('Skeet Ulrich', 'Viggo Mortensen'),
#  ('Kate Hudson', 'Sophie Marceau'),
#  ('Giancarlo Esposito', 'Jean Reno'),
#  ('Angelina Jolie', 'Colin Farrell'),
#  ('Colin Farrell', 'Val Kilmer'),
#  ('Colin Farrell', 'Rosario Dawson'),
#  ('Angelina Jolie', 'Val Kilmer'),
#  ('Angelina Jolie', 'Rosario Dawson'),
#  ('Rosario Dawson', 'Val Kilmer'),
#  ('Jennifer Garner', 'Steve Carell'),
#  ('Jude Law', 'Marisa Tomei'),
#  ('Jude Law', 'Susan Sarandon'),
#  ('Jude Law', 'Katherine LaNasa'),
#  ('Marisa Tomei', 'Susan Sarandon'),
#  ('Katherine LaNasa', 'Marisa Tomei'),
#  ('Katherine LaNasa', 'Susan Sarandon'),
#  ('Charles Dance', 'Rhona Mitra'),
#  ('Anne Hathaway', 'Johnny Depp'),
#  ('Christopher Lloyd', 'Johnny Depp'),
#  ('Anne Hathaway', 'Christopher Lloyd'),
#  ('Anne Hathaway', 'Johnny Depp'),
#  ('Sigourney Weaver', 'Winona Ryder'),
#  ('Ron Perlman', 'Sigourney Weaver'),
#  ('Ron Perlman', 'Winona Ryder'),
#  ('Austin Butler', 'J.K. Simmons'),
#  ('Charles Dance', 'Sigourney Weaver'),
#  ('Jennifer Connelly', 'Rosa Salazar'),
#  ('Bradley Cooper', 'Sandra Bullock'),
#  ('Keith David', 'Sandra Bullock'),
#  ('Bradley Cooper', 'Keith David'),
#  ('Kirsten Dunst', 'Ryan Gosling'),
#  ('Emile Hirsch', 'J.K. Simmons'),
#  ("Dylan O'Brien", 'Sadie Sink'),
#  ('Amber Heard', 'Luke Grimes'),
#  ('Jude Law', 'Kate Winslet'),
#  ('Chris Pine', 'Laurence Fishburne'),
#  ('Matt Damon', 'Penélope Cruz'),
#  ('Matt Damon', 'Robert Patrick'),
#  ('Penélope Cruz', 'Robert Patrick'),
#  ('Bill Skarsgård', 'Theo James'),
#  ('Frances McDormand', 'Kate Hudson'),
#  ('Frances McDormand', 'Zooey Deschanel'),
#  ('Frances McDormand', 'Rainn Wilson'),
#  ('Kate Hudson', 'Zooey Deschanel'),
#  ('Kate Hudson', 'Rainn Wilson'),
#  ('Rainn Wilson', 'Zooey Deschanel'),
#  ('Cillian Murphy', 'Jennifer Connelly'),
#  ('Bradley Cooper', 'Emma Stone'),
#  ('Bradley Cooper', 'John Krasinski'),
#  ('Emma Stone', 'John Krasinski'),
#  ('Jennifer Aniston', 'Kevin Hart'),
#  ('Dermot Mulroney', 'Kate Bosworth'),
#  ('Bruce Willis', 'Emile Hirsch'),
#  ('Amanda Seyfried', 'Emile Hirsch'),
#  ('Amber Heard', 'Emile Hirsch'),
#  ('Emile Hirsch', 'Sharon Stone'),
#  ('Emile Hirsch', 'Olivia Wilde'),
#  ('Amanda Seyfried', 'Bruce Willis'),
#  ('Amber Heard', 'Bruce Willis'),
#  ('Bruce Willis', 'Sharon Stone'),
#  ('Bruce Willis', 'Olivia Wilde'),
#  ('Amanda Seyfried', 'Amber Heard'),
#  ('Amanda Seyfried', 'Sharon Stone'),
#  ('Amanda Seyfried', 'Olivia Wilde'),
#  ('Amber Heard', 'Sharon Stone'),
#  ('Amber Heard', 'Olivia Wilde'),
#  ('Olivia Wilde', 'Sharon Stone'),
#  ('Ali Wong', 'Keanu Reeves'),
#  ('Colleen Camp', 'Mackenzie Davis'),
#  ('Devan Long', 'Jake Gyllenhaal'),
#  ('Ewan McGregor', 'Richard Gere'),
#  ('Christopher Walken', 'Rainn Wilson'),
#  ('Christopher Walken', 'Emma Roberts'),
#  ('Emma Roberts', 'Rainn Wilson'),
#  ("Dylan O'Brien", 'Michael Keaton'),
#  ("Dylan O'Brien", 'Taylor Kitsch'),
#  ("Dylan O'Brien", 'Scott Adkins'),
#  ('Michael Keaton', 'Taylor Kitsch'),
#  ('Michael Keaton', 'Scott Adkins'),
#  ('Scott Adkins', 'Taylor Kitsch'),
#  ('Dennis Quaid', 'Willem Dafoe'),
#  ('Denzel Washington', 'Russell Crowe'),
#  ('Josh Brolin', 'Russell Crowe'),
#  ('Idris Elba', 'Russell Crowe'),
#  ('Carla Gugino', 'Russell Crowe'),
#  ('Norman Reedus', 'Russell Crowe'),
#  ('Denzel Washington', 'Josh Brolin'),
#  ('Denzel Washington', 'Idris Elba'),
#  ('Carla Gugino', 'Denzel Washington'),
#  ('Denzel Washington', 'Norman Reedus'),
#  ('Idris Elba', 'Josh Brolin'),
#  ('Carla Gugino', 'Josh Brolin'),
#  ('Josh Brolin', 'Norman Reedus'),
#  ('Carla Gugino', 'Idris Elba'),
#  ('Idris Elba', 'Norman Reedus'),
#  ('Carla Gugino', 'Norman Reedus'),
#  ('Adrien Brody', 'Hayden Christensen'),
#  ('Amy Adams', 'Bradley Cooper'),
#  ('Bradley Cooper', 'Jeremy Renner'),
#  ('Bradley Cooper', 'Colleen Camp'),
#  ('Bradley Cooper', 'Dawn Olivieri'),
#  ('Bradley Cooper', 'Robert De Niro'),
#  ('Amy Adams', 'Jeremy Renner'),
#  ('Amy Adams', 'Colleen Camp'),
#  ('Amy Adams', 'Dawn Olivieri'),
#  ('Amy Adams', 'Robert De Niro'),
#  ('Colleen Camp', 'Jeremy Renner'),
#  ('Dawn Olivieri', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Robert De Niro'),
#  ('Colleen Camp', 'Dawn Olivieri'),
#  ('Colleen Camp', 'Robert De Niro'),
#  ('Dawn Olivieri', 'Robert De Niro'),
#  ('Colin Farrell', 'Timothy Dalton'),
#  ('Ewan McGregor', 'Jennifer Connelly'),
#  ('Dakota Fanning', 'Ewan McGregor'),
#  ('Dakota Fanning', 'Jennifer Connelly'),
#  ('Madison Pettis', 'Zachary Gordon'),
#  ('Denise Richards', 'Tori Black'),
#  ('Bradley Cooper', 'Luke Grimes'),
#  ('Bradley Cooper', 'Clint Eastwood'),
#  ('Clint Eastwood', 'Luke Grimes'),
#  ('John Leguizamo', 'Kristen Stewart'),
#  ('Bill Pullman', 'Kristen Stewart'),
#  ('Bill Pullman', 'John Leguizamo'),
#  ('Dennis Quaid', 'Zachary Levi'),
#  ('Djimon Hounsou', 'Morgan Freeman'),
#  ('Matthew McConaughey', 'Morgan Freeman'),
#  ('Djimon Hounsou', 'Matthew McConaughey'),
#  ('Jennifer Morrison', 'Mckenna Grace'),
#  ('Kate Winslet', 'Saoirse Ronan'),
#  ('Nicolas Cage', 'Samuel L. Jackson'),
#  ('Giancarlo Esposito', 'Samuel L. Jackson'),
#  ('Giancarlo Esposito', 'Nicolas Cage'),
#  ('Margot Robbie', 'Robert De Niro'),
#  ('Anya Taylor-Joy', 'Margot Robbie'),
#  ('Margot Robbie', 'Rami Malek'),
#  ('Margot Robbie', 'Zoe Saldaña'),
#  ('Colleen Camp', 'Margot Robbie'),
#  ('Anya Taylor-Joy', 'Robert De Niro'),
#  ('Rami Malek', 'Robert De Niro'),
#  ('Robert De Niro', 'Zoe Saldaña'),
#  ('Colleen Camp', 'Robert De Niro'),
#  ('Anya Taylor-Joy', 'Rami Malek'),
#  ('Anya Taylor-Joy', 'Zoe Saldaña'),
#  ('Anya Taylor-Joy', 'Colleen Camp'),
#  ('Rami Malek', 'Zoe Saldaña'),
#  ('Colleen Camp', 'Rami Malek'),
#  ('Colleen Camp', 'Zoe Saldaña'),
#  ('Lacey Chabert', 'Ron Perlman'),
#  ('Peter Stormare', 'Willem Dafoe'),
#  ('Christopher Lloyd', 'Kirsten Dunst'),
#  ('Christopher Lloyd', 'Lacey Chabert'),
#  ('Kirsten Dunst', 'Lacey Chabert'),
#  ('Paul Rudd', 'Steve Carell'),
#  ('Meagan Good', 'Steve Carell'),
#  ('Harrison Ford', 'Steve Carell'),
#  ('James Marsden', 'Steve Carell'),
#  ('Kirsten Dunst', 'Steve Carell'),
#  ('Meagan Good', 'Paul Rudd'),
#  ('Harrison Ford', 'Paul Rudd'),
#  ('James Marsden', 'Paul Rudd'),
#  ('Kirsten Dunst', 'Paul Rudd'),
#  ('Harrison Ford', 'Meagan Good'),
#  ('James Marsden', 'Meagan Good'),
#  ('Kirsten Dunst', 'Meagan Good'),
#  ('Harrison Ford', 'James Marsden'),
#  ('Harrison Ford', 'Kirsten Dunst'),
#  ('James Marsden', 'Kirsten Dunst'),
#  ('Paul Rudd', 'Steve Carell'),
#  ('Kathryn Hahn', 'Paul Rudd'),
#  ('Jack Black', 'Paul Rudd'),
#  ('Kathryn Hahn', 'Steve Carell'),
#  ('Jack Black', 'Steve Carell'),
#  ('Jack Black', 'Kathryn Hahn'),
#  ('Michael Fassbender', 'Sam Neill'),
#  ('Gerard Butler', 'Morgan Freeman'),
#  ('Gerard Butler', 'Lance Reddick'),
#  ('Gerard Butler', 'Piper Perabo'),
#  ('Lance Reddick', 'Morgan Freeman'),
#  ('Morgan Freeman', 'Piper Perabo'),
#  ('Lance Reddick', 'Piper Perabo'),
#  ('Luke Evans', 'Yvonne Strahovski'),
#  ('Ewan McGregor', 'Tom Hanks'),
#  ('Christopher Lloyd', 'Matthew McConaughey'),
#  ('Adrien Brody', 'Christopher Lloyd'),
#  ('Christopher Lloyd', 'Dermot Mulroney'),
#  ('Adrien Brody', 'Matthew McConaughey'),
#  ('Dermot Mulroney', 'Matthew McConaughey'),
#  ('Adrien Brody', 'Dermot Mulroney'),
#  ('Adam Sandler', 'Marisa Tomei'),
#  ('Adam Sandler', 'Woody Harrelson'),
#  ('Adam Sandler', 'Heather Graham'),
#  ('Marisa Tomei', 'Woody Harrelson'),
#  ('Heather Graham', 'Marisa Tomei'),
#  ('Heather Graham', 'Woody Harrelson'),
#  ('Emily Blunt', 'John Krasinski'),
#  ('Emily Blunt', 'Sylvester Stallone'),
#  ('Danny DeVito', 'Emily Blunt'),
#  ('John Krasinski', 'Sylvester Stallone'),
#  ('Danny DeVito', 'John Krasinski'),
#  ('Danny DeVito', 'Sylvester Stallone'),
#  ('Brian Cox', 'Mark Strong'),
#  ('Indira Varma', 'Mark Strong'),
#  ('Brian Cox', 'Indira Varma'),
#  ('Jude Law', 'Matthew Macfadyen'),
#  ('Aaron Taylor-Johnson', 'Matthew Macfadyen'),
#  ('Bill Skarsgård', 'Matthew Macfadyen'),
#  ('Matthew Macfadyen', 'Sophie Marceau'),
#  ('Matthew Macfadyen', 'Sean Bean'),
#  ('Aaron Taylor-Johnson', 'Jude Law'),
#  ('Bill Skarsgård', 'Jude Law'),
#  ('Jude Law', 'Sophie Marceau'),
#  ('Jude Law', 'Sean Bean'),
#  ('Aaron Taylor-Johnson', 'Bill Skarsgård'),
#  ('Aaron Taylor-Johnson', 'Sophie Marceau'),
#  ('Aaron Taylor-Johnson', 'Sean Bean'),
#  ('Bill Skarsgård', 'Sophie Marceau'),
#  ('Bill Skarsgård', 'Sean Bean'),
#  ('Sean Bean', 'Sophie Marceau'),
#  ('Mckenna Grace', 'Vera Farmiga'),
#  ('Annabelle Wallis', 'Grace Caroline Currey'),
#  ('Mila Kunis', 'Sarah Hyland'),
#  ('Natalie Portman', 'Tessa Thompson'),
#  ('Natalie Portman', 'Oscar Isaac'),
#  ('Oscar Isaac', 'Tessa Thompson'),
#  ('Evangeline Lilly', 'Paul Rudd'),
#  ('Chris Evans', 'Paul Rudd'),
#  ('Chris Evans', 'Evangeline Lilly'),
#  ('Evangeline Lilly', 'Paul Rudd'),
#  ('Michelle Pfeiffer', 'Paul Rudd'),
#  ('Laurence Fishburne', 'Paul Rudd'),
#  ('Evangeline Lilly', 'Michelle Pfeiffer'),
#  ('Evangeline Lilly', 'Laurence Fishburne'),
#  ('Laurence Fishburne', 'Michelle Pfeiffer'),
#  ('Claire Forlani', 'Ryan Phillippe'),
#  ('Denzel Washington', 'Viola Davis'),
#  ('Gene Hackman', 'Sharon Stone'),
#  ('Sharon Stone', 'Sylvester Stallone'),
#  ('Christopher Walken', 'Sharon Stone'),
#  ('Gene Hackman', 'Sylvester Stallone'),
#  ('Christopher Walken', 'Gene Hackman'),
#  ('Christopher Walken', 'Sylvester Stallone'),
#  ('Al Pacino', 'Dennis Quaid'),
#  ('Aaron Eckhart', 'Al Pacino'),
#  ('Aaron Eckhart', 'Dennis Quaid'),
#  ('Christina Ricci', 'Danny DeVito'),
#  ('Natalie Portman', 'Susan Sarandon'),
#  ('Ashley Johnson', 'Susan Sarandon'),
#  ('Ashley Johnson', 'Natalie Portman'),
#  ('Jack Black', 'Zachary Levi'),
#  ('Glen Powell', 'Jack Black'),
#  ('Glen Powell', 'Zachary Levi'),
#  ('Kevin Bacon', 'Tom Hanks'),
#  ('Amber Heard', 'Jason Momoa'),
#  ('Jason Momoa', 'Willem Dafoe'),
#  ('Jason Momoa', 'Nicole Kidman'),
#  ('Djimon Hounsou', 'Jason Momoa'),
#  ('Amber Heard', 'Willem Dafoe'),
#  ('Amber Heard', 'Nicole Kidman'),
#  ('Amber Heard', 'Djimon Hounsou'),
#  ('Nicole Kidman', 'Willem Dafoe'),
#  ('Djimon Hounsou', 'Willem Dafoe'),
#  ('Djimon Hounsou', 'Nicole Kidman'),
#  ('Richard Gere', 'Susan Sarandon'),
#  ('Rhona Mitra', 'Theo James'),
#  ('Nina Dobrev', 'Samuel L. Jackson'),
#  ('Bryan Cranston', 'John Goodman'),
#  ('Bruce Willis', 'Liv Tyler'),
#  ('Bruce Willis', 'William Fichtner'),
#  ('Bruce Willis', 'Owen Wilson'),
#  ('Bruce Willis', 'Peter Stormare'),
#  ('Bruce Willis', 'Keith David'),
#  ('Liv Tyler', 'William Fichtner'),
#  ('Liv Tyler', 'Owen Wilson'),
#  ('Liv Tyler', 'Peter Stormare'),
#  ('Keith David', 'Liv Tyler'),
#  ('Owen Wilson', 'William Fichtner'),
#  ('Peter Stormare', 'William Fichtner'),
#  ('Keith David', 'William Fichtner'),
#  ('Owen Wilson', 'Peter Stormare'),
#  ('Keith David', 'Owen Wilson'),
#  ('Keith David', 'Peter Stormare'),
#  ('Jean Reno', 'Laurence Fishburne'),
#  ('Jean Reno', 'Skeet Ulrich'),
#  ('Laurence Fishburne', 'Skeet Ulrich'),
#  ('Bridget Fonda', 'Embeth Davidtz'),
#  ('Nicolas Cage', 'Rainn Wilson'),
#  ('Hiroyuki Sanada', 'Nathalie Emmanuel'),
#  ('Dave Bautista', 'Nathalie Emmanuel'),
#  ('Dave Bautista', 'Hiroyuki Sanada'),
#  ('Dave Bautista', 'Ella Purnell'),
#  ('Dave Bautista', 'Hiroyuki Sanada'),
#  ('Ella Purnell', 'Hiroyuki Sanada'),
#  ('Jackie Chan', 'Owen Wilson'),
#  ('Amy Adams', 'Jeremy Renner'),
#  ('Colin Farrell', 'Hong Chau'),
#  ('Helen Mirren', 'Jennifer Garner'),
#  ('Bill Nighy', 'James McAvoy'),
#  ('Andy Serkis', 'James McAvoy'),
#  ('Andy Serkis', 'Bill Nighy'),
#  ('Anne Heche', 'Emily Blunt'),
#  ('Jason Bateman', 'Robert De Niro'),
#  ('Harvey Keitel', 'Jason Bateman'),
#  ('Harvey Keitel', 'Robert De Niro'),
#  ('Helen Hunt', 'Skeet Ulrich'),
#  ('Famke Janssen', 'Ron Perlman'),
#  ('Jacqueline Bisset', 'Ron Perlman'),
#  ('Marta Milans', 'Ron Perlman'),
#  ('Famke Janssen', 'Jacqueline Bisset'),
#  ('Famke Janssen', 'Marta Milans'),
#  ('Jacqueline Bisset', 'Marta Milans'),
#  ('Britt Robertson', 'Robert Patrick'),
#  ('Britt Robertson', 'Christian Slater'),
#  ('Christian Slater', 'Robert Patrick'),
#  ('Colin Farrell', 'Salma Hayek'),
#  ('Colin Farrell', 'Donald Sutherland'),
#  ('Donald Sutherland', 'Salma Hayek'),
#  ('Brendan Gleeson', 'Michael Fassbender'),
#  ('Bill Skarsgård', 'Jennifer Morrison'),
#  ('Bruce Willis', 'Luke Grimes'),
#  ('Antonio Banderas', 'Sylvester Stallone'),
#  ('Laurence Fishburne', 'Maria Bello'),
#  ('John Leguizamo', 'Laurence Fishburne'),
#  ('John Leguizamo', 'Maria Bello'),
#  ('Donald Sutherland', 'Nicolas Cage'),
#  ('Bill Nighy', 'Nicolas Cage'),
#  ('Nicolas Cage', 'Samuel L. Jackson'),
#  ('Charlize Theron', 'Nicolas Cage'),
#  ('Elle Fanning', 'Nicolas Cage'),
#  ('Bill Nighy', 'Donald Sutherland'),
#  ('Donald Sutherland', 'Samuel L. Jackson'),
#  ('Charlize Theron', 'Donald Sutherland'),
#  ('Donald Sutherland', 'Elle Fanning'),
#  ('Bill Nighy', 'Samuel L. Jackson'),
#  ('Bill Nighy', 'Charlize Theron'),
#  ('Bill Nighy', 'Elle Fanning'),
#  ('Charlize Theron', 'Samuel L. Jackson'),
#  ('Elle Fanning', 'Samuel L. Jackson'),
#  ('Charlize Theron', 'Elle Fanning'),
#  ('Dennis Quaid', 'Zac Efron'),
#  ('Clancy Brown', 'Dennis Quaid'),
#  ('Dennis Quaid', 'Heather Graham'),
#  ('Clancy Brown', 'Zac Efron'),
#  ('Heather Graham', 'Zac Efron'),
#  ('Clancy Brown', 'Heather Graham'),
#  ('Oscar Isaac', 'Willem Dafoe'),
#  ('Mads Mikkelsen', 'Willem Dafoe'),
#  ('Mads Mikkelsen', 'Oscar Isaac'),
#  ('Charlize Theron', 'James McAvoy'),
#  ('Charlize Theron', 'John Goodman'),
#  ('Bill Skarsgård', 'Charlize Theron'),
#  ('James McAvoy', 'John Goodman'),
#  ('Bill Skarsgård', 'James McAvoy'),
#  ('Bill Skarsgård', 'John Goodman'),
#  ('James McAvoy', 'Saoirse Ronan'),
#  ('James McAvoy', 'Juno Temple'),
#  ('Benedict Cumberbatch', 'James McAvoy'),
#  ('Juno Temple', 'Saoirse Ronan'),
#  ('Benedict Cumberbatch', 'Saoirse Ronan'),
#  ('Benedict Cumberbatch', 'Juno Temple'),
#  ('Dermot Mulroney', 'Ewan McGregor'),
#  ('Benedict Cumberbatch', 'Ewan McGregor'),
#  ('Benedict Cumberbatch', 'Dermot Mulroney'),
#  ('Danny DeVito', 'John Travolta'),
#  ('John Travolta', 'Tom Cruise'),
#  ('John Travolta', 'Rob Lowe'),
#  ('John Travolta', 'Steven Spielberg'),
#  ('Danny DeVito', 'Tom Cruise'),
#  ('Danny DeVito', 'Rob Lowe'),
#  ('Danny DeVito', 'Steven Spielberg'),
#  ('Rob Lowe', 'Tom Cruise'),
#  ('Steven Spielberg', 'Tom Cruise'),
#  ('Rob Lowe', 'Steven Spielberg'),
#  ('Christian Slater', 'Mimi Rogers'),
#  ('Mimi Rogers', 'Rob Lowe'),
#  ('Christian Slater', 'Rob Lowe'),
#  ('Heather Graham', 'Rob Lowe'),
#  ('Heather Graham', 'Woody Harrelson'),
#  ('Rob Lowe', 'Woody Harrelson'),
#  ('Maria Bello', 'Willem Dafoe'),
#  ('Richard Gere', 'Winona Ryder'),
#  ('Richard Gere', 'Vera Farmiga'),
#  ('J.K. Simmons', 'Richard Gere'),
#  ('Vera Farmiga', 'Winona Ryder'),
#  ('J.K. Simmons', 'Winona Ryder'),
#  ('J.K. Simmons', 'Vera Farmiga'),
#  ('Sam Worthington', 'Zoe Saldaña'),
#  ('Sam Worthington', 'Sigourney Weaver'),
#  ('Sam Worthington', 'Stephen Lang'),
#  ('Giovanni Ribisi', 'Sam Worthington'),
#  ('Sigourney Weaver', 'Zoe Saldaña'),
#  ('Stephen Lang', 'Zoe Saldaña'),
#  ('Giovanni Ribisi', 'Zoe Saldaña'),
#  ('Sigourney Weaver', 'Stephen Lang'),
#  ('Giovanni Ribisi', 'Sigourney Weaver'),
#  ('Giovanni Ribisi', 'Stephen Lang'),
#  ('Sam Worthington', 'Zoe Saldaña'),
#  ('Sam Worthington', 'Sigourney Weaver'),
#  ('Sam Worthington', 'Stephen Lang'),
#  ('Kate Winslet', 'Sam Worthington'),
#  ('Giovanni Ribisi', 'Sam Worthington'),
#  ('Sigourney Weaver', 'Zoe Saldaña'),
#  ('Stephen Lang', 'Zoe Saldaña'),
#  ('Kate Winslet', 'Zoe Saldaña'),
#  ('Giovanni Ribisi', 'Zoe Saldaña'),
#  ('Sigourney Weaver', 'Stephen Lang'),
#  ('Kate Winslet', 'Sigourney Weaver'),
#  ('Giovanni Ribisi', 'Sigourney Weaver'),
#  ('Kate Winslet', 'Stephen Lang'),
#  ('Giovanni Ribisi', 'Stephen Lang'),
#  ('Giovanni Ribisi', 'Kate Winslet'),
#  ('Chris Hemsworth', 'Robert Downey Jr.'),
#  ('Chris Evans', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Scarlett Johansson'),
#  ('Jeremy Renner', 'Robert Downey Jr.'),
#  ('James Spader', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Samuel L. Jackson'),
#  ('Aaron Taylor-Johnson', 'Robert Downey Jr.'),
#  ('Elizabeth Olsen', 'Robert Downey Jr.'),
#  ('Paul Bettany', 'Robert Downey Jr.'),
#  ('Idris Elba', 'Robert Downey Jr.'),
#  ('Linda Cardellini', 'Robert Downey Jr.'),
#  ('Andy Serkis', 'Robert Downey Jr.'),
#  ('Josh Brolin', 'Robert Downey Jr.'),
#  ('Chris Evans', 'Chris Hemsworth'),
#  ('Chris Hemsworth', 'Scarlett Johansson'),
#  ('Chris Hemsworth', 'Jeremy Renner'),
#  ('Chris Hemsworth', 'James Spader'),
#  ('Chris Hemsworth', 'Samuel L. Jackson'),
#  ('Aaron Taylor-Johnson', 'Chris Hemsworth'),
#  ('Chris Hemsworth', 'Elizabeth Olsen'),
#  ('Chris Hemsworth', 'Paul Bettany'),
#  ('Chris Hemsworth', 'Idris Elba'),
#  ('Chris Hemsworth', 'Linda Cardellini'),
#  ('Andy Serkis', 'Chris Hemsworth'),
#  ('Chris Hemsworth', 'Josh Brolin'),
#  ('Chris Evans', 'Scarlett Johansson'),
#  ('Chris Evans', 'Jeremy Renner'),
#  ('Chris Evans', 'James Spader'),
#  ('Chris Evans', 'Samuel L. Jackson'),
#  ('Aaron Taylor-Johnson', 'Chris Evans'),
#  ('Chris Evans', 'Elizabeth Olsen'),
#  ('Chris Evans', 'Paul Bettany'),
#  ('Chris Evans', 'Idris Elba'),
#  ('Chris Evans', 'Linda Cardellini'),
#  ('Andy Serkis', 'Chris Evans'),
#  ('Chris Evans', 'Josh Brolin'),
#  ('Jeremy Renner', 'Scarlett Johansson'),
#  ('James Spader', 'Scarlett Johansson'),
#  ('Samuel L. Jackson', 'Scarlett Johansson'),
#  ('Aaron Taylor-Johnson', 'Scarlett Johansson'),
#  ('Elizabeth Olsen', 'Scarlett Johansson'),
#  ('Paul Bettany', 'Scarlett Johansson'),
#  ('Idris Elba', 'Scarlett Johansson'),
#  ('Linda Cardellini', 'Scarlett Johansson'),
#  ('Andy Serkis', 'Scarlett Johansson'),
#  ('Josh Brolin', 'Scarlett Johansson'),
#  ('James Spader', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Samuel L. Jackson'),
#  ('Aaron Taylor-Johnson', 'Jeremy Renner'),
#  ('Elizabeth Olsen', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Paul Bettany'),
#  ('Idris Elba', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Linda Cardellini'),
#  ('Andy Serkis', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Josh Brolin'),
#  ('James Spader', 'Samuel L. Jackson'),
#  ('Aaron Taylor-Johnson', 'James Spader'),
#  ('Elizabeth Olsen', 'James Spader'),
#  ('James Spader', 'Paul Bettany'),
#  ('Idris Elba', 'James Spader'),
#  ('James Spader', 'Linda Cardellini'),
#  ('Andy Serkis', 'James Spader'),
#  ('James Spader', 'Josh Brolin'),
#  ('Aaron Taylor-Johnson', 'Samuel L. Jackson'),
#  ('Elizabeth Olsen', 'Samuel L. Jackson'),
#  ('Paul Bettany', 'Samuel L. Jackson'),
#  ('Idris Elba', 'Samuel L. Jackson'),
#  ('Linda Cardellini', 'Samuel L. Jackson'),
#  ('Andy Serkis', 'Samuel L. Jackson'),
#  ('Josh Brolin', 'Samuel L. Jackson'),
#  ('Aaron Taylor-Johnson', 'Elizabeth Olsen'),
#  ('Aaron Taylor-Johnson', 'Paul Bettany'),
#  ('Aaron Taylor-Johnson', 'Idris Elba'),
#  ('Aaron Taylor-Johnson', 'Linda Cardellini'),
#  ('Aaron Taylor-Johnson', 'Andy Serkis'),
#  ('Aaron Taylor-Johnson', 'Josh Brolin'),
#  ('Elizabeth Olsen', 'Paul Bettany'),
#  ('Elizabeth Olsen', 'Idris Elba'),
#  ('Elizabeth Olsen', 'Linda Cardellini'),
#  ('Andy Serkis', 'Elizabeth Olsen'),
#  ('Elizabeth Olsen', 'Josh Brolin'),
#  ('Idris Elba', 'Paul Bettany'),
#  ('Linda Cardellini', 'Paul Bettany'),
#  ('Andy Serkis', 'Paul Bettany'),
#  ('Josh Brolin', 'Paul Bettany'),
#  ('Idris Elba', 'Linda Cardellini'),
#  ('Andy Serkis', 'Idris Elba'),
#  ('Idris Elba', 'Josh Brolin'),
#  ('Andy Serkis', 'Linda Cardellini'),
#  ('Josh Brolin', 'Linda Cardellini'),
#  ('Andy Serkis', 'Josh Brolin'),
#  ('Chris Evans', 'Robert Downey Jr.'),
#  ('Chris Hemsworth', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Scarlett Johansson'),
#  ('Jeremy Renner', 'Robert Downey Jr.'),
#  ('Paul Rudd', 'Robert Downey Jr.'),
#  ('Benedict Cumberbatch', 'Robert Downey Jr.'),
#  ('Brie Larson', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Tom Holland'),
#  ('Karen Gillan', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Zoe Saldaña'),
#  ('Evangeline Lilly', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Tessa Thompson'),
#  ('Elizabeth Olsen', 'Robert Downey Jr.'),
#  ('Dave Bautista', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Tilda Swinton'),
#  ('Jon Favreau', 'Robert Downey Jr.'),
#  ('Natalie Portman', 'Robert Downey Jr.'),
#  ('Marisa Tomei', 'Robert Downey Jr.'),
#  ('Angela Bassett', 'Robert Downey Jr.'),
#  ('Michelle Pfeiffer', 'Robert Downey Jr.'),
#  ('Linda Cardellini', 'Robert Downey Jr.'),
#  ('Frank Grillo', 'Robert Downey Jr.'),
#  ('Hiroyuki Sanada', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Vin Diesel'),
#  ('Bradley Cooper', 'Robert Downey Jr.'),
#  ('Josh Brolin', 'Robert Downey Jr.'),
#  ('Chris Pratt', 'Robert Downey Jr.'),
#  ('Robert Downey Jr.', 'Samuel L. Jackson'),
#  ('Chris Evans', 'Chris Hemsworth'),
#  ('Chris Evans', 'Scarlett Johansson'),
#  ('Chris Evans', 'Jeremy Renner'),
#  ('Chris Evans', 'Paul Rudd'),
#  ('Benedict Cumberbatch', 'Chris Evans'),
#  ('Brie Larson', 'Chris Evans'),
#  ('Chris Evans', 'Tom Holland'),
#  ('Chris Evans', 'Karen Gillan'),
#  ('Chris Evans', 'Zoe Saldaña'),
#  ('Chris Evans', 'Evangeline Lilly'),
#  ('Chris Evans', 'Tessa Thompson'),
#  ('Chris Evans', 'Elizabeth Olsen'),
#  ('Chris Evans', 'Dave Bautista'),
#  ('Chris Evans', 'Tilda Swinton'),
#  ('Chris Evans', 'Jon Favreau'),
#  ('Chris Evans', 'Natalie Portman'),
#  ('Chris Evans', 'Marisa Tomei'),
#  ('Angela Bassett', 'Chris Evans'),
#  ('Chris Evans', 'Michelle Pfeiffer'),
#  ('Chris Evans', 'Linda Cardellini'),
#  ('Chris Evans', 'Frank Grillo'),
#  ('Chris Evans', 'Hiroyuki Sanada'),
#  ('Chris Evans', 'Vin Diesel'),
#  ('Bradley Cooper', 'Chris Evans'),
#  ('Chris Evans', 'Josh Brolin'),
#  ('Chris Evans', 'Chris Pratt'),
#  ('Chris Evans', 'Samuel L. Jackson'),
#  ('Chris Hemsworth', 'Scarlett Johansson'),
#  ('Chris Hemsworth', 'Jeremy Renner'),
#  ('Chris Hemsworth', 'Paul Rudd'),
#  ('Benedict Cumberbatch', 'Chris Hemsworth'),
#  ('Brie Larson', 'Chris Hemsworth'),
#  ('Chris Hemsworth', 'Tom Holland'),
#  ('Chris Hemsworth', 'Karen Gillan'),
#  ('Chris Hemsworth', 'Zoe Saldaña'),
#  ('Chris Hemsworth', 'Evangeline Lilly'),
#  ('Chris Hemsworth', 'Tessa Thompson'),
#  ('Chris Hemsworth', 'Elizabeth Olsen'),
#  ('Chris Hemsworth', 'Dave Bautista'),
#  ('Chris Hemsworth', 'Tilda Swinton'),
#  ('Chris Hemsworth', 'Jon Favreau'),
#  ('Chris Hemsworth', 'Natalie Portman'),
#  ('Chris Hemsworth', 'Marisa Tomei'),
#  ('Angela Bassett', 'Chris Hemsworth'),
#  ('Chris Hemsworth', 'Michelle Pfeiffer'),
#  ('Chris Hemsworth', 'Linda Cardellini'),
#  ('Chris Hemsworth', 'Frank Grillo'),
#  ('Chris Hemsworth', 'Hiroyuki Sanada'),
#  ('Chris Hemsworth', 'Vin Diesel'),
#  ('Bradley Cooper', 'Chris Hemsworth'),
#  ('Chris Hemsworth', 'Josh Brolin'),
#  ('Chris Hemsworth', 'Chris Pratt'),
#  ('Chris Hemsworth', 'Samuel L. Jackson'),
#  ('Jeremy Renner', 'Scarlett Johansson'),
#  ('Paul Rudd', 'Scarlett Johansson'),
#  ('Benedict Cumberbatch', 'Scarlett Johansson'),
#  ('Brie Larson', 'Scarlett Johansson'),
#  ('Scarlett Johansson', 'Tom Holland'),
#  ('Karen Gillan', 'Scarlett Johansson'),
#  ('Scarlett Johansson', 'Zoe Saldaña'),
#  ('Evangeline Lilly', 'Scarlett Johansson'),
#  ('Scarlett Johansson', 'Tessa Thompson'),
#  ('Elizabeth Olsen', 'Scarlett Johansson'),
#  ('Dave Bautista', 'Scarlett Johansson'),
#  ('Scarlett Johansson', 'Tilda Swinton'),
#  ('Jon Favreau', 'Scarlett Johansson'),
#  ('Natalie Portman', 'Scarlett Johansson'),
#  ('Marisa Tomei', 'Scarlett Johansson'),
#  ('Angela Bassett', 'Scarlett Johansson'),
#  ('Michelle Pfeiffer', 'Scarlett Johansson'),
#  ('Linda Cardellini', 'Scarlett Johansson'),
#  ('Frank Grillo', 'Scarlett Johansson'),
#  ('Hiroyuki Sanada', 'Scarlett Johansson'),
#  ('Scarlett Johansson', 'Vin Diesel'),
#  ('Bradley Cooper', 'Scarlett Johansson'),
#  ('Josh Brolin', 'Scarlett Johansson'),
#  ('Chris Pratt', 'Scarlett Johansson'),
#  ('Samuel L. Jackson', 'Scarlett Johansson'),
#  ('Jeremy Renner', 'Paul Rudd'),
#  ('Benedict Cumberbatch', 'Jeremy Renner'),
#  ('Brie Larson', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Tom Holland'),
#  ('Jeremy Renner', 'Karen Gillan'),
#  ('Jeremy Renner', 'Zoe Saldaña'),
#  ('Evangeline Lilly', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Tessa Thompson'),
#  ('Elizabeth Olsen', 'Jeremy Renner'),
#  ('Dave Bautista', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Tilda Swinton'),
#  ('Jeremy Renner', 'Jon Favreau'),
#  ('Jeremy Renner', 'Natalie Portman'),
#  ('Jeremy Renner', 'Marisa Tomei'),
#  ('Angela Bassett', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Michelle Pfeiffer'),
#  ('Jeremy Renner', 'Linda Cardellini'),
#  ('Frank Grillo', 'Jeremy Renner'),
#  ('Hiroyuki Sanada', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Vin Diesel'),
#  ('Bradley Cooper', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Josh Brolin'),
#  ('Chris Pratt', 'Jeremy Renner'),
#  ('Jeremy Renner', 'Samuel L. Jackson'),
#  ('Benedict Cumberbatch', 'Paul Rudd'),
#  ('Brie Larson', 'Paul Rudd'),
#  ('Paul Rudd', 'Tom Holland'),
#  ('Karen Gillan', 'Paul Rudd'),
#  ('Paul Rudd', 'Zoe Saldaña'),
#  ('Evangeline Lilly', 'Paul Rudd'),
#  ('Paul Rudd', 'Tessa Thompson'),
#  ('Elizabeth Olsen', 'Paul Rudd'),
#  ('Dave Bautista', 'Paul Rudd'),
#  ('Paul Rudd', 'Tilda Swinton'),
#  ('Jon Favreau', 'Paul Rudd'),
#  ('Natalie Portman', 'Paul Rudd'),
#  ('Marisa Tomei', 'Paul Rudd'),
#  ('Angela Bassett', 'Paul Rudd'),
#  ('Michelle Pfeiffer', 'Paul Rudd'),
#  ('Linda Cardellini', 'Paul Rudd'),
#  ('Frank Grillo', 'Paul Rudd'),
#  ('Hiroyuki Sanada', 'Paul Rudd'),
#  ('Paul Rudd', 'Vin Diesel'),
#  ('Bradley Cooper', 'Paul Rudd'),
#  ('Josh Brolin', 'Paul Rudd'),
#  ('Chris Pratt', 'Paul Rudd'),
#  ('Paul Rudd', 'Samuel L. Jackson'),
#  ('Benedict Cumberbatch', 'Brie Larson'),
#  ('Benedict Cumberbatch', 'Tom Holland'),
#  ('Benedict Cumberbatch', 'Karen Gillan'),
#  ('Benedict Cumberbatch', 'Zoe Saldaña'),
#  ('Benedict Cumberbatch', 'Evangeline Lilly'),
#  ('Benedict Cumberbatch', 'Tessa Thompson'),
#  ('Benedict Cumberbatch', 'Elizabeth Olsen'),
#  ('Benedict Cumberbatch', 'Dave Bautista'),
#  ('Benedict Cumberbatch', 'Tilda Swinton'),
#  ('Benedict Cumberbatch', 'Jon Favreau'),
#  ('Benedict Cumberbatch', 'Natalie Portman'),
#  ('Benedict Cumberbatch', 'Marisa Tomei'),
#  ('Angela Bassett', 'Benedict Cumberbatch'),
#  ('Benedict Cumberbatch', 'Michelle Pfeiffer'),
#  ('Benedict Cumberbatch', 'Linda Cardellini'),
#  ('Benedict Cumberbatch', 'Frank Grillo'),
#  ('Benedict Cumberbatch', 'Hiroyuki Sanada'),
#  ('Benedict Cumberbatch', 'Vin Diesel'),
#  ('Benedict Cumberbatch', 'Bradley Cooper'),
#  ('Benedict Cumberbatch', 'Josh Brolin'),
#  ('Benedict Cumberbatch', 'Chris Pratt'),
#  ('Benedict Cumberbatch', 'Samuel L. Jackson'),
#  ('Brie Larson', 'Tom Holland'),
#  ('Brie Larson', 'Karen Gillan'),
#  ('Brie Larson', 'Zoe Saldaña'),
#  ('Brie Larson', 'Evangeline Lilly'),
#  ('Brie Larson', 'Tessa Thompson'),
#  ('Brie Larson', 'Elizabeth Olsen'),
#  ('Brie Larson', 'Dave Bautista'),
#  ('Brie Larson', 'Tilda Swinton'),
#  ('Brie Larson', 'Jon Favreau'),
#  ('Brie Larson', 'Natalie Portman'),
#  ('Brie Larson', 'Marisa Tomei'),
#  ('Angela Bassett', 'Brie Larson'),
#  ('Brie Larson', 'Michelle Pfeiffer'),
#  ('Brie Larson', 'Linda Cardellini'),
#  ('Brie Larson', 'Frank Grillo'),
#  ('Brie Larson', 'Hiroyuki Sanada'),
#  ('Brie Larson', 'Vin Diesel'),
#  ('Bradley Cooper', 'Brie Larson'),
#  ('Brie Larson', 'Josh Brolin'),
#  ('Brie Larson', 'Chris Pratt'),
#  ('Brie Larson', 'Samuel L. Jackson'),
#  ('Karen Gillan', 'Tom Holland'),
#  ('Tom Holland', 'Zoe Saldaña'),
#  ('Evangeline Lilly', 'Tom Holland'),
#  ('Tessa Thompson', 'Tom Holland'),
#  ('Elizabeth Olsen', 'Tom Holland'),
#  ('Dave Bautista', 'Tom Holland'),
#  ('Tilda Swinton', 'Tom Holland'),
#  ('Jon Favreau', 'Tom Holland'),
#  ('Natalie Portman', 'Tom Holland'),
#  ('Marisa Tomei', 'Tom Holland'),
#  ('Angela Bassett', 'Tom Holland'),
#  ('Michelle Pfeiffer', 'Tom Holland'),
#  ('Linda Cardellini', 'Tom Holland'),
#  ('Frank Grillo', 'Tom Holland'),
#  ('Hiroyuki Sanada', 'Tom Holland'),
#  ('Tom Holland', 'Vin Diesel'),
#  ...]

# %%
def _get_combinations_dict(flattened_combination_tuples):
    combinations_dict = {}
    for flattened_combination_tuple in flattened_combination_tuples:
        if flattened_combination_tuple in combinations_dict:
            combinations_dict[flattened_combination_tuple] +=1
        else:
            combinations_dict[flattened_combination_tuple] =1
    return combinations_dict

# %%
combinations_dict = _get_combinations_dict(flattened_combination_tuples)

# %%
combinations_dict
# Out:
# {('Chloë Grace Moretz', 'Zooey Deschanel'): 1,
#  ('John Goodman', 'Mary Elizabeth Winstead'): 1,
#  ('Bradley Cooper', 'Mary Elizabeth Winstead'): 1,
#  ('Bradley Cooper', 'John Goodman'): 2,
#  ('Danny DeVito', 'Morgan Freeman'): 1,
#  ('Channing Tatum', 'Oscar Isaac'): 1,
#  ('Channing Tatum', 'Chris Pratt'): 3,
#  ('Aubrey Plaza', 'Channing Tatum'): 1,
#  ('Channing Tatum', 'Rosario Dawson'): 3,
#  ('Chris Pratt', 'Oscar Isaac'): 1,
#  ('Aubrey Plaza', 'Oscar Isaac'): 1,
#  ('Oscar Isaac', 'Rosario Dawson'): 1,
#  ('Aubrey Plaza', 'Chris Pratt'): 1,
#  ('Chris Pratt', 'Rosario Dawson'): 1,
#  ('Aubrey Plaza', 'Rosario Dawson'): 1,
#  ('Emile Hirsch', 'Hailee Steinfeld'): 1,
#  ('Gemma Arterton', 'Idris Elba'): 2,
#  ('Kelly Reilly', 'Luke Evans'): 1,
#  ('Chris Hemsworth', 'Elsa Pataky'): 4,
#  ('Chris Hemsworth', 'Taylor Sheridan'): 1,
#  ('Chris Hemsworth', 'William Fichtner'): 1,
#  ('Elsa Pataky', 'Taylor Sheridan'): 1,
#  ('Elsa Pataky', 'William Fichtner'): 1,
#  ('Taylor Sheridan', 'William Fichtner'): 1,
#  ('Benedict Cumberbatch', 'Michael Fassbender'): 1,
#  ('Michael Fassbender', 'Paul Dano'): 1,
#  ('Brad Pitt', 'Michael Fassbender'): 4,
#  ('Benedict Cumberbatch', 'Paul Dano'): 1,
#  ('Benedict Cumberbatch', 'Brad Pitt'): 1,
#  ('Brad Pitt', 'Paul Dano'): 1,
#  ('Andy Serkis', 'Jennifer Garner'): 1,
#  ('Brie Larson', 'Jennifer Garner'): 1,
#  ('Andy Serkis', 'Brie Larson'): 1,
#  ('Gérard Depardieu', 'Sigourney Weaver'): 1,
#  ('Charlize Theron', 'Robert De Niro'): 2,
#  ('Robert De Niro', 'Vera Farmiga'): 1,
#  ('Charlize Theron', 'Vera Farmiga'): 1,
#  ('Leslie Mann', 'Zac Efron'): 1,
#  ('Mark Strong', 'Richard Madden'): 1,
#  ('Benedict Cumberbatch', 'Mark Strong'): 3,
#  ('Benedict Cumberbatch', 'Richard Madden'): 1,
#  ('Charlize Theron', 'James Spader'): 1,
#  ('Cole Hauser', 'Paul Walker'): 1,
#  ('Denzel Washington', 'Mark Wahlberg'): 1,
#  ('Denzel Washington', 'Paula Patton'): 2,
#  ('Denzel Washington', 'James Marsden'): 1,
#  ('Mark Wahlberg', 'Paula Patton'): 1,
#  ('James Marsden', 'Mark Wahlberg'): 1,
#  ('James Marsden', 'Paula Patton'): 1,
#  ('Christina Ricci', 'Kate Hudson'): 1,
#  ('Kate Hudson', 'Paul Rudd'): 1,
#  ('Christina Ricci', 'Paul Rudd'): 1,
#  ('Eve Harlow', 'Woody Harrelson'): 1,
#  ('Kate Bosworth', 'Laurence Fishburne'): 1,
#  ('J.K. Simmons', 'Taylor Kitsch'): 1,
#  ('J.K. Simmons', 'Keith David'): 1,
#  ('Keith David', 'Taylor Kitsch'): 1,
#  ('Brie Larson', 'Channing Tatum'): 2,
#  ('Channing Tatum', 'Dakota Johnson'): 1,
#  ('Channing Tatum', 'Johnny Depp'): 2,
#  ('Brie Larson', 'Dakota Johnson'): 1,
#  ('Brie Larson', 'Johnny Depp'): 1,
#  ('Dakota Johnson', 'Johnny Depp'): 2,
#  ('Channing Tatum', 'Peter Stormare'): 1,
#  ('Brian Cox', 'Rosario Dawson'): 1,
#  ('James Marsden', 'Peyton List'): 1,
#  ('Sandra Bullock', 'Viggo Mortensen'): 1,
#  ('Brendan Gleeson', 'Cillian Murphy'): 4,
#  ('Idris Elba', 'Jeremy Renner'): 3,
#  ('Hailee Steinfeld', 'Kevin Costner'): 1,
#  ('Connie Nielsen', 'Kevin Costner'): 2,
#  ('Amber Heard', 'Kevin Costner'): 2,
#  ('Connie Nielsen', 'Hailee Steinfeld'): 1,
#  ('Amber Heard', 'Hailee Steinfeld'): 1,
#  ('Amber Heard', 'Connie Nielsen'): 3,
#  ('Elle Fanning', 'Susan Sarandon'): 1,
#  ('Gerard Butler', 'Lena Headey'): 1,
#  ('Gerard Butler', 'Michael Fassbender'): 1,
#  ('Lena Headey', 'Michael Fassbender'): 1,
#  ('Kevin Costner', 'Kurt Russell'): 1,
#  ('Courteney Cox', 'Kurt Russell'): 1,
#  ('Christian Slater', 'Kurt Russell'): 2,
#  ('Courteney Cox', 'Kevin Costner'): 1,
#  ('Christian Slater', 'Kevin Costner'): 2,
#  ('Christian Slater', 'Courteney Cox'): 1,
#  ('Eva Green', 'Lena Headey'): 1,
#  ('Jude Law', 'Rachel Weisz'): 4,
#  ('Hiroyuki Sanada', 'Keanu Reeves'): 1,
#  ('Heather Graham', 'Val Kilmer'): 1,
#  ('Adam Sandler', 'Drew Barrymore'): 3,
#  ('Adam Sandler', 'Jackie Sandler'): 20,
#  ('Adam Sandler', 'Katheryn Winnick'): 1,
#  ('Drew Barrymore', 'Jackie Sandler'): 3,
#  ('Drew Barrymore', 'Katheryn Winnick'): 1,
#  ('Jackie Sandler', 'Katheryn Winnick'): 1,
#  ('Daniel Radcliffe', 'Emma Watson'): 10,
#  ('Daniel Radcliffe', 'Rupert Grint'): 10,
#  ('Emma Watson', 'Rupert Grint'): 10,
#  ('Anna Kendrick', 'Bryce Dallas Howard'): 2,
#  ('Ryan Phillippe', 'Salma Hayek'): 1,
#  ('Nicolas Cage', 'Peter Stormare'): 3,
#  ('Nicolas Cage', 'Norman Reedus'): 1,
#  ('Norman Reedus', 'Peter Stormare'): 1,
#  ('Elijah Wood', 'Jennifer Connelly'): 1,
#  ('Gina Gershon', 'Jacqueline Bisset'): 1,
#  ('Hayden Christensen', 'Kate Bosworth'): 1,
#  ('Andrew Garfield', 'Clancy Brown'): 1,
#  ('Kathryn Hahn', 'Mila Kunis'): 2,
#  ('Mila Kunis', 'Susan Sarandon'): 2,
#  ('Ariana Greenblatt', 'Mila Kunis'): 1,
#  ('Kathryn Hahn', 'Susan Sarandon'): 1,
#  ('Ariana Greenblatt', 'Kathryn Hahn'): 1,
#  ('Ariana Greenblatt', 'Susan Sarandon'): 1,
#  ('Jennifer Connelly', 'Russell Crowe'): 3,
#  ('Paul Bettany', 'Russell Crowe'): 2,
#  ('Bryce Dallas Howard', 'Russell Crowe'): 1,
#  ('Jennifer Connelly', 'Paul Bettany'): 3,
#  ('Bryce Dallas Howard', 'Jennifer Connelly'): 1,
#  ('Bryce Dallas Howard', 'Paul Bettany'): 1,
#  ('Ralph Fiennes', 'Tilda Swinton'): 3,
#  ('Dakota Johnson', 'Tilda Swinton'): 2,
#  ('Dakota Johnson', 'Ralph Fiennes'): 1,
#  ('Brooke Shields', 'Drew Barrymore'): 1,
#  ('Andy Serkis', 'Gary Oldman'): 2,
#  ('Michael Fassbender', 'Viggo Mortensen'): 1,
#  ('Sarah Gadon', 'Viggo Mortensen'): 1,
#  ('Michael Fassbender', 'Sarah Gadon'): 1,
#  ('Bruce Willis', 'Frank Grillo'): 4,
#  ('Britt Robertson', 'Dennis Quaid'): 1,
#  ('Gerard Butler', 'Willem Dafoe'): 1,
#  ('Alison Brie', 'Gerard Butler'): 1,
#  ('Alison Brie', 'Willem Dafoe'): 1,
#  ('Kevin Bacon', 'Tom Cruise'): 3,
#  ('Kiefer Sutherland', 'Tom Cruise'): 1,
#  ('Kevin Bacon', 'Kiefer Sutherland'): 3,
#  ('Emmy Rossum', 'Paul Rudd'): 1,
#  ('Bruce Willis', 'Mary Elizabeth Winstead'): 2,
#  ('Bruce Willis', 'Cole Hauser'): 4,
#  ('Cole Hauser', 'Mary Elizabeth Winstead'): 1,
#  ('Helen Hunt', 'Scarlett Johansson'): 1,
#  ('Channing Tatum', 'Shia LaBeouf'): 1,
#  ('Robert Downey Jr.', 'Shia LaBeouf'): 1,
#  ('Rosario Dawson', 'Shia LaBeouf'): 2,
#  ('Channing Tatum', 'Robert Downey Jr.'): 1,
#  ('Robert Downey Jr.', 'Rosario Dawson'): 1,
#  ('Maria Bello', 'Viggo Mortensen'): 1,
#  ('Daniel Craig', 'Kate Winslet'): 2,
#  ('Bill Pullman', 'Tom Hanks'): 2,
#  ('Kate Hudson', 'Peter Dinklage'): 1,
#  ('Aaron Paul', 'Pierce Brosnan'): 1,
#  ('Pierce Brosnan', 'Sam Neill'): 1,
#  ('Pierce Brosnan', 'Rosamund Pike'): 3,
#  ('Enrique Arce', 'Pierce Brosnan'): 1,
#  ('Aaron Paul', 'Sam Neill'): 1,
#  ('Aaron Paul', 'Rosamund Pike'): 1,
#  ('Aaron Paul', 'Enrique Arce'): 1,
#  ('Rosamund Pike', 'Sam Neill'): 1,
#  ('Enrique Arce', 'Sam Neill'): 1,
#  ('Enrique Arce', 'Rosamund Pike'): 1,
#  ('Aimee Garcia', 'Kathryn Hahn'): 1,
#  ('Kathryn Hahn', 'Sarah Shahi'): 1,
#  ('Aimee Garcia', 'Sarah Shahi'): 1,
#  ('John Travolta', 'Scarlett Johansson'): 1,
#  ('Michelle Pfeiffer', 'Sophie Marceau'): 1,
#  ('Charlize Theron', 'Seth MacFarlane'): 1,
#  ('Amanda Seyfried', 'Seth MacFarlane'): 2,
#  ('Giovanni Ribisi', 'Seth MacFarlane'): 3,
#  ('Ewan McGregor', 'Seth MacFarlane'): 1,
#  ('Christopher Lloyd', 'Seth MacFarlane'): 1,
#  ('Ryan Reynolds', 'Seth MacFarlane'): 2,
#  ('Amanda Seyfried', 'Charlize Theron'): 2,
#  ('Charlize Theron', 'Giovanni Ribisi'): 2,
#  ('Charlize Theron', 'Ewan McGregor'): 1,
#  ('Charlize Theron', 'Christopher Lloyd'): 2,
#  ('Charlize Theron', 'Ryan Reynolds'): 1,
#  ('Amanda Seyfried', 'Giovanni Ribisi'): 2,
#  ('Amanda Seyfried', 'Ewan McGregor'): 1,
#  ('Amanda Seyfried', 'Christopher Lloyd'): 1,
#  ('Amanda Seyfried', 'Ryan Reynolds'): 1,
#  ('Ewan McGregor', 'Giovanni Ribisi'): 1,
#  ('Christopher Lloyd', 'Giovanni Ribisi'): 1,
#  ('Giovanni Ribisi', 'Ryan Reynolds'): 2,
#  ('Christopher Lloyd', 'Ewan McGregor'): 1,
#  ('Ewan McGregor', 'Ryan Reynolds'): 1,
#  ('Christopher Lloyd', 'Ryan Reynolds'): 1,
#  ('Clancy Brown', 'Rooney Mara'): 1,
#  ('Milla Jovovich', 'Steve Zahn'): 1,
#  ('Chris Hemsworth', 'Steve Zahn'): 1,
#  ('Chris Hemsworth', 'Milla Jovovich'): 1,
#  ('Clint Eastwood', 'Kevin Costner'): 1,
#  ('Tommy Lee Jones', 'Woody Harrelson'): 4,
#  ('Emily Blunt', 'John Krasinski'): 4,
#  ('Emily Blunt', 'Noah Jupe'): 2,
#  ('John Krasinski', 'Noah Jupe'): 2,
#  ('Cillian Murphy', 'Emily Blunt'): 1,
#  ('Cillian Murphy', 'Noah Jupe'): 1,
#  ('Cillian Murphy', 'Djimon Hounsou'): 1,
#  ('Cillian Murphy', 'John Krasinski'): 1,
#  ('Djimon Hounsou', 'Emily Blunt'): 1,
#  ('Djimon Hounsou', 'Noah Jupe'): 1,
#  ('Djimon Hounsou', 'John Krasinski'): 1,
#  ('Elle Fanning', 'Timothée Chalamet'): 1,
#  ('Jude Law', 'Timothée Chalamet'): 1,
#  ('Elle Fanning', 'Jude Law'): 1,
#  ('Keanu Reeves', 'Robert Downey Jr.'): 1,
#  ('Keanu Reeves', 'Woody Harrelson'): 1,
#  ('Keanu Reeves', 'Winona Ryder'): 4,
#  ('Robert Downey Jr.', 'Woody Harrelson'): 2,
#  ('Robert Downey Jr.', 'Winona Ryder'): 1,
#  ('Winona Ryder', 'Woody Harrelson'): 1,
#  ('Anna Kendrick', 'Linda Cardellini'): 1,
#  ('Bradley Cooper', 'Sam Elliott'): 1,
#  ('Matthew McConaughey', 'Sandra Bullock'): 1,
#  ('Matthew McConaughey', 'Samuel L. Jackson'): 1,
#  ('Donald Sutherland', 'Matthew McConaughey'): 3,
#  ('Kiefer Sutherland', 'Matthew McConaughey'): 1,
#  ('Samuel L. Jackson', 'Sandra Bullock'): 1,
#  ('Donald Sutherland', 'Sandra Bullock'): 1,
#  ('Kiefer Sutherland', 'Sandra Bullock'): 2,
#  ('Donald Sutherland', 'Samuel L. Jackson'): 2,
#  ('Kiefer Sutherland', 'Samuel L. Jackson'): 1,
#  ('Donald Sutherland', 'Kiefer Sutherland'): 2,
#  ('Hassie Harrison', 'Thomas Jane'): 1,
#  ('Haley Joel Osment', 'Jude Law'): 1,
#  ('Brendan Gleeson', 'Haley Joel Osment'): 1,
#  ('Brendan Gleeson', 'Jude Law'): 2,
#  ('Charlie Hunnam', 'Zooey Deschanel'): 1,
#  ('Charlie Hunnam', 'Melanie Lynskey'): 1,
#  ('Melanie Lynskey', 'Zooey Deschanel'): 1,
#  ('Emma Roberts', 'Mimi Rogers'): 1,
#  ('Maria Bello', 'Sigourney Weaver'): 1,
#  ('Dermot Mulroney', 'Sigourney Weaver'): 2,
#  ('Dermot Mulroney', 'Maria Bello'): 1,
#  ('Britt Robertson', 'Emma Roberts'): 2,
#  ('Kevin Hart', 'Paula Patton'): 1,
#  ('Bill Nighy', 'Margot Robbie'): 1,
#  ('Bill Nighy', 'Vanessa Kirby'): 1,
#  ('Margot Robbie', 'Vanessa Kirby'): 1,
#  ('Nicholas Hoult', 'Rachel Weisz'): 2,
#  ('Clint Eastwood', 'Gene Hackman'): 2,
#  ('Jake Gyllenhaal', 'James Marsden'): 1,
#  ('Brad Pitt', 'Tommy Lee Jones'): 1,
#  ('Brad Pitt', 'Liv Tyler'): 2,
#  ('Brad Pitt', 'Donald Sutherland'): 1,
#  ('Liv Tyler', 'Tommy Lee Jones'): 1,
#  ('Donald Sutherland', 'Tommy Lee Jones'): 3,
#  ('Donald Sutherland', 'Liv Tyler'): 2,
#  ('Nicolas Cage', 'Tilda Swinton'): 1,
#  ('Brian Cox', 'Nicolas Cage'): 1,
#  ('Brian Cox', 'Tilda Swinton'): 1,
#  ('Christina Ricci', 'Christopher Lloyd'): 2,
#  ('Emma Roberts', 'Evan Peters'): 1,
#  ('Kristen Stewart', 'Ryan Reynolds'): 1,
#  ('Lucy Liu', 'Samuel L. Jackson'): 4,
#  ('Samuel L. Jackson', 'Zachary Gordon'): 1,
#  ('Lucy Liu', 'Zachary Gordon'): 1,
#  ('Ginger Lynn Allen', 'Lisa Ann'): 1,
#  ('Ariana Marie', 'Ginger Lynn Allen'): 1,
#  ('Ariana Marie', 'Lisa Ann'): 1,
#  ('Mila Kunis', 'Noel Fisher'): 1,
#  ('Noel Fisher', 'Zoe Saldaña'): 1,
#  ('Mila Kunis', 'Zoe Saldaña'): 3,
#  ('Pierce Brosnan', 'Salma Hayek'): 2,
#  ('Pierce Brosnan', 'Woody Harrelson'): 1,
#  ('Salma Hayek', 'Woody Harrelson'): 1,
#  ('Juno Temple', 'Kathryn Hahn'): 1,
#  ('Ian McShane', 'Keith David'): 3,
#  ('Keith David', 'Noel Fisher'): 1,
#  ('Ian McShane', 'Noel Fisher'): 1,
#  ('Oscar Isaac', 'Rachel Weisz'): 2,
#  ('Rami Malek', 'Rooney Mara'): 1,
#  ('Djimon Hounsou', 'Norman Reedus'): 1,
#  ('Mel Gibson', 'Robert Downey Jr.'): 2,
#  ('Gary Oldman', 'Harrison Ford'): 2,
#  ('Adrien Brody', 'Bruce Willis'): 1,
#  ('Keke Palmer', 'Laurence Fishburne'): 1,
#  ('Angela Bassett', 'Keke Palmer'): 1,
#  ('Angela Bassett', 'Laurence Fishburne'): 3,
#  ('Aaron Taylor-Johnson', 'Brendan Gleeson'): 1,
#  ('Viggo Mortensen', 'William Fichtner'): 1,
#  ('Skeet Ulrich', 'William Fichtner'): 2,
#  ('Skeet Ulrich', 'Viggo Mortensen'): 1,
#  ('Kate Hudson', 'Sophie Marceau'): 1,
#  ('Giancarlo Esposito', 'Jean Reno'): 1,
#  ('Angelina Jolie', 'Colin Farrell'): 1,
#  ('Colin Farrell', 'Val Kilmer'): 1,
#  ('Colin Farrell', 'Rosario Dawson'): 1,
#  ('Angelina Jolie', 'Val Kilmer'): 1,
#  ('Angelina Jolie', 'Rosario Dawson'): 1,
#  ('Rosario Dawson', 'Val Kilmer'): 2,
#  ('Jennifer Garner', 'Steve Carell'): 1,
#  ('Jude Law', 'Marisa Tomei'): 1,
#  ('Jude Law', 'Susan Sarandon'): 1,
#  ('Jude Law', 'Katherine LaNasa'): 1,
#  ('Marisa Tomei', 'Susan Sarandon'): 1,
#  ('Katherine LaNasa', 'Marisa Tomei'): 1,
#  ('Katherine LaNasa', 'Susan Sarandon'): 1,
#  ('Charles Dance', 'Rhona Mitra'): 1,
#  ('Anne Hathaway', 'Johnny Depp'): 2,
#  ('Christopher Lloyd', 'Johnny Depp'): 1,
#  ('Anne Hathaway', 'Christopher Lloyd'): 1,
#  ('Sigourney Weaver', 'Winona Ryder'): 1,
#  ('Ron Perlman', 'Sigourney Weaver'): 1,
#  ('Ron Perlman', 'Winona Ryder'): 1,
#  ('Austin Butler', 'J.K. Simmons'): 1,
#  ('Charles Dance', 'Sigourney Weaver'): 2,
#  ('Jennifer Connelly', 'Rosa Salazar'): 1,
#  ('Bradley Cooper', 'Sandra Bullock'): 1,
#  ('Keith David', 'Sandra Bullock'): 2,
#  ('Bradley Cooper', 'Keith David'): 1,
#  ('Kirsten Dunst', 'Ryan Gosling'): 1,
#  ('Emile Hirsch', 'J.K. Simmons'): 1,
#  ("Dylan O'Brien", 'Sadie Sink'): 1,
#  ('Amber Heard', 'Luke Grimes'): 1,
#  ('Jude Law', 'Kate Winslet'): 3,
#  ('Chris Pine', 'Laurence Fishburne'): 1,
#  ('Matt Damon', 'Penélope Cruz'): 1,
#  ('Matt Damon', 'Robert Patrick'): 1,
#  ('Penélope Cruz', 'Robert Patrick'): 1,
#  ('Bill Skarsgård', 'Theo James'): 1,
#  ('Frances McDormand', 'Kate Hudson'): 1,
#  ('Frances McDormand', 'Zooey Deschanel'): 1,
#  ('Frances McDormand', 'Rainn Wilson'): 1,
#  ('Kate Hudson', 'Zooey Deschanel'): 2,
#  ('Kate Hudson', 'Rainn Wilson'): 1,
#  ('Rainn Wilson', 'Zooey Deschanel'): 1,
#  ('Cillian Murphy', 'Jennifer Connelly'): 1,
#  ('Bradley Cooper', 'Emma Stone'): 2,
#  ('Bradley Cooper', 'John Krasinski'): 1,
#  ('Emma Stone', 'John Krasinski'): 1,
#  ('Jennifer Aniston', 'Kevin Hart'): 1,
#  ('Dermot Mulroney', 'Kate Bosworth'): 1,
#  ('Bruce Willis', 'Emile Hirsch'): 2,
#  ('Amanda Seyfried', 'Emile Hirsch'): 1,
#  ('Amber Heard', 'Emile Hirsch'): 1,
#  ('Emile Hirsch', 'Sharon Stone'): 1,
#  ('Emile Hirsch', 'Olivia Wilde'): 2,
#  ('Amanda Seyfried', 'Bruce Willis'): 1,
#  ('Amber Heard', 'Bruce Willis'): 1,
#  ('Bruce Willis', 'Sharon Stone'): 1,
#  ('Bruce Willis', 'Olivia Wilde'): 1,
#  ('Amanda Seyfried', 'Amber Heard'): 1,
#  ('Amanda Seyfried', 'Sharon Stone'): 2,
#  ('Amanda Seyfried', 'Olivia Wilde'): 3,
#  ('Amber Heard', 'Sharon Stone'): 1,
#  ('Amber Heard', 'Olivia Wilde'): 1,
#  ('Olivia Wilde', 'Sharon Stone'): 1,
#  ('Ali Wong', 'Keanu Reeves'): 1,
#  ('Colleen Camp', 'Mackenzie Davis'): 1,
#  ('Devan Long', 'Jake Gyllenhaal'): 1,
#  ('Ewan McGregor', 'Richard Gere'): 1,
#  ('Christopher Walken', 'Rainn Wilson'): 1,
#  ('Christopher Walken', 'Emma Roberts'): 1,
#  ('Emma Roberts', 'Rainn Wilson'): 1,
#  ("Dylan O'Brien", 'Michael Keaton'): 1,
#  ("Dylan O'Brien", 'Taylor Kitsch'): 1,
#  ("Dylan O'Brien", 'Scott Adkins'): 1,
#  ('Michael Keaton', 'Taylor Kitsch'): 1,
#  ('Michael Keaton', 'Scott Adkins'): 1,
#  ('Scott Adkins', 'Taylor Kitsch'): 2,
#  ('Dennis Quaid', 'Willem Dafoe'): 1,
#  ('Denzel Washington', 'Russell Crowe'): 2,
#  ('Josh Brolin', 'Russell Crowe'): 1,
#  ('Idris Elba', 'Russell Crowe'): 2,
#  ('Carla Gugino', 'Russell Crowe'): 3,
#  ('Norman Reedus', 'Russell Crowe'): 1,
#  ('Denzel Washington', 'Josh Brolin'): 1,
#  ('Denzel Washington', 'Idris Elba'): 1,
#  ('Carla Gugino', 'Denzel Washington'): 1,
#  ('Denzel Washington', 'Norman Reedus'): 1,
#  ('Idris Elba', 'Josh Brolin'): 3,
#  ('Carla Gugino', 'Josh Brolin'): 1,
#  ('Josh Brolin', 'Norman Reedus'): 2,
#  ('Carla Gugino', 'Idris Elba'): 2,
#  ('Idris Elba', 'Norman Reedus'): 1,
#  ('Carla Gugino', 'Norman Reedus'): 1,
#  ('Adrien Brody', 'Hayden Christensen'): 1,
#  ('Amy Adams', 'Bradley Cooper'): 1,
#  ('Bradley Cooper', 'Jeremy Renner'): 2,
#  ('Bradley Cooper', 'Colleen Camp'): 2,
#  ('Bradley Cooper', 'Dawn Olivieri'): 1,
#  ('Bradley Cooper', 'Robert De Niro'): 4,
#  ('Amy Adams', 'Jeremy Renner'): 2,
#  ('Amy Adams', 'Colleen Camp'): 1,
#  ('Amy Adams', 'Dawn Olivieri'): 1,
#  ('Amy Adams', 'Robert De Niro'): 1,
#  ('Colleen Camp', 'Jeremy Renner'): 1,
#  ('Dawn Olivieri', 'Jeremy Renner'): 1,
#  ('Jeremy Renner', 'Robert De Niro'): 1,
#  ('Colleen Camp', 'Dawn Olivieri'): 1,
#  ('Colleen Camp', 'Robert De Niro'): 3,
#  ('Dawn Olivieri', 'Robert De Niro'): 1,
#  ('Colin Farrell', 'Timothy Dalton'): 1,
#  ('Ewan McGregor', 'Jennifer Connelly'): 1,
#  ('Dakota Fanning', 'Ewan McGregor'): 1,
#  ('Dakota Fanning', 'Jennifer Connelly'): 1,
#  ('Madison Pettis', 'Zachary Gordon'): 4,
#  ('Denise Richards', 'Tori Black'): 1,
#  ('Bradley Cooper', 'Luke Grimes'): 1,
#  ('Bradley Cooper', 'Clint Eastwood'): 2,
#  ('Clint Eastwood', 'Luke Grimes'): 1,
#  ('John Leguizamo', 'Kristen Stewart'): 1,
#  ('Bill Pullman', 'Kristen Stewart'): 1,
#  ('Bill Pullman', 'John Leguizamo'): 2,
#  ('Dennis Quaid', 'Zachary Levi'): 1,
#  ('Djimon Hounsou', 'Morgan Freeman'): 1,
#  ('Matthew McConaughey', 'Morgan Freeman'): 1,
#  ('Djimon Hounsou', 'Matthew McConaughey'): 2,
#  ('Jennifer Morrison', 'Mckenna Grace'): 1,
#  ('Kate Winslet', 'Saoirse Ronan'): 1,
#  ('Nicolas Cage', 'Samuel L. Jackson'): 3,
#  ('Giancarlo Esposito', 'Samuel L. Jackson'): 3,
#  ('Giancarlo Esposito', 'Nicolas Cage'): 1,
#  ('Margot Robbie', 'Robert De Niro'): 1,
#  ('Anya Taylor-Joy', 'Margot Robbie'): 1,
#  ('Margot Robbie', 'Rami Malek'): 1,
#  ('Margot Robbie', 'Zoe Saldaña'): 1,
#  ('Colleen Camp', 'Margot Robbie'): 1,
#  ('Anya Taylor-Joy', 'Robert De Niro'): 1,
#  ('Rami Malek', 'Robert De Niro'): 1,
#  ('Robert De Niro', 'Zoe Saldaña'): 1,
#  ('Anya Taylor-Joy', 'Rami Malek'): 1,
#  ('Anya Taylor-Joy', 'Zoe Saldaña'): 1,
#  ('Anya Taylor-Joy', 'Colleen Camp'): 1,
#  ('Rami Malek', 'Zoe Saldaña'): 1,
#  ('Colleen Camp', 'Rami Malek'): 1,
#  ('Colleen Camp', 'Zoe Saldaña'): 1,
#  ('Lacey Chabert', 'Ron Perlman'): 1,
#  ('Peter Stormare', 'Willem Dafoe'): 1,
#  ('Christopher Lloyd', 'Kirsten Dunst'): 1,
#  ('Christopher Lloyd', 'Lacey Chabert'): 1,
#  ('Kirsten Dunst', 'Lacey Chabert'): 1,
#  ('Paul Rudd', 'Steve Carell'): 6,
#  ('Meagan Good', 'Steve Carell'): 1,
#  ('Harrison Ford', 'Steve Carell'): 1,
#  ('James Marsden', 'Steve Carell'): 1,
#  ('Kirsten Dunst', 'Steve Carell'): 1,
#  ('Meagan Good', 'Paul Rudd'): 1,
#  ('Harrison Ford', 'Paul Rudd'): 1,
#  ('James Marsden', 'Paul Rudd'): 1,
#  ('Kirsten Dunst', 'Paul Rudd'): 1,
#  ('Harrison Ford', 'Meagan Good'): 1,
#  ('James Marsden', 'Meagan Good'): 1,
#  ('Kirsten Dunst', 'Meagan Good'): 1,
#  ('Harrison Ford', 'James Marsden'): 1,
#  ('Harrison Ford', 'Kirsten Dunst'): 1,
#  ('James Marsden', 'Kirsten Dunst'): 2,
#  ('Kathryn Hahn', 'Paul Rudd'): 5,
#  ('Jack Black', 'Paul Rudd'): 3,
#  ('Kathryn Hahn', 'Steve Carell'): 2,
#  ('Jack Black', 'Steve Carell'): 1,
#  ('Jack Black', 'Kathryn Hahn'): 3,
#  ('Michael Fassbender', 'Sam Neill'): 1,
#  ('Gerard Butler', 'Morgan Freeman'): 3,
#  ('Gerard Butler', 'Lance Reddick'): 1,
#  ('Gerard Butler', 'Piper Perabo'): 1,
#  ('Lance Reddick', 'Morgan Freeman'): 1,
#  ('Morgan Freeman', 'Piper Perabo'): 2,
#  ('Lance Reddick', 'Piper Perabo'): 1,
#  ('Luke Evans', 'Yvonne Strahovski'): 1,
#  ('Ewan McGregor', 'Tom Hanks'): 1,
#  ('Christopher Lloyd', 'Matthew McConaughey'): 1,
#  ('Adrien Brody', 'Christopher Lloyd'): 1,
#  ('Christopher Lloyd', 'Dermot Mulroney'): 1,
#  ('Adrien Brody', 'Matthew McConaughey'): 1,
#  ('Dermot Mulroney', 'Matthew McConaughey'): 1,
#  ('Adrien Brody', 'Dermot Mulroney'): 1,
#  ('Adam Sandler', 'Marisa Tomei'): 1,
#  ('Adam Sandler', 'Woody Harrelson'): 1,
#  ('Adam Sandler', 'Heather Graham'): 1,
#  ('Marisa Tomei', 'Woody Harrelson'): 1,
#  ('Heather Graham', 'Marisa Tomei'): 2,
#  ('Heather Graham', 'Woody Harrelson'): 2,
#  ('Emily Blunt', 'Sylvester Stallone'): 1,
#  ('Danny DeVito', 'Emily Blunt'): 1,
#  ('John Krasinski', 'Sylvester Stallone'): 1,
#  ('Danny DeVito', 'John Krasinski'): 1,
#  ('Danny DeVito', 'Sylvester Stallone'): 2,
#  ('Brian Cox', 'Mark Strong'): 2,
#  ('Indira Varma', 'Mark Strong'): 1,
#  ('Brian Cox', 'Indira Varma'): 1,
#  ('Jude Law', 'Matthew Macfadyen'): 1,
#  ('Aaron Taylor-Johnson', 'Matthew Macfadyen'): 1,
#  ('Bill Skarsgård', 'Matthew Macfadyen'): 1,
#  ('Matthew Macfadyen', 'Sophie Marceau'): 1,
#  ('Matthew Macfadyen', 'Sean Bean'): 1,
#  ('Aaron Taylor-Johnson', 'Jude Law'): 1,
#  ('Bill Skarsgård', 'Jude Law'): 1,
#  ('Jude Law', 'Sophie Marceau'): 1,
#  ('Jude Law', 'Sean Bean'): 1,
#  ('Aaron Taylor-Johnson', 'Bill Skarsgård'): 1,
#  ('Aaron Taylor-Johnson', 'Sophie Marceau'): 1,
#  ('Aaron Taylor-Johnson', 'Sean Bean'): 1,
#  ('Bill Skarsgård', 'Sophie Marceau'): 1,
#  ('Bill Skarsgård', 'Sean Bean'): 1,
#  ('Sean Bean', 'Sophie Marceau'): 1,
#  ('Mckenna Grace', 'Vera Farmiga'): 1,
#  ('Annabelle Wallis', 'Grace Caroline Currey'): 1,
#  ('Mila Kunis', 'Sarah Hyland'): 1,
#  ('Natalie Portman', 'Tessa Thompson'): 3,
#  ('Natalie Portman', 'Oscar Isaac'): 1,
#  ('Oscar Isaac', 'Tessa Thompson'): 1,
#  ('Evangeline Lilly', 'Paul Rudd'): 3,
#  ('Chris Evans', 'Paul Rudd'): 3,
#  ('Chris Evans', 'Evangeline Lilly'): 2,
#  ('Michelle Pfeiffer', 'Paul Rudd'): 3,
#  ('Laurence Fishburne', 'Paul Rudd'): 1,
#  ('Evangeline Lilly', 'Michelle Pfeiffer'): 2,
#  ('Evangeline Lilly', 'Laurence Fishburne'): 1,
#  ('Laurence Fishburne', 'Michelle Pfeiffer'): 1,
#  ('Claire Forlani', 'Ryan Phillippe'): 1,
#  ('Denzel Washington', 'Viola Davis'): 2,
#  ('Gene Hackman', 'Sharon Stone'): 2,
#  ('Sharon Stone', 'Sylvester Stallone'): 2,
#  ('Christopher Walken', 'Sharon Stone'): 1,
#  ('Gene Hackman', 'Sylvester Stallone'): 2,
#  ('Christopher Walken', 'Gene Hackman'): 1,
#  ('Christopher Walken', 'Sylvester Stallone'): 1,
#  ('Al Pacino', 'Dennis Quaid'): 1,
#  ('Aaron Eckhart', 'Al Pacino'): 1,
#  ('Aaron Eckhart', 'Dennis Quaid'): 2,
#  ('Christina Ricci', 'Danny DeVito'): 1,
#  ('Natalie Portman', 'Susan Sarandon'): 2,
#  ('Ashley Johnson', 'Susan Sarandon'): 1,
#  ('Ashley Johnson', 'Natalie Portman'): 1,
#  ('Jack Black', 'Zachary Levi'): 1,
#  ('Glen Powell', 'Jack Black'): 1,
#  ('Glen Powell', 'Zachary Levi'): 1,
#  ('Kevin Bacon', 'Tom Hanks'): 2,
#  ('Amber Heard', 'Jason Momoa'): 3,
#  ('Jason Momoa', 'Willem Dafoe'): 2,
#  ('Jason Momoa', 'Nicole Kidman'): 1,
#  ('Djimon Hounsou', 'Jason Momoa'): 1,
#  ('Amber Heard', 'Willem Dafoe'): 2,
#  ('Amber Heard', 'Nicole Kidman'): 1,
#  ('Amber Heard', 'Djimon Hounsou'): 2,
#  ('Nicole Kidman', 'Willem Dafoe'): 2,
#  ('Djimon Hounsou', 'Willem Dafoe'): 1,
#  ('Djimon Hounsou', 'Nicole Kidman'): 1,
#  ('Richard Gere', 'Susan Sarandon'): 2,
#  ('Rhona Mitra', 'Theo James'): 1,
#  ('Nina Dobrev', 'Samuel L. Jackson'): 2,
#  ('Bryan Cranston', 'John Goodman'): 2,
#  ('Bruce Willis', 'Liv Tyler'): 2,
#  ('Bruce Willis', 'William Fichtner'): 1,
#  ('Bruce Willis', 'Owen Wilson'): 1,
#  ('Bruce Willis', 'Peter Stormare'): 2,
#  ('Bruce Willis', 'Keith David'): 1,
#  ('Liv Tyler', 'William Fichtner'): 1,
#  ('Liv Tyler', 'Owen Wilson'): 1,
#  ('Liv Tyler', 'Peter Stormare'): 1,
#  ('Keith David', 'Liv Tyler'): 1,
#  ('Owen Wilson', 'William Fichtner'): 1,
#  ('Peter Stormare', 'William Fichtner'): 1,
#  ('Keith David', 'William Fichtner'): 3,
#  ('Owen Wilson', 'Peter Stormare'): 1,
#  ('Keith David', 'Owen Wilson'): 2,
#  ('Keith David', 'Peter Stormare'): 1,
#  ('Jean Reno', 'Laurence Fishburne'): 1,
#  ('Jean Reno', 'Skeet Ulrich'): 1,
#  ('Laurence Fishburne', 'Skeet Ulrich'): 1,
#  ('Bridget Fonda', 'Embeth Davidtz'): 1,
#  ('Nicolas Cage', 'Rainn Wilson'): 1,
#  ('Hiroyuki Sanada', 'Nathalie Emmanuel'): 1,
#  ('Dave Bautista', 'Nathalie Emmanuel'): 1,
#  ('Dave Bautista', 'Hiroyuki Sanada'): 3,
#  ('Dave Bautista', 'Ella Purnell'): 1,
#  ('Ella Purnell', 'Hiroyuki Sanada'): 1,
#  ('Jackie Chan', 'Owen Wilson'): 3,
#  ('Colin Farrell', 'Hong Chau'): 1,
#  ('Helen Mirren', 'Jennifer Garner'): 1,
#  ('Bill Nighy', 'James McAvoy'): 1,
#  ('Andy Serkis', 'James McAvoy'): 1,
#  ('Andy Serkis', 'Bill Nighy'): 3,
#  ('Anne Heche', 'Emily Blunt'): 1,
#  ('Jason Bateman', 'Robert De Niro'): 1,
#  ('Harvey Keitel', 'Jason Bateman'): 1,
#  ('Harvey Keitel', 'Robert De Niro'): 6,
#  ('Helen Hunt', 'Skeet Ulrich'): 1,
#  ('Famke Janssen', 'Ron Perlman'): 1,
#  ('Jacqueline Bisset', 'Ron Perlman'): 1,
#  ('Marta Milans', 'Ron Perlman'): 1,
#  ('Famke Janssen', 'Jacqueline Bisset'): 1,
#  ('Famke Janssen', 'Marta Milans'): 1,
#  ('Jacqueline Bisset', 'Marta Milans'): 1,
#  ('Britt Robertson', 'Robert Patrick'): 1,
#  ('Britt Robertson', 'Christian Slater'): 1,
#  ('Christian Slater', 'Robert Patrick'): 1,
#  ('Colin Farrell', 'Salma Hayek'): 1,
#  ('Colin Farrell', 'Donald Sutherland'): 2,
#  ('Donald Sutherland', 'Salma Hayek'): 1,
#  ('Brendan Gleeson', 'Michael Fassbender'): 2,
#  ('Bill Skarsgård', 'Jennifer Morrison'): 1,
#  ('Bruce Willis', 'Luke Grimes'): 1,
#  ('Antonio Banderas', 'Sylvester Stallone'): 3,
#  ('Laurence Fishburne', 'Maria Bello'): 1,
#  ('John Leguizamo', 'Laurence Fishburne'): 3,
#  ('John Leguizamo', 'Maria Bello'): 1,
#  ('Donald Sutherland', 'Nicolas Cage'): 2,
#  ('Bill Nighy', 'Nicolas Cage'): 2,
#  ('Charlize Theron', 'Nicolas Cage'): 1,
#  ('Elle Fanning', 'Nicolas Cage'): 1,
#  ('Bill Nighy', 'Donald Sutherland'): 1,
#  ('Charlize Theron', 'Donald Sutherland'): 2,
#  ('Donald Sutherland', 'Elle Fanning'): 1,
#  ('Bill Nighy', 'Samuel L. Jackson'): 1,
#  ('Bill Nighy', 'Charlize Theron'): 1,
#  ('Bill Nighy', 'Elle Fanning'): 1,
#  ('Charlize Theron', 'Samuel L. Jackson'): 1,
#  ('Elle Fanning', 'Samuel L. Jackson'): 1,
#  ('Charlize Theron', 'Elle Fanning'): 1,
#  ('Dennis Quaid', 'Zac Efron'): 1,
#  ('Clancy Brown', 'Dennis Quaid'): 2,
#  ('Dennis Quaid', 'Heather Graham'): 1,
#  ('Clancy Brown', 'Zac Efron'): 1,
#  ('Heather Graham', 'Zac Efron'): 1,
#  ('Clancy Brown', 'Heather Graham'): 1,
#  ('Oscar Isaac', 'Willem Dafoe'): 2,
#  ('Mads Mikkelsen', 'Willem Dafoe'): 1,
#  ('Mads Mikkelsen', 'Oscar Isaac'): 1,
#  ('Charlize Theron', 'James McAvoy'): 1,
#  ('Charlize Theron', 'John Goodman'): 1,
#  ('Bill Skarsgård', 'Charlize Theron'): 1,
#  ('James McAvoy', 'John Goodman'): 1,
#  ('Bill Skarsgård', 'James McAvoy'): 4,
#  ('Bill Skarsgård', 'John Goodman'): 1,
#  ('James McAvoy', 'Saoirse Ronan'): 2,
#  ('James McAvoy', 'Juno Temple'): 1,
#  ('Benedict Cumberbatch', 'James McAvoy'): 2,
#  ('Juno Temple', 'Saoirse Ronan'): 1,
#  ('Benedict Cumberbatch', 'Saoirse Ronan'): 1,
#  ('Benedict Cumberbatch', 'Juno Temple'): 3,
#  ('Dermot Mulroney', 'Ewan McGregor'): 1,
#  ('Benedict Cumberbatch', 'Ewan McGregor'): 1,
#  ('Benedict Cumberbatch', 'Dermot Mulroney'): 2,
#  ('Danny DeVito', 'John Travolta'): 5,
#  ('John Travolta', 'Tom Cruise'): 2,
#  ('John Travolta', 'Rob Lowe'): 1,
#  ('John Travolta', 'Steven Spielberg'): 1,
#  ('Danny DeVito', 'Tom Cruise'): 1,
#  ('Danny DeVito', 'Rob Lowe'): 1,
#  ('Danny DeVito', 'Steven Spielberg'): 2,
#  ('Rob Lowe', 'Tom Cruise'): 1,
#  ('Steven Spielberg', 'Tom Cruise'): 4,
#  ('Rob Lowe', 'Steven Spielberg'): 1,
#  ('Christian Slater', 'Mimi Rogers'): 1,
#  ('Mimi Rogers', 'Rob Lowe'): 1,
#  ('Christian Slater', 'Rob Lowe'): 1,
#  ('Heather Graham', 'Rob Lowe'): 1,
#  ('Rob Lowe', 'Woody Harrelson'): 1,
#  ('Maria Bello', 'Willem Dafoe'): 1,
#  ('Richard Gere', 'Winona Ryder'): 1,
#  ('Richard Gere', 'Vera Farmiga'): 1,
#  ('J.K. Simmons', 'Richard Gere'): 2,
#  ('Vera Farmiga', 'Winona Ryder'): 1,
#  ('J.K. Simmons', 'Winona Ryder'): 2,
#  ('J.K. Simmons', 'Vera Farmiga'): 3,
#  ('Sam Worthington', 'Zoe Saldaña'): 2,
#  ('Sam Worthington', 'Sigourney Weaver'): 2,
#  ('Sam Worthington', 'Stephen Lang'): 2,
#  ('Giovanni Ribisi', 'Sam Worthington'): 2,
#  ('Sigourney Weaver', 'Zoe Saldaña'): 3,
#  ('Stephen Lang', 'Zoe Saldaña'): 2,
#  ('Giovanni Ribisi', 'Zoe Saldaña'): 2,
#  ('Sigourney Weaver', 'Stephen Lang'): 2,
#  ('Giovanni Ribisi', 'Sigourney Weaver'): 2,
#  ('Giovanni Ribisi', 'Stephen Lang'): 3,
#  ('Kate Winslet', 'Sam Worthington'): 1,
#  ('Kate Winslet', 'Zoe Saldaña'): 1,
#  ('Kate Winslet', 'Sigourney Weaver'): 1,
#  ('Kate Winslet', 'Stephen Lang'): 1,
#  ('Giovanni Ribisi', 'Kate Winslet'): 1,
#  ('Chris Hemsworth', 'Robert Downey Jr.'): 5,
#  ('Chris Evans', 'Robert Downey Jr.'): 7,
#  ('Robert Downey Jr.', 'Scarlett Johansson'): 8,
#  ('Jeremy Renner', 'Robert Downey Jr.'): 5,
#  ('James Spader', 'Robert Downey Jr.'): 1,
#  ('Robert Downey Jr.', 'Samuel L. Jackson'): 7,
#  ('Aaron Taylor-Johnson', 'Robert Downey Jr.'): 1,
#  ('Elizabeth Olsen', 'Robert Downey Jr.'): 4,
#  ('Paul Bettany', 'Robert Downey Jr.'): 7,
#  ('Idris Elba', 'Robert Downey Jr.'): 2,
#  ('Linda Cardellini', 'Robert Downey Jr.'): 2,
#  ('Andy Serkis', 'Robert Downey Jr.'): 1,
#  ('Josh Brolin', 'Robert Downey Jr.'): 3,
#  ('Chris Evans', 'Chris Hemsworth'): 6,
#  ('Chris Hemsworth', 'Scarlett Johansson'): 6,
#  ('Chris Hemsworth', 'Jeremy Renner'): 5,
#  ('Chris Hemsworth', 'James Spader'): 1,
#  ('Chris Hemsworth', 'Samuel L. Jackson'): 6,
#  ('Aaron Taylor-Johnson', 'Chris Hemsworth'): 1,
#  ('Chris Hemsworth', 'Elizabeth Olsen'): 3,
#  ('Chris Hemsworth', 'Paul Bettany'): 3,
#  ('Chris Hemsworth', 'Idris Elba'): 6,
#  ('Chris Hemsworth', 'Linda Cardellini'): 2,
#  ('Andy Serkis', 'Chris Hemsworth'): 1,
#  ('Chris Hemsworth', 'Josh Brolin'): 3,
#  ('Chris Evans', 'Scarlett Johansson'): 10,
#  ('Chris Evans', 'Jeremy Renner'): 5,
#  ('Chris Evans', 'James Spader'): 1,
#  ('Chris Evans', 'Samuel L. Jackson'): 8,
#  ('Aaron Taylor-Johnson', 'Chris Evans'): 2,
#  ('Chris Evans', 'Elizabeth Olsen'): 5,
#  ('Chris Evans', 'Paul Bettany'): 4,
#  ('Chris Evans', 'Idris Elba'): 4,
#  ('Chris Evans', 'Linda Cardellini'): 2,
#  ('Andy Serkis', 'Chris Evans'): 1,
#  ('Chris Evans', 'Josh Brolin'): 3,
#  ('Jeremy Renner', 'Scarlett Johansson'): 6,
#  ('James Spader', 'Scarlett Johansson'): 1,
#  ('Samuel L. Jackson', 'Scarlett Johansson'): 9,
#  ('Aaron Taylor-Johnson', 'Scarlett Johansson'): 2,
#  ('Elizabeth Olsen', 'Scarlett Johansson'): 5,
#  ('Paul Bettany', 'Scarlett Johansson'): 5,
#  ('Idris Elba', 'Scarlett Johansson'): 4,
#  ('Linda Cardellini', 'Scarlett Johansson'): 2,
#  ('Andy Serkis', 'Scarlett Johansson'): 2,
#  ('Josh Brolin', 'Scarlett Johansson'): 5,
#  ('James Spader', 'Jeremy Renner'): 1,
#  ('Jeremy Renner', 'Samuel L. Jackson'): 6,
#  ('Aaron Taylor-Johnson', 'Jeremy Renner'): 1,
#  ('Elizabeth Olsen', 'Jeremy Renner'): 4,
#  ('Jeremy Renner', 'Paul Bettany'): 3,
#  ('Jeremy Renner', 'Linda Cardellini'): 2,
#  ('Andy Serkis', 'Jeremy Renner'): 1,
#  ('Jeremy Renner', 'Josh Brolin'): 2,
#  ('James Spader', 'Samuel L. Jackson'): 1,
#  ('Aaron Taylor-Johnson', 'James Spader'): 1,
#  ('Elizabeth Olsen', 'James Spader'): 1,
#  ('James Spader', 'Paul Bettany'): 1,
#  ('Idris Elba', 'James Spader'): 1,
#  ('James Spader', 'Linda Cardellini'): 1,
#  ('Andy Serkis', 'James Spader'): 1,
#  ('James Spader', 'Josh Brolin'): 1,
#  ('Aaron Taylor-Johnson', 'Samuel L. Jackson'): 2,
#  ('Elizabeth Olsen', 'Samuel L. Jackson'): 5,
#  ('Paul Bettany', 'Samuel L. Jackson'): 5,
#  ('Idris Elba', 'Samuel L. Jackson'): 4,
#  ('Linda Cardellini', 'Samuel L. Jackson'): 2,
#  ('Andy Serkis', 'Samuel L. Jackson'): 2,
#  ('Josh Brolin', 'Samuel L. Jackson'): 4,
#  ('Aaron Taylor-Johnson', 'Elizabeth Olsen'): 3,
#  ('Aaron Taylor-Johnson', 'Paul Bettany'): 1,
#  ('Aaron Taylor-Johnson', 'Idris Elba'): 1,
#  ('Aaron Taylor-Johnson', 'Linda Cardellini'): 1,
#  ('Aaron Taylor-Johnson', 'Andy Serkis'): 1,
#  ('Aaron Taylor-Johnson', 'Josh Brolin'): 1,
#  ('Elizabeth Olsen', 'Paul Bettany'): 3,
#  ('Elizabeth Olsen', 'Idris Elba'): 2,
#  ('Elizabeth Olsen', 'Linda Cardellini'): 2,
#  ('Andy Serkis', 'Elizabeth Olsen'): 1,
#  ('Elizabeth Olsen', 'Josh Brolin'): 4,
#  ('Idris Elba', 'Paul Bettany'): 2,
#  ('Linda Cardellini', 'Paul Bettany'): 1,
#  ('Andy Serkis', 'Paul Bettany'): 2,
#  ('Josh Brolin', 'Paul Bettany'): 2,
#  ('Idris Elba', 'Linda Cardellini'): 1,
#  ('Andy Serkis', 'Idris Elba'): 1,
#  ('Andy Serkis', 'Linda Cardellini'): 1,
#  ('Josh Brolin', 'Linda Cardellini'): 2,
#  ('Andy Serkis', 'Josh Brolin'): 1,
#  ('Paul Rudd', 'Robert Downey Jr.'): 2,
#  ('Benedict Cumberbatch', 'Robert Downey Jr.'): 2,
#  ('Brie Larson', 'Robert Downey Jr.'): 1,
#  ('Robert Downey Jr.', 'Tom Holland'): 5,
#  ('Karen Gillan', 'Robert Downey Jr.'): 2,
#  ('Robert Downey Jr.', 'Zoe Saldaña'): 2,
#  ('Evangeline Lilly', 'Robert Downey Jr.'): 1,
#  ('Robert Downey Jr.', 'Tessa Thompson'): 1,
#  ('Dave Bautista', 'Robert Downey Jr.'): 2,
#  ('Robert Downey Jr.', 'Tilda Swinton'): 1,
#  ('Jon Favreau', 'Robert Downey Jr.'): 7,
#  ('Natalie Portman', 'Robert Downey Jr.'): 1,
#  ('Marisa Tomei', 'Robert Downey Jr.'): 5,
#  ('Angela Bassett', 'Robert Downey Jr.'): 1,
#  ('Michelle Pfeiffer', 'Robert Downey Jr.'): 1,
#  ('Frank Grillo', 'Robert Downey Jr.'): 2,
#  ('Hiroyuki Sanada', 'Robert Downey Jr.'): 1,
#  ('Robert Downey Jr.', 'Vin Diesel'): 3,
#  ('Bradley Cooper', 'Robert Downey Jr.'): 2,
#  ('Chris Pratt', 'Robert Downey Jr.'): 3,
#  ('Benedict Cumberbatch', 'Chris Evans'): 2,
#  ('Brie Larson', 'Chris Evans'): 3,
#  ('Chris Evans', 'Tom Holland'): 4,
#  ('Chris Evans', 'Karen Gillan'): 2,
#  ('Chris Evans', 'Zoe Saldaña'): 3,
#  ('Chris Evans', 'Tessa Thompson'): 1,
#  ('Chris Evans', 'Dave Bautista'): 2,
#  ('Chris Evans', 'Tilda Swinton'): 1,
#  ('Chris Evans', 'Jon Favreau'): 3,
#  ('Chris Evans', 'Natalie Portman'): 2,
#  ('Chris Evans', 'Marisa Tomei'): 3,
#  ('Angela Bassett', 'Chris Evans'): 1,
#  ('Chris Evans', 'Michelle Pfeiffer'): 1,
#  ('Chris Evans', 'Frank Grillo'): 3,
#  ('Chris Evans', 'Hiroyuki Sanada'): 2,
#  ('Chris Evans', 'Vin Diesel'): 3,
#  ('Bradley Cooper', 'Chris Evans'): 2,
#  ('Chris Evans', 'Chris Pratt'): 4,
#  ('Chris Hemsworth', 'Paul Rudd'): 1,
#  ('Benedict Cumberbatch', 'Chris Hemsworth'): 4,
#  ('Brie Larson', 'Chris Hemsworth'): 1,
#  ('Chris Hemsworth', 'Tom Holland'): 3,
#  ('Chris Hemsworth', 'Karen Gillan'): 3,
#  ('Chris Hemsworth', 'Zoe Saldaña'): 3,
#  ('Chris Hemsworth', 'Evangeline Lilly'): 1,
#  ('Chris Hemsworth', 'Tessa Thompson'): 4,
#  ('Chris Hemsworth', 'Dave Bautista'): 3,
#  ('Chris Hemsworth', 'Tilda Swinton'): 2,
#  ('Chris Hemsworth', 'Jon Favreau'): 2,
#  ('Chris Hemsworth', 'Natalie Portman'): 4,
#  ('Chris Hemsworth', 'Marisa Tomei'): 1,
#  ('Angela Bassett', 'Chris Hemsworth'): 1,
#  ('Chris Hemsworth', 'Michelle Pfeiffer'): 1,
#  ('Chris Hemsworth', 'Frank Grillo'): 1,
#  ('Chris Hemsworth', 'Hiroyuki Sanada'): 1,
#  ('Chris Hemsworth', 'Vin Diesel'): 4,
#  ('Bradley Cooper', 'Chris Hemsworth'): 3,
#  ('Chris Hemsworth', 'Chris Pratt'): 4,
#  ('Paul Rudd', 'Scarlett Johansson'): 2,
#  ('Benedict Cumberbatch', 'Scarlett Johansson'): 4,
#  ('Brie Larson', 'Scarlett Johansson'): 3,
#  ('Scarlett Johansson', 'Tom Holland'): 3,
#  ('Karen Gillan', 'Scarlett Johansson'): 2,
#  ('Scarlett Johansson', 'Zoe Saldaña'): 2,
#  ('Evangeline Lilly', 'Scarlett Johansson'): 1,
#  ('Scarlett Johansson', 'Tessa Thompson'): 2,
#  ('Dave Bautista', 'Scarlett Johansson'): 2,
#  ('Scarlett Johansson', 'Tilda Swinton'): 3,
#  ('Jon Favreau', 'Scarlett Johansson'): 5,
#  ('Natalie Portman', 'Scarlett Johansson'): 2,
#  ('Marisa Tomei', 'Scarlett Johansson'): 2,
#  ('Angela Bassett', 'Scarlett Johansson'): 1,
#  ('Michelle Pfeiffer', 'Scarlett Johansson'): 1,
#  ('Frank Grillo', 'Scarlett Johansson'): 3,
#  ('Hiroyuki Sanada', 'Scarlett Johansson'): 1,
#  ('Scarlett Johansson', 'Vin Diesel'): 3,
#  ('Bradley Cooper', 'Scarlett Johansson'): 3,
#  ('Chris Pratt', 'Scarlett Johansson'): 4,
#  ('Jeremy Renner', 'Paul Rudd'): 2,
#  ('Benedict Cumberbatch', 'Jeremy Renner'): 1,
#  ('Brie Larson', 'Jeremy Renner'): 1,
#  ('Jeremy Renner', 'Tom Holland'): 2,
#  ('Jeremy Renner', 'Karen Gillan'): 1,
#  ('Jeremy Renner', 'Zoe Saldaña'): 1,
#  ('Evangeline Lilly', 'Jeremy Renner'): 2,
#  ('Jeremy Renner', 'Tessa Thompson'): 1,
#  ('Dave Bautista', 'Jeremy Renner'): 1,
#  ('Jeremy Renner', 'Tilda Swinton'): 1,
#  ('Jeremy Renner', 'Jon Favreau'): 2,
#  ('Jeremy Renner', 'Natalie Portman'): 2,
#  ('Jeremy Renner', 'Marisa Tomei'): 2,
#  ('Angela Bassett', 'Jeremy Renner'): 1,
#  ('Jeremy Renner', 'Michelle Pfeiffer'): 1,
#  ('Frank Grillo', 'Jeremy Renner'): 2,
#  ('Hiroyuki Sanada', 'Jeremy Renner'): 1,
#  ('Jeremy Renner', 'Vin Diesel'): 2,
#  ('Chris Pratt', 'Jeremy Renner'): 2,
#  ('Benedict Cumberbatch', 'Paul Rudd'): 2,
#  ('Brie Larson', 'Paul Rudd'): 2,
#  ('Paul Rudd', 'Tom Holland'): 2,
#  ('Karen Gillan', 'Paul Rudd'): 1,
#  ('Paul Rudd', 'Zoe Saldaña'): 1,
#  ('Paul Rudd', 'Tessa Thompson'): 2,
#  ('Elizabeth Olsen', 'Paul Rudd'): 2,
#  ('Dave Bautista', 'Paul Rudd'): 1,
#  ('Paul Rudd', 'Tilda Swinton'): 1,
#  ('Jon Favreau', 'Paul Rudd'): 2,
#  ('Natalie Portman', 'Paul Rudd'): 1,
#  ('Marisa Tomei', 'Paul Rudd'): 2,
#  ('Angela Bassett', 'Paul Rudd'): 1,
#  ('Linda Cardellini', 'Paul Rudd'): 1,
#  ('Frank Grillo', 'Paul Rudd'): 2,
#  ('Hiroyuki Sanada', 'Paul Rudd'): 2,
#  ('Paul Rudd', 'Vin Diesel'): 1,
#  ('Bradley Cooper', 'Paul Rudd'): 2,
#  ('Josh Brolin', 'Paul Rudd'): 1,
#  ('Chris Pratt', 'Paul Rudd'): 1,
#  ('Paul Rudd', 'Samuel L. Jackson'): 1,
#  ('Benedict Cumberbatch', 'Brie Larson'): 2,
#  ('Benedict Cumberbatch', 'Tom Holland'): 4,
#  ('Benedict Cumberbatch', 'Karen Gillan'): 2,
#  ('Benedict Cumberbatch', 'Zoe Saldaña'): 3,
#  ('Benedict Cumberbatch', 'Evangeline Lilly'): 3,
#  ('Benedict Cumberbatch', 'Tessa Thompson'): 3,
#  ('Benedict Cumberbatch', 'Elizabeth Olsen'): 3,
#  ('Benedict Cumberbatch', 'Dave Bautista'): 2,
#  ('Benedict Cumberbatch', 'Tilda Swinton'): 2,
#  ('Benedict Cumberbatch', 'Jon Favreau'): 2,
#  ('Benedict Cumberbatch', 'Natalie Portman'): 2,
#  ('Benedict Cumberbatch', 'Marisa Tomei'): 2,
#  ('Angela Bassett', 'Benedict Cumberbatch'): 1,
#  ('Benedict Cumberbatch', 'Michelle Pfeiffer'): 1,
#  ('Benedict Cumberbatch', 'Linda Cardellini'): 1,
#  ('Benedict Cumberbatch', 'Frank Grillo'): 1,
#  ('Benedict Cumberbatch', 'Hiroyuki Sanada'): 1,
#  ('Benedict Cumberbatch', 'Vin Diesel'): 2,
#  ('Benedict Cumberbatch', 'Bradley Cooper'): 2,
#  ('Benedict Cumberbatch', 'Josh Brolin'): 2,
#  ('Benedict Cumberbatch', 'Chris Pratt'): 2,
#  ('Benedict Cumberbatch', 'Samuel L. Jackson'): 2,
#  ('Brie Larson', 'Tom Holland'): 1,
#  ('Brie Larson', 'Karen Gillan'): 1,
#  ('Brie Larson', 'Zoe Saldaña'): 1,
#  ('Brie Larson', 'Evangeline Lilly'): 1,
#  ('Brie Larson', 'Tessa Thompson'): 2,
#  ('Brie Larson', 'Elizabeth Olsen'): 1,
#  ('Brie Larson', 'Dave Bautista'): 1,
#  ('Brie Larson', 'Tilda Swinton'): 2,
#  ('Brie Larson', 'Jon Favreau'): 1,
#  ('Brie Larson', 'Natalie Portman'): 1,
#  ('Brie Larson', 'Marisa Tomei'): 2,
#  ('Angela Bassett', 'Brie Larson'): 1,
#  ('Brie Larson', 'Michelle Pfeiffer'): 1,
#  ('Brie Larson', 'Linda Cardellini'): 1,
#  ('Brie Larson', 'Frank Grillo'): 1,
#  ('Brie Larson', 'Hiroyuki Sanada'): 1,
#  ('Brie Larson', 'Vin Diesel'): 1,
#  ('Bradley Cooper', 'Brie Larson'): 1,
#  ('Brie Larson', 'Josh Brolin'): 1,
#  ('Brie Larson', 'Chris Pratt'): 1,
#  ('Brie Larson', 'Samuel L. Jackson'): 4,
#  ('Karen Gillan', 'Tom Holland'): 3,
#  ('Tom Holland', 'Zoe Saldaña'): 2,
#  ('Evangeline Lilly', 'Tom Holland'): 1,
#  ('Tessa Thompson', 'Tom Holland'): 1,
#  ('Elizabeth Olsen', 'Tom Holland'): 3,
#  ('Dave Bautista', 'Tom Holland'): 2,
#  ('Tilda Swinton', 'Tom Holland'): 1,
#  ('Jon Favreau', 'Tom Holland'): 4,
#  ('Natalie Portman', 'Tom Holland'): 1,
#  ('Marisa Tomei', 'Tom Holland'): 5,
#  ('Angela Bassett', 'Tom Holland'): 1,
#  ('Michelle Pfeiffer', 'Tom Holland'): 1,
#  ('Linda Cardellini', 'Tom Holland'): 1,
#  ('Frank Grillo', 'Tom Holland'): 2,
#  ('Hiroyuki Sanada', 'Tom Holland'): 1,
#  ('Tom Holland', 'Vin Diesel'): 2,
#  ('Bradley Cooper', 'Tom Holland'): 2,
#  ('Josh Brolin', 'Tom Holland'): 2,
#  ('Chris Pratt', 'Tom Holland'): 3,
#  ('Samuel L. Jackson', 'Tom Holland'): 3,
#  ('Karen Gillan', 'Zoe Saldaña'): 4,
#  ('Evangeline Lilly', 'Karen Gillan'): 1,
#  ('Karen Gillan', 'Tessa Thompson'): 2,
#  ('Elizabeth Olsen', 'Karen Gillan'): 2,
#  ('Dave Bautista', 'Karen Gillan'): 7,
#  ('Karen Gillan', 'Tilda Swinton'): 1,
#  ('Jon Favreau', 'Karen Gillan'): 1,
#  ('Karen Gillan', 'Natalie Portman'): 2,
#  ('Karen Gillan', 'Marisa Tomei'): 2,
#  ('Angela Bassett', 'Karen Gillan'): 2,
#  ('Karen Gillan', 'Michelle Pfeiffer'): 1,
#  ('Karen Gillan', 'Linda Cardellini'): 1,
#  ('Frank Grillo', 'Karen Gillan'): 1,
#  ('Hiroyuki Sanada', 'Karen Gillan'): 1,
#  ('Karen Gillan', 'Vin Diesel'): 6,
#  ('Bradley Cooper', 'Karen Gillan'): 6,
#  ('Josh Brolin', 'Karen Gillan'): 3,
#  ('Chris Pratt', 'Karen Gillan'): 6,
#  ('Karen Gillan', 'Samuel L. Jackson'): 2,
#  ('Evangeline Lilly', 'Zoe Saldaña'): 1,
#  ('Tessa Thompson', 'Zoe Saldaña'): 1,
#  ('Elizabeth Olsen', 'Zoe Saldaña'): 2,
#  ('Dave Bautista', 'Zoe Saldaña'): 4,
#  ('Tilda Swinton', 'Zoe Saldaña'): 1,
#  ('Jon Favreau', 'Zoe Saldaña'): 1,
#  ('Natalie Portman', 'Zoe Saldaña'): 1,
#  ('Marisa Tomei', 'Zoe Saldaña'): 1,
#  ('Angela Bassett', 'Zoe Saldaña'): 1,
#  ('Michelle Pfeiffer', 'Zoe Saldaña'): 1,
#  ('Linda Cardellini', 'Zoe Saldaña'): 1,
#  ('Frank Grillo', 'Zoe Saldaña'): 1,
#  ('Hiroyuki Sanada', 'Zoe Saldaña'): 1,
#  ('Vin Diesel', 'Zoe Saldaña'): 4,
#  ('Bradley Cooper', 'Zoe Saldaña'): 5,
#  ('Josh Brolin', 'Zoe Saldaña'): 3,
#  ('Chris Pratt', 'Zoe Saldaña'): 4,
#  ('Samuel L. Jackson', 'Zoe Saldaña'): 2,
#  ('Evangeline Lilly', 'Tessa Thompson'): 1,
#  ('Elizabeth Olsen', 'Evangeline Lilly'): 1,
#  ('Dave Bautista', 'Evangeline Lilly'): 1,
#  ('Evangeline Lilly', 'Tilda Swinton'): 1,
#  ('Evangeline Lilly', 'Jon Favreau'): 1,
#  ('Evangeline Lilly', 'Natalie Portman'): 1,
#  ('Evangeline Lilly', 'Marisa Tomei'): 1,
#  ('Angela Bassett', 'Evangeline Lilly'): 1,
#  ('Evangeline Lilly', 'Linda Cardellini'): 1,
#  ('Evangeline Lilly', 'Frank Grillo'): 1,
#  ('Evangeline Lilly', 'Hiroyuki Sanada'): 1,
#  ('Evangeline Lilly', 'Vin Diesel'): 1,
#  ('Bradley Cooper', 'Evangeline Lilly'): 1,
#  ('Evangeline Lilly', 'Josh Brolin'): 1,
#  ('Chris Pratt', 'Evangeline Lilly'): 1,
#  ('Evangeline Lilly', 'Samuel L. Jackson'): 1,
#  ('Elizabeth Olsen', 'Tessa Thompson'): 1,
#  ('Dave Bautista', 'Tessa Thompson'): 2,
#  ('Tessa Thompson', 'Tilda Swinton'): 1,
#  ('Jon Favreau', 'Tessa Thompson'): 1,
#  ('Marisa Tomei', 'Tessa Thompson'): 1,
#  ...}

# %%
def _get_d3_dataframe(combinations_dict):
    df_d3 = pd.DataFrame(combinations_dict.items())
    df_d3 = pd.concat([df_d3[0].apply(pd.Series),df_d3[1]],axis=1)
    df_d3.columns =['source','target','weight']
    return df_d3

# %%
df_d3 = _get_d3_dataframe(combinations_dict)

# %%
def _get_edge_frequency_dict(df_d3):
    x = df_d3.source.value_counts().to_dict()
    y = df_d3.target.value_counts().to_dict()
    result = {key: x.get(key, 0) + y.get(key, 0)for key in x}
    return result

# %%
edge_frequency_dict = _get_edge_frequency_dict(df_d3)

# %%
edge_frequency_dict
# Out:
# {'Bruce Willis': 134,
#  'Brad Pitt': 107,
#  'Bradley Cooper': 94,
#  'Benedict Cumberbatch': 91,
#  'Charlize Theron': 91,
#  'Chris Evans': 90,
#  'Channing Tatum': 87,
#  'Angela Bassett': 75,
#  'J.K. Simmons': 116,
#  'Benicio del Toro': 79,
#  'Chris Pratt': 94,
#  'Djimon Hounsou': 86,
#  'Brie Larson': 77,
#  'Christopher Walken': 80,
#  'Antonio Banderas': 69,
#  'Chris Hemsworth': 79,
#  'Dave Bautista': 77,
#  'Amy Adams': 63,
#  'Brian Cox': 68,
#  'Angelina Jolie': 60,
#  'Aaron Taylor-Johnson': 58,
#  'Idris Elba': 85,
#  'Brendan Gleeson': 63,
#  'Bill Nighy': 59,
#  'Bryan Cranston': 66,
#  'Anne Hathaway': 58,
#  'Josh Brolin': 105,
#  'Danny DeVito': 70,
#  'Gary Oldman': 85,
#  'Christian Slater': 62,
#  'Aaron Eckhart': 53,
#  'Drew Barrymore': 69,
#  'Adam Sandler': 53,
#  'Elijah Wood': 67,
#  'Colin Farrell': 65,
#  'Chloë Grace Moretz': 56,
#  'Elizabeth Banks': 72,
#  'Denzel Washington': 67,
#  'Ewan McGregor': 71,
#  'Andy Serkis': 52,
#  'Adrien Brody': 49,
#  'Al Pacino': 51,
#  'Clancy Brown': 61,
#  'Jeff Goldblum': 78,
#  'Frank Grillo': 69,
#  'Amanda Seyfried': 50,
#  'James Marsden': 67,
#  'Jon Favreau': 96,
#  'John Goodman': 85,
#  'Carla Gugino': 56,
#  'Anna Kendrick': 46,
#  'Donald Sutherland': 63,
#  'Dennis Quaid': 63,
#  'Matt Damon': 107,
#  'Jack Black': 69,
#  'Bill Pullman': 45,
#  'Daniel Craig': 54,
#  'Amber Heard': 45,
#  'Emma Stone': 54,
#  'Keith David': 76,
#  'Charles Dance': 48,
#  'Harrison Ford': 60,
#  'Jude Law': 72,
#  'Frances McDormand': 54,
#  'Famke Janssen': 50,
#  'Hiroyuki Sanada': 61,
#  'Jeremy Renner': 71,
#  'John Leguizamo': 73,
#  'Colleen Camp': 50,
#  'Harvey Keitel': 55,
#  'Giovanni Ribisi': 60,
#  'Chris Pine': 47,
#  'Helen Mirren': 60,
#  'Kurt Russell': 84,
#  'Gal Gadot': 50,
#  'Adam Driver': 38,
#  'Johnny Depp': 81,
#  'Gene Hackman': 48,
#  'Dakota Fanning': 48,
#  'Cillian Murphy': 46,
#  'Jason Statham': 59,
#  'Jason Bateman': 58,
#  'Gerard Butler': 54,
#  'Alison Brie': 35,
#  'Elizabeth Olsen': 53,
#  'Giancarlo Esposito': 49,
#  'Keanu Reeves': 80,
#  'Jon Bernthal': 52,
#  'Laurence Fishburne': 87,
#  'Jake Gyllenhaal': 56,
#  'Christina Ricci': 45,
#  'Mark Strong': 87,
#  'Emile Hirsch': 50,
#  'James McAvoy': 59,
#  'Halle Berry': 51,
#  'Ariana Greenblatt': 36,
#  'Christopher Lloyd': 43,
#  'Heather Graham': 50,
#  'Andrew Garfield': 34,
#  'Karen Gillan': 66,
#  'Dermot Mulroney': 43,
#  'Kevin Bacon': 73,
#  'Natalie Portman': 90,
#  'Connie Nielsen': 44,
#  'Matthew McConaughey': 89,
#  'Bob Odenkirk': 35,
#  'Aubrey Plaza': 35,
#  'Leonardo DiCaprio': 78,
#  'Aaron Paul': 31,
#  'Marisa Tomei': 83,
#  'John Travolta': 57,
#  'Mark Wahlberg': 72,
#  'Anne Heche': 32,
#  'Elle Fanning': 45,
#  'Frances Fisher': 39,
#  'Kirsten Dunst': 66,
#  'Charlie Hunnam': 33,
#  'Ashley Johnson': 30,
#  'Kate Winslet': 64,
#  'Ian McShane': 45,
#  'Billy Zane': 31,
#  'Morgan Freeman': 95,
#  'Charlie Day': 35,
#  'Glen Powell': 39,
#  'Henry Cavill': 37,
#  'Awkwafina': 29,
#  'Annabelle Wallis': 29,
#  'Cole Hauser': 30,
#  'Linda Cardellini': 55,
#  'Evangeline Lilly': 36,
#  'Juno Temple': 55,
#  'Angourie Rice': 27,
#  'John Cena': 44,
#  'Kevin Hart': 61,
#  'Jennifer Aniston': 56,
#  'Clint Eastwood': 36,
#  'Ralph Fiennes': 98,
#  'Emily Blunt': 44,
#  'Anya Taylor-Joy': 25,
#  'Bill Skarsgård': 27,
#  'Kiefer Sutherland': 50,
#  'Joey King': 39,
#  'Hailee Steinfeld': 42,
#  'Jennifer Connelly': 47,
#  'Owen Wilson': 76,
#  'Robert De Niro': 104,
#  'Jennifer Garner': 46,
#  'Bridget Fonda': 29,
#  'Robert Downey Jr.': 105,
#  'John Krasinski': 49,
#  'Alan Ruck': 24,
#  'Ray Liotta': 85,
#  'Samuel L. Jackson': 149,
#  'Paul Rudd': 93,
#  'Emma Watson': 29,
#  'Bryce Dallas Howard': 27,
#  'Bonnie Hunt': 26,
#  'Margot Robbie': 47,
#  'Kate Hudson': 48,
#  'Daniel Radcliffe': 31,
#  'Elsa Pataky': 30,
#  "Beverly D'Angelo": 23,
#  'Michelle Pfeiffer': 70,
#  'Emma Roberts': 33,
#  'Britt Robertson': 25,
#  'Nicolas Cage': 68,
#  'Lucy Liu': 61,
#  'Jason Momoa': 39,
#  'James Spader': 35,
#  'Hayden Christensen': 37,
#  'Paul Bettany': 65,
#  'Maria Bello': 46,
#  'Carrie-Anne Moss': 22,
#  'Luke Evans': 51,
#  'Liv Tyler': 44,
#  'Michael Keaton': 54,
#  'Michelle Monaghan': 53,
#  'Nicole Kidman': 77,
#  'Alexander Ludwig': 22,
#  'Embeth Davidtz': 32,
#  'Dakota Johnson': 30,
#  'Daisy Ridley': 24,
#  'Kathryn Hahn': 46,
#  'Gemma Arterton': 29,
#  'Ali Wong': 21,
#  'Kate Beckinsale': 43,
#  'Mila Kunis': 43,
#  'Helen Hunt': 29,
#  'Michael Fassbender': 55,
#  'Olivia Wilde': 69,
#  'Evan Peters': 28,
#  'Jackie Sandler': 31,
#  "Dylan O'Brien": 22,
#  'Ron Perlman': 73,
#  'Ana de Armas': 19,
#  'Kristen Stewart': 46,
#  'Eva Green': 29,
#  'Kate Bosworth': 42,
#  'Milla Jovovich': 42,
#  'Gina Gershon': 25,
#  'Jim Caviezel': 30,
#  'Jenny Slate': 38,
#  'Florence Pugh': 22,
#  'Melanie Lynskey': 38,
#  'Alexandra Daddario': 17,
#  'Russell Crowe': 74,
#  'Lance Reddick': 32,
#  'Denise Richards': 23,
#  'Aimee Garcia': 17,
#  'Peter Dinklage': 78,
#  'Courteney Cox': 24,
#  'Jean Reno': 26,
#  'Meagan Good': 41,
#  'Claire Forlani': 21,
#  'Lena Headey': 44,
#  'Peter Stormare': 71,
#  'Josh Hartnett': 30,
#  'Jeffrey Dean Morgan': 35,
#  'Christian Convery': 16,
#  'Oscar Isaac': 64,
#  'Bailee Madison': 16,
#  'Rosario Dawson': 76,
#  'Kevin Costner': 51,
#  'Jennifer Morrison': 23,
#  'Nicholas Hoult': 51,
#  'Matthew Macfadyen': 33,
#  'Mel Gibson': 50,
#  'Finn Wolfhard': 21,
#  'Pierce Brosnan': 48,
#  'Martin Lawrence': 28,
#  'Austin Butler': 16,
#  'Gillian Jacobs': 20,
#  'Kaya Scodelario': 20,
#  'Mads Mikkelsen': 28,
#  'Leslie Mann': 47,
#  'Mckenna Grace': 33,
#  'Penélope Cruz': 44,
#  'Mimi Rogers': 30,
#  'Jodie Foster': 23,
#  'Haley Joel Osment': 19,
#  'Scarlett Johansson': 104,
#  'Rachel Weisz': 53,
#  'Sandra Bullock': 53,
#  'Ryan Reynolds': 79,
#  'Ryan Phillippe': 49,
#  'Emilia Clarke': 14,
#  'Sam Neill': 54,
#  'Robert Patrick': 67,
#  'Gérard Depardieu': 12,
#  'Matthew Lillard': 29,
#  'Noel Gugliemi': 46,
#  'Paul Walker': 33,
#  'Donnie Yen': 11,
#  'Alexis Texas': 10,
#  'Emmy Rossum': 11,
#  'Rebecca Ferguson': 30,
#  'Dina Meyer': 16,
#  'Lily James': 19,
#  'Nathan Fillion': 50,
#  'Nathalie Emmanuel': 27,
#  'Jackie Chan': 22,
#  'Jack Dylan Grazer': 16,
#  'Michelle Yeoh': 46,
#  'Alan Ritchson': 10,
#  'Ella Purnell': 16,
#  'Kelly Reilly': 17,
#  'Mary Elizabeth Winstead': 39,
#  'Rami Malek': 38,
#  'Paul Dano': 38,
#  'Jennifer Beals': 16,
#  'Richard Gere': 37,
#  'Rob Lowe': 31,
#  'Dawn Olivieri': 12,
#  'Peyton List': 26,
#  'Shia LaBeouf': 54,
#  'Bella Ramsey': 9,
#  'Salma Hayek': 58,
#  'Orlando Bloom': 44,
#  'Steve Zahn': 62,
#  'Monica Bellucci': 23,
#  'Michael B. Jordan': 18,
#  'Marina Sirtis': 13,
#  'Jennifer Love Hewitt': 15,
#  'Madison Pettis': 11,
#  'Sam Elliott': 47,
#  'Natalie Dormer': 18,
#  'Kaitlyn Dever': 20,
#  'Marta Milans': 16,
#  'Indira Varma': 20,
#  'Rainn Wilson': 40,
#  'Norman Reedus': 30,
#  'Robert Pattinson': 37,
#  'Sigourney Weaver': 56,
#  'Daisy Head': 8,
#  'Tom Cruise': 75,
#  'Elisha Cuthbert': 11,
#  'Debby Ryan': 10,
#  'Anna Gunn': 8,
#  'Noah Jupe': 18,
#  'Piper Perabo': 30,
#  'Kathryn Newton': 13,
#  'Asher Angel': 7,
#  'Jean Dujardin': 7,
#  'Lacey Chabert': 18,
#  'Mackenzie Davis': 22,
#  'Manuel Ferrara': 16,
#  'Tilda Swinton': 88,
#  'Mia Goth': 16,
#  'Hong Chau': 10,
#  'Rosamund Pike': 29,
#  'Brooke Shields': 10,
#  'Chanel Preston': 6,
#  'Grace Caroline Currey': 9,
#  'Jet Li': 16,
#  'Saoirse Ronan': 37,
#  'Courtney Eaton': 8,
#  'Maisie Williams': 13,
#  'Enrique Arce': 8,
#  'Susan Sarandon': 89,
#  'Tom Hanks': 75,
#  'Katheryn Winnick': 20,
#  'Dani Daniels': 10,
#  'Sylvester Stallone': 61,
#  'Eve Harlow': 8,
#  'Tessa Thompson': 54,
#  'Jonathan Majors': 12,
#  'Tom Hardy': 54,
#  'Sean Bean': 60,
#  'Steve Carell': 66,
#  'Sharon Stone': 48,
#  'Dove Cameron': 8,
#  'Noel Fisher': 18,
#  'Lucy Boynton': 13,
#  'Thomas Jane': 47,
#  'Danielle Panabaker': 7,
#  'Nina Dobrev': 18,
#  'Keke Palmer': 10,
#  'D.B. Woodside': 5,
#  'Rooney Mara': 33,
#  'Morena Baccarin': 22,
#  'Lauren Cohan': 12,
#  'Tobey Maguire': 48,
#  'Tom Holland': 65,
#  'Steven Spielberg': 24,
#  'Jessica Drake': 6,
#  'Paula Patton': 26,
#  'Scott Adkins': 34,
#  'Rosa Salazar': 16,
#  'Paget Brewster': 6,
#  'Percy Hynes White': 6,
#  'Laura San Giacomo': 8,
#  'Felisha Terrell': 8,
#  'Timothée Chalamet': 49,
#  'Stephen Lang': 33,
#  'Kay Parker': 6,
#  'Robin Tunney': 17,
#  'Jacqueline Bisset': 9,
#  'Steven Yeun': 14,
#  'Sam Worthington': 35,
#  'Sarah Gadon': 19,
#  'Skeet Ulrich': 16,
#  'Natascha McElhone': 13,
#  'Rhona Mitra': 17,
#  'Riki Lindhome': 28,
#  'Jocelyn Hudon': 6,
#  'Ian Somerhalder': 5,
#  'Mia Serafino': 5,
#  'Willem Dafoe': 112,
#  'Abigail Cowen': 3,
#  'Seth MacFarlane': 30,
#  'Rory Culkin': 19,
#  'Guy Ritchie': 8,
#  'Millie Brady': 12,
#  'Winona Ryder': 63,
#  'Samara Weaving': 12,
#  'Gabriel Basso': 10,
#  'Katee Sackhoff': 7,
#  'Mia Malkova': 10,
#  'Alyvia Alyn Lind': 4,
#  'Ryan Gosling': 40,
#  'Kim Kardashian': 9,
#  'Nina Hartley': 9,
#  'Tommy Lee Jones': 59,
#  'Katherine LaNasa': 10,
#  'Charlie Murphy': 2,
#  'Zac Efron': 45,
#  'Andy Lau': 2,
#  'Vin Diesel': 74,
#  'Madelyn Cline': 6,
#  'Viggo Mortensen': 51,
#  'Woody Harrelson': 88,
#  'Traci Lords': 11,
#  'Manny Montana': 6,
#  'Thomas Brodie-Sangster': 21,
#  'Ariana Marie': 2,
#  'Inbar Lavi': 4,
#  'Taron Egerton': 19,
#  'Daisy Edgar-Jones': 2,
#  'Luke Grimes': 10,
#  'Sarah Hyland': 11,
#  'Nijiro Murakami': 6,
#  'Richard Madden': 13,
#  'Isabel May': 3,
#  'Sarah Shahi': 18,
#  'Rudy Pankow': 4,
#  'Rupert Grint': 13,
#  'Raegan Revord': 2,
#  'Hassie Harrison': 1,
#  'Jenna Haze': 3,
#  'Ginger Lynn Allen': 2,
#  'Tati Gabrielle': 4,
#  'Sadie Sink': 7,
#  'Sophia Lillis': 6,
#  'Rhea Seehorn': 2,
#  'Charles Bronson': 2,
#  'Jacob Elordi': 3,
#  'Rose Leslie': 10,
#  'Vera Farmiga': 39,
#  'Ryan Eggold': 7,
#  'Nikki Benz': 2,
#  'Anna Torv': 1,
#  'Asa Akira': 1,
#  'Timothy Dalton': 14,
#  'Taylor Sheridan': 4,
#  'Val Kilmer': 55,
#  'Devan Long': 1,
#  'Alexander Dreymon': 1,
#  'Tyler Hoechlin': 17,
#  'Katie Douglas': 3,
#  'Viola Davis': 54,
#  'Taylor Kitsch': 26,
#  'Lily Gao': 3,
#  'Lauren German': 1,
#  'Stoya': 15,
#  'Uma Thurman': 66,
#  'Sydney Sweeney': 15,
#  'Louis Partridge': 4,
#  'Gianna Michaels': 3,
#  'Nastassja Kinski': 4,
#  'Riley Reid': 6}

# %%
def _mask_on_actor_edge_frequency(df_d3, edge_frequency_dict, min_threshold):
    actors_to_mask = [k for k, v in edge_frequency_dict.items() if v > min_threshold]
    mask = df_d3['source'].isin(actors_to_mask) & df_d3['target'].isin(actors_to_mask)
    return df_d3[mask].reset_index(drop=True)

# %%
df_d3_masked = _mask_on_actor_edge_frequency(df_d3, edge_frequency_dict,6)

# %%
df_d3_masked
# Out:
#               source                   target  weight
# 0       John Goodman  Mary Elizabeth Winstead       1
# 1     Bradley Cooper  Mary Elizabeth Winstead       1
# 2     Bradley Cooper             John Goodman       2
# 3       Danny DeVito           Morgan Freeman       1
# 4     Channing Tatum              Oscar Isaac       1
# ...              ...                      ...     ...
# 8335     Bonnie Hunt             J.K. Simmons       1
# 8336      Donnie Yen               Vin Diesel       1
# 8337     Nina Dobrev               Vin Diesel       1
# 8338      Donnie Yen              Nina Dobrev       1
# 8339      Donnie Yen        Samuel L. Jackson       1
#
# [8340 rows x 3 columns]

# %% [markdown]
# # Graph Stuff

# %%
import networkx as nx
class ActorGraphMetrics:
    def __init__(self, df):
        self.df = df
        self.graph = self._create_graph()
        self.df_actor_attributes = self._calculate_actor_attributes()

    def _create_graph(self):
        graph = nx.from_pandas_edgelist(self.df, 'source', 'target', 'weight')
        return graph

    def _calculate_actor_attributes(self):
        actor_attributes = pd.DataFrame(index=self.graph.nodes)
        
        
        actor_attributes['DegreeCentrality'] = pd.Series(nx.degree_centrality(self.graph))
        actor_attributes['BetweennessCentrality'] = pd.Series(nx.betweenness_centrality(self.graph))
        actor_attributes['EigenvectorCentrality'] = pd.Series(nx.eigenvector_centrality(self.graph))
        actor_attributes['ClusteringCoefficient'] = pd.Series(nx.clustering(self.graph))
    
        return round(actor_attributes,3).reset_index().rename(columns={'index':'Actor'})

    def get_actor_attributes(self):
        return self.df_actor_attributes

# %%
df_actor_attributes
# Out:
#                        Actor  DegreeCentrality  BetweennessCentrality  \
# 0               John Goodman             0.210                  0.010
# 1    Mary Elizabeth Winstead             0.098                  0.002
# 2             Bradley Cooper             0.227                  0.007
# 3               Danny DeVito             0.172                  0.005
# 4             Morgan Freeman             0.237                  0.006
# ..                       ...               ...                    ...
# 392              Steven Yeun             0.030                  0.000
# 393       Danielle Panabaker             0.018                  0.000
# 394           Sydney Sweeney             0.035                  0.000
# 395              Asher Angel             0.015                  0.000
# 396            Jean Dujardin             0.018                  0.000
#
#      EigenvectorCentrality  ClusteringCoefficient
# 0                    0.077                  0.191
# 1                    0.035                  0.206
# 2                    0.103                  0.287
# 3                    0.067                  0.211
# 4                    0.100                  0.247
# ..                     ...                    ...
# 392                  0.009                  0.227
# 393                  0.005                  0.333
# 394                  0.010                  0.374
# 395                  0.004                  1.000
# 396                  0.009                  0.667
#
# [397 rows x 5 columns]

# %%
# Assuming you have a dataframe called 'df' representing the actor graph
actor_metrics = ActorGraphMetrics(df_d3_masked)
df_actor_attributes = actor_metrics.get_actor_attributes()


def create_actor_graph_metrics_dict(df):
#     df = df.reset_index()
    actor_dict = {}
    for _, row in df.iterrows():
        actor = row[0].replace(" ","_")
        attributes = {col: val for col, val in row[1:].items()}
        actor_dict[actor] = attributes
    return actor_dict

actor_graph_metrics_dict = create_actor_graph_metrics_dict(df_actor_attributes)

# %%
actor_graph_metrics_dict
# Out:
# {'John_Goodman': {'DegreeCentrality': 0.21,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.077,
#   'ClusteringCoefficient': 0.191},
#  'Mary_Elizabeth_Winstead': {'DegreeCentrality': 0.098,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.206},
#  'Bradley_Cooper': {'DegreeCentrality': 0.227,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.103,
#   'ClusteringCoefficient': 0.287},
#  'Danny_DeVito': {'DegreeCentrality': 0.172,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.067,
#   'ClusteringCoefficient': 0.211},
#  'Morgan_Freeman': {'DegreeCentrality': 0.237,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.1,
#   'ClusteringCoefficient': 0.247},
#  'Channing_Tatum': {'DegreeCentrality': 0.207,
#   'BetweennessCentrality': 0.011,
#   'EigenvectorCentrality': 0.082,
#   'ClusteringCoefficient': 0.215},
#  'Oscar_Isaac': {'DegreeCentrality': 0.159,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.061,
#   'ClusteringCoefficient': 0.217},
#  'Chris_Pratt': {'DegreeCentrality': 0.23,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.103,
#   'ClusteringCoefficient': 0.288},
#  'Aubrey_Plaza': {'DegreeCentrality': 0.083,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.22},
#  'Rosario_Dawson': {'DegreeCentrality': 0.184,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.075,
#   'ClusteringCoefficient': 0.229},
#  'Emile_Hirsch': {'DegreeCentrality': 0.124,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.243},
#  'Hailee_Steinfeld': {'DegreeCentrality': 0.104,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.288},
#  'Gemma_Arterton': {'DegreeCentrality': 0.071,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.259},
#  'Idris_Elba': {'DegreeCentrality': 0.202,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.087,
#   'ClusteringCoefficient': 0.266},
#  'Kelly_Reilly': {'DegreeCentrality': 0.043,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.265},
#  'Luke_Evans': {'DegreeCentrality': 0.126,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.042,
#   'ClusteringCoefficient': 0.206},
#  'Chris_Hemsworth': {'DegreeCentrality': 0.187,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.085,
#   'ClusteringCoefficient': 0.325},
#  'Elsa_Pataky': {'DegreeCentrality': 0.068,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.501},
#  'Benedict_Cumberbatch': {'DegreeCentrality': 0.222,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.103,
#   'ClusteringCoefficient': 0.311},
#  'Michael_Fassbender': {'DegreeCentrality': 0.139,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.059,
#   'ClusteringCoefficient': 0.269},
#  'Paul_Dano': {'DegreeCentrality': 0.093,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.213},
#  'Brad_Pitt': {'DegreeCentrality': 0.258,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.11,
#   'ClusteringCoefficient': 0.242},
#  'Andy_Serkis': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.054,
#   'ClusteringCoefficient': 0.271},
#  'Jennifer_Garner': {'DegreeCentrality': 0.109,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.226},
#  'Brie_Larson': {'DegreeCentrality': 0.189,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.078,
#   'ClusteringCoefficient': 0.28},
#  'Gérard_Depardieu': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.197},
#  'Sigourney_Weaver': {'DegreeCentrality': 0.139,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.18},
#  'Charlize_Theron': {'DegreeCentrality': 0.23,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.09,
#   'ClusteringCoefficient': 0.206},
#  'Robert_De_Niro': {'DegreeCentrality': 0.245,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.101,
#   'ClusteringCoefficient': 0.226},
#  'Vera_Farmiga': {'DegreeCentrality': 0.098,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.247},
#  'Leslie_Mann': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.223},
#  'Zac_Efron': {'DegreeCentrality': 0.106,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.163},
#  'Mark_Strong': {'DegreeCentrality': 0.217,
#   'BetweennessCentrality': 0.011,
#   'EigenvectorCentrality': 0.085,
#   'ClusteringCoefficient': 0.216},
#  'Richard_Madden': {'DegreeCentrality': 0.033,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.218},
#  'James_Spader': {'DegreeCentrality': 0.086,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.04,
#   'ClusteringCoefficient': 0.348},
#  'Cole_Hauser': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.262},
#  'Paul_Walker': {'DegreeCentrality': 0.081,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.22},
#  'Denzel_Washington': {'DegreeCentrality': 0.167,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.063,
#   'ClusteringCoefficient': 0.199},
#  'Mark_Wahlberg': {'DegreeCentrality': 0.169,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.063,
#   'ClusteringCoefficient': 0.192},
#  'Paula_Patton': {'DegreeCentrality': 0.061,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.228},
#  'James_Marsden': {'DegreeCentrality': 0.164,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.062,
#   'ClusteringCoefficient': 0.207},
#  'Christina_Ricci': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.226},
#  'Kate_Hudson': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.219},
#  'Paul_Rudd': {'DegreeCentrality': 0.227,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.102,
#   'ClusteringCoefficient': 0.283},
#  'Eve_Harlow': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.429},
#  'Woody_Harrelson': {'DegreeCentrality': 0.217,
#   'BetweennessCentrality': 0.012,
#   'EigenvectorCentrality': 0.079,
#   'ClusteringCoefficient': 0.184},
#  'Kate_Bosworth': {'DegreeCentrality': 0.104,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.24},
#  'Laurence_Fishburne': {'DegreeCentrality': 0.217,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.089,
#   'ClusteringCoefficient': 0.227},
#  'J.K._Simmons': {'DegreeCentrality': 0.28,
#   'BetweennessCentrality': 0.014,
#   'EigenvectorCentrality': 0.107,
#   'ClusteringCoefficient': 0.2},
#  'Taylor_Kitsch': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.297},
#  'Keith_David': {'DegreeCentrality': 0.182,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.07,
#   'ClusteringCoefficient': 0.2},
#  'Dakota_Johnson': {'DegreeCentrality': 0.071,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.201},
#  'Johnny_Depp': {'DegreeCentrality': 0.194,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.075,
#   'ClusteringCoefficient': 0.217},
#  'Peter_Stormare': {'DegreeCentrality': 0.169,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.065,
#   'ClusteringCoefficient': 0.198},
#  'Brian_Cox': {'DegreeCentrality': 0.162,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.067,
#   'ClusteringCoefficient': 0.218},
#  'Peyton_List': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.177},
#  'Sandra_Bullock': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.051,
#   'ClusteringCoefficient': 0.209},
#  'Viggo_Mortensen': {'DegreeCentrality': 0.124,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.056,
#   'ClusteringCoefficient': 0.313},
#  'Brendan_Gleeson': {'DegreeCentrality': 0.149,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.055,
#   'ClusteringCoefficient': 0.21},
#  'Cillian_Murphy': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.292},
#  'Jeremy_Renner': {'DegreeCentrality': 0.169,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.08,
#   'ClusteringCoefficient': 0.346},
#  'Kevin_Costner': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.244},
#  'Connie_Nielsen': {'DegreeCentrality': 0.111,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.288},
#  'Amber_Heard': {'DegreeCentrality': 0.109,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.278},
#  'Elle_Fanning': {'DegreeCentrality': 0.111,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.225},
#  'Susan_Sarandon': {'DegreeCentrality': 0.225,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.081,
#   'ClusteringCoefficient': 0.187},
#  'Gerard_Butler': {'DegreeCentrality': 0.134,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.216},
#  'Lena_Headey': {'DegreeCentrality': 0.111,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.037,
#   'ClusteringCoefficient': 0.199},
#  'Kurt_Russell': {'DegreeCentrality': 0.207,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.087,
#   'ClusteringCoefficient': 0.259},
#  'Courteney_Cox': {'DegreeCentrality': 0.058,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.271},
#  'Christian_Slater': {'DegreeCentrality': 0.157,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.063,
#   'ClusteringCoefficient': 0.272},
#  'Eva_Green': {'DegreeCentrality': 0.073,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.266},
#  'Jude_Law': {'DegreeCentrality': 0.177,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.07,
#   'ClusteringCoefficient': 0.225},
#  'Rachel_Weisz': {'DegreeCentrality': 0.126,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.055,
#   'ClusteringCoefficient': 0.259},
#  'Hiroyuki_Sanada': {'DegreeCentrality': 0.149,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.072,
#   'ClusteringCoefficient': 0.368},
#  'Keanu_Reeves': {'DegreeCentrality': 0.199,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.077,
#   'ClusteringCoefficient': 0.192},
#  'Heather_Graham': {'DegreeCentrality': 0.121,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.041,
#   'ClusteringCoefficient': 0.188},
#  'Val_Kilmer': {'DegreeCentrality': 0.136,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.059,
#   'ClusteringCoefficient': 0.259},
#  'Adam_Sandler': {'DegreeCentrality': 0.126,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.21},
#  'Drew_Barrymore': {'DegreeCentrality': 0.172,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.072,
#   'ClusteringCoefficient': 0.255},
#  'Jackie_Sandler': {'DegreeCentrality': 0.071,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.262},
#  'Katheryn_Winnick': {'DegreeCentrality': 0.048,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.246},
#  'Daniel_Radcliffe': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.211},
#  'Emma_Watson': {'DegreeCentrality': 0.073,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.241},
#  'Rupert_Grint': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.424},
#  'Anna_Kendrick': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.221},
#  'Bryce_Dallas_Howard': {'DegreeCentrality': 0.068,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.251},
#  'Ryan_Phillippe': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.178},
#  'Salma_Hayek': {'DegreeCentrality': 0.146,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.057,
#   'ClusteringCoefficient': 0.223},
#  'Nicolas_Cage': {'DegreeCentrality': 0.167,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.061,
#   'ClusteringCoefficient': 0.186},
#  'Norman_Reedus': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.262},
#  'Elijah_Wood': {'DegreeCentrality': 0.167,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.069,
#   'ClusteringCoefficient': 0.249},
#  'Jennifer_Connelly': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.238},
#  'Gina_Gershon': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.197},
#  'Jacqueline_Bisset': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.25},
#  'Hayden_Christensen': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.252},
#  'Andrew_Garfield': {'DegreeCentrality': 0.081,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.244},
#  'Clancy_Brown': {'DegreeCentrality': 0.146,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.056,
#   'ClusteringCoefficient': 0.201},
#  'Kathryn_Hahn': {'DegreeCentrality': 0.106,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.22},
#  'Mila_Kunis': {'DegreeCentrality': 0.098,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.223},
#  'Ariana_Greenblatt': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.405},
#  'Russell_Crowe': {'DegreeCentrality': 0.177,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.073,
#   'ClusteringCoefficient': 0.234},
#  'Paul_Bettany': {'DegreeCentrality': 0.159,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.074,
#   'ClusteringCoefficient': 0.321},
#  'Ralph_Fiennes': {'DegreeCentrality': 0.242,
#   'BetweennessCentrality': 0.012,
#   'EigenvectorCentrality': 0.093,
#   'ClusteringCoefficient': 0.208},
#  'Tilda_Swinton': {'DegreeCentrality': 0.215,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.1,
#   'ClusteringCoefficient': 0.302},
#  'Brooke_Shields': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.333},
#  'Gary_Oldman': {'DegreeCentrality': 0.212,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.08,
#   'ClusteringCoefficient': 0.199},
#  'Sarah_Gadon': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.17},
#  'Bruce_Willis': {'DegreeCentrality': 0.331,
#   'BetweennessCentrality': 0.016,
#   'EigenvectorCentrality': 0.137,
#   'ClusteringCoefficient': 0.219},
#  'Frank_Grillo': {'DegreeCentrality': 0.169,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.079,
#   'ClusteringCoefficient': 0.337},
#  'Britt_Robertson': {'DegreeCentrality': 0.061,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.217},
#  'Dennis_Quaid': {'DegreeCentrality': 0.146,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.052,
#   'ClusteringCoefficient': 0.194},
#  'Willem_Dafoe': {'DegreeCentrality': 0.275,
#   'BetweennessCentrality': 0.011,
#   'EigenvectorCentrality': 0.117,
#   'ClusteringCoefficient': 0.233},
#  'Alison_Brie': {'DegreeCentrality': 0.086,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.23},
#  'Kevin_Bacon': {'DegreeCentrality': 0.184,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.081,
#   'ClusteringCoefficient': 0.261},
#  'Tom_Cruise': {'DegreeCentrality': 0.187,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.078,
#   'ClusteringCoefficient': 0.254},
#  'Kiefer_Sutherland': {'DegreeCentrality': 0.126,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.189},
#  'Emmy_Rossum': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.222},
#  'Helen_Hunt': {'DegreeCentrality': 0.073,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.244},
#  'Scarlett_Johansson': {'DegreeCentrality': 0.25,
#   'BetweennessCentrality': 0.013,
#   'EigenvectorCentrality': 0.109,
#   'ClusteringCoefficient': 0.262},
#  'Shia_LaBeouf': {'DegreeCentrality': 0.131,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.053,
#   'ClusteringCoefficient': 0.233},
#  'Robert_Downey_Jr.': {'DegreeCentrality': 0.258,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.122,
#   'ClusteringCoefficient': 0.3},
#  'Maria_Bello': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.178},
#  'Daniel_Craig': {'DegreeCentrality': 0.134,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.196},
#  'Kate_Winslet': {'DegreeCentrality': 0.157,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.057,
#   'ClusteringCoefficient': 0.2},
#  'Bill_Pullman': {'DegreeCentrality': 0.106,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.036,
#   'ClusteringCoefficient': 0.187},
#  'Tom_Hanks': {'DegreeCentrality': 0.184,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.079,
#   'ClusteringCoefficient': 0.253},
#  'Peter_Dinklage': {'DegreeCentrality': 0.189,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.075,
#   'ClusteringCoefficient': 0.248},
#  'Aaron_Paul': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.172},
#  'Pierce_Brosnan': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.164},
#  'Sam_Neill': {'DegreeCentrality': 0.134,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.058,
#   'ClusteringCoefficient': 0.271},
#  'Rosamund_Pike': {'DegreeCentrality': 0.073,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.165},
#  'Enrique_Arce': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 0.286},
#  'Aimee_Garcia': {'DegreeCentrality': 0.04,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.258},
#  'Sarah_Shahi': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.216},
#  'John_Travolta': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.06,
#   'ClusteringCoefficient': 0.28},
#  'Seth_MacFarlane': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.384},
#  'Amanda_Seyfried': {'DegreeCentrality': 0.121,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.211},
#  'Giovanni_Ribisi': {'DegreeCentrality': 0.149,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.064,
#   'ClusteringCoefficient': 0.265},
#  'Ewan_McGregor': {'DegreeCentrality': 0.172,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.064,
#   'ClusteringCoefficient': 0.205},
#  'Christopher_Lloyd': {'DegreeCentrality': 0.101,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.251},
#  'Ryan_Reynolds': {'DegreeCentrality': 0.192,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.074,
#   'ClusteringCoefficient': 0.217},
#  'Rooney_Mara': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.271},
#  'Milla_Jovovich': {'DegreeCentrality': 0.104,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.046,
#   'ClusteringCoefficient': 0.295},
#  'Steve_Zahn': {'DegreeCentrality': 0.146,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.053,
#   'ClusteringCoefficient': 0.18},
#  'Clint_Eastwood': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.04,
#   'ClusteringCoefficient': 0.393},
#  'Tommy_Lee_Jones': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.064,
#   'ClusteringCoefficient': 0.278},
#  'Emily_Blunt': {'DegreeCentrality': 0.109,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.227},
#  'John_Krasinski': {'DegreeCentrality': 0.121,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.205},
#  'Noah_Jupe': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.261},
#  'Djimon_Hounsou': {'DegreeCentrality': 0.212,
#   'BetweennessCentrality': 0.012,
#   'EigenvectorCentrality': 0.079,
#   'ClusteringCoefficient': 0.193},
#  'Timothée_Chalamet': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.227},
#  'Winona_Ryder': {'DegreeCentrality': 0.154,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.061,
#   'ClusteringCoefficient': 0.216},
#  'Linda_Cardellini': {'DegreeCentrality': 0.136,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.066,
#   'ClusteringCoefficient': 0.413},
#  'Sam_Elliott': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.201},
#  'Matthew_McConaughey': {'DegreeCentrality': 0.22,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.084,
#   'ClusteringCoefficient': 0.196},
#  'Samuel_L._Jackson': {'DegreeCentrality': 0.366,
#   'BetweennessCentrality': 0.024,
#   'EigenvectorCentrality': 0.151,
#   'ClusteringCoefficient': 0.212},
#  'Donald_Sutherland': {'DegreeCentrality': 0.159,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.062,
#   'ClusteringCoefficient': 0.233},
#  'Haley_Joel_Osment': {'DegreeCentrality': 0.048,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.164},
#  'Charlie_Hunnam': {'DegreeCentrality': 0.081,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.22},
#  'Melanie_Lynskey': {'DegreeCentrality': 0.093,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.219},
#  'Emma_Roberts': {'DegreeCentrality': 0.081,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.179},
#  'Mimi_Rogers': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.257},
#  'Dermot_Mulroney': {'DegreeCentrality': 0.104,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.248},
#  'Kevin_Hart': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.054,
#   'ClusteringCoefficient': 0.221},
#  'Bill_Nighy': {'DegreeCentrality': 0.136,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.168},
#  'Margot_Robbie': {'DegreeCentrality': 0.109,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.041,
#   'ClusteringCoefficient': 0.227},
#  'Nicholas_Hoult': {'DegreeCentrality': 0.121,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.241},
#  'Gene_Hackman': {'DegreeCentrality': 0.121,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.246},
#  'Jake_Gyllenhaal': {'DegreeCentrality': 0.131,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.051,
#   'ClusteringCoefficient': 0.227},
#  'Liv_Tyler': {'DegreeCentrality': 0.109,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.344},
#  'Evan_Peters': {'DegreeCentrality': 0.068,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.33},
#  'Kristen_Stewart': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.213},
#  'Lucy_Liu': {'DegreeCentrality': 0.146,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.06,
#   'ClusteringCoefficient': 0.26},
#  'Noel_Fisher': {'DegreeCentrality': 0.04,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.158},
#  'Juno_Temple': {'DegreeCentrality': 0.139,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.054,
#   'ClusteringCoefficient': 0.234},
#  'Ian_McShane': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.207},
#  'Rami_Malek': {'DegreeCentrality': 0.091,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.224},
#  'Mel_Gibson': {'DegreeCentrality': 0.121,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.149},
#  'Harrison_Ford': {'DegreeCentrality': 0.152,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.058,
#   'ClusteringCoefficient': 0.212},
#  'Adrien_Brody': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.257},
#  'Keke_Palmer': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.422},
#  'Angela_Bassett': {'DegreeCentrality': 0.182,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.079,
#   'ClusteringCoefficient': 0.291},
#  'Aaron_Taylor-Johnson': {'DegreeCentrality': 0.141,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.057,
#   'ClusteringCoefficient': 0.243},
#  'Skeet_Ulrich': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.205},
#  'Giancarlo_Esposito': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.04,
#   'ClusteringCoefficient': 0.175},
#  'Jean_Reno': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.243},
#  'Angelina_Jolie': {'DegreeCentrality': 0.146,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.055,
#   'ClusteringCoefficient': 0.19},
#  'Colin_Farrell': {'DegreeCentrality': 0.162,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.063,
#   'ClusteringCoefficient': 0.21},
#  'Steve_Carell': {'DegreeCentrality': 0.159,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.057,
#   'ClusteringCoefficient': 0.196},
#  'Marisa_Tomei': {'DegreeCentrality': 0.205,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.092,
#   'ClusteringCoefficient': 0.288},
#  'Katherine_LaNasa': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.356},
#  'Charles_Dance': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.042,
#   'ClusteringCoefficient': 0.189},
#  'Rhona_Mitra': {'DegreeCentrality': 0.04,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.225},
#  'Anne_Hathaway': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.188},
#  'Ron_Perlman': {'DegreeCentrality': 0.179,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.06,
#   'ClusteringCoefficient': 0.156},
#  'Austin_Butler': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.486},
#  'Rosa_Salazar': {'DegreeCentrality': 0.035,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.187},
#  'Kirsten_Dunst': {'DegreeCentrality': 0.164,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.065,
#   'ClusteringCoefficient': 0.222},
#  'Ryan_Gosling': {'DegreeCentrality': 0.101,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.281},
#  "Dylan_O'Brien": {'DegreeCentrality': 0.051,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.184},
#  'Sadie_Sink': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.095},
#  'Luke_Grimes': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.244},
#  'Chris_Pine': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.203},
#  'Matt_Damon': {'DegreeCentrality': 0.26,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.112,
#   'ClusteringCoefficient': 0.24},
#  'Penélope_Cruz': {'DegreeCentrality': 0.111,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.259},
#  'Robert_Patrick': {'DegreeCentrality': 0.167,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.067,
#   'ClusteringCoefficient': 0.231},
#  'Frances_McDormand': {'DegreeCentrality': 0.131,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.061,
#   'ClusteringCoefficient': 0.299},
#  'Rainn_Wilson': {'DegreeCentrality': 0.098,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.037,
#   'ClusteringCoefficient': 0.224},
#  'Emma_Stone': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.221},
#  'Jennifer_Aniston': {'DegreeCentrality': 0.136,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.212},
#  'Sharon_Stone': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.259},
#  'Olivia_Wilde': {'DegreeCentrality': 0.169,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.067,
#   'ClusteringCoefficient': 0.216},
#  'Ali_Wong': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.271},
#  'Colleen_Camp': {'DegreeCentrality': 0.121,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.23},
#  'Mackenzie_Davis': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.171},
#  'Richard_Gere': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.269},
#  'Christopher_Walken': {'DegreeCentrality': 0.202,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.086,
#   'ClusteringCoefficient': 0.254},
#  'Michael_Keaton': {'DegreeCentrality': 0.134,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.051,
#   'ClusteringCoefficient': 0.21},
#  'Scott_Adkins': {'DegreeCentrality': 0.083,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.032,
#   'ClusteringCoefficient': 0.233},
#  'Josh_Brolin': {'DegreeCentrality': 0.253,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.112,
#   'ClusteringCoefficient': 0.273},
#  'Carla_Gugino': {'DegreeCentrality': 0.141,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.058,
#   'ClusteringCoefficient': 0.256},
#  'Amy_Adams': {'DegreeCentrality': 0.159,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.065,
#   'ClusteringCoefficient': 0.236},
#  'Dawn_Olivieri': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.4},
#  'Timothy_Dalton': {'DegreeCentrality': 0.035,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.308},
#  'Dakota_Fanning': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.042,
#   'ClusteringCoefficient': 0.189},
#  'John_Leguizamo': {'DegreeCentrality': 0.179,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.071,
#   'ClusteringCoefficient': 0.21},
#  'Jennifer_Morrison': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.233},
#  'Mckenna_Grace': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.209},
#  'Saoirse_Ronan': {'DegreeCentrality': 0.093,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.04,
#   'ClusteringCoefficient': 0.3},
#  'Anya_Taylor-Joy': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.268},
#  'Lacey_Chabert': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.242},
#  'Meagan_Good': {'DegreeCentrality': 0.098,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.242},
#  'Jack_Black': {'DegreeCentrality': 0.172,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.065,
#   'ClusteringCoefficient': 0.212},
#  'Lance_Reddick': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.282},
#  'Piper_Perabo': {'DegreeCentrality': 0.068,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.217},
#  'Sylvester_Stallone': {'DegreeCentrality': 0.152,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.058,
#   'ClusteringCoefficient': 0.225},
#  'Indira_Varma': {'DegreeCentrality': 0.048,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.298},
#  'Matthew_Macfadyen': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.267},
#  'Bill_Skarsgård': {'DegreeCentrality': 0.058,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.312},
#  'Sean_Bean': {'DegreeCentrality': 0.141,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.188},
#  'Annabelle_Wallis': {'DegreeCentrality': 0.073,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.239},
#  'Grace_Caroline_Currey': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.607},
#  'Sarah_Hyland': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.156},
#  'Natalie_Portman': {'DegreeCentrality': 0.215,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.099,
#   'ClusteringCoefficient': 0.293},
#  'Tessa_Thompson': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.066,
#   'ClusteringCoefficient': 0.485},
#  'Evangeline_Lilly': {'DegreeCentrality': 0.086,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.715},
#  'Chris_Evans': {'DegreeCentrality': 0.22,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.094,
#   'ClusteringCoefficient': 0.275},
#  'Michelle_Pfeiffer': {'DegreeCentrality': 0.172,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.084,
#   'ClusteringCoefficient': 0.338},
#  'Claire_Forlani': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.319},
#  'Viola_Davis': {'DegreeCentrality': 0.131,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.182},
#  'Al_Pacino': {'DegreeCentrality': 0.124,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.052,
#   'ClusteringCoefficient': 0.266},
#  'Aaron_Eckhart': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.19},
#  'Ashley_Johnson': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.331},
#  'Glen_Powell': {'DegreeCentrality': 0.093,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.237},
#  'Jason_Momoa': {'DegreeCentrality': 0.093,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.041,
#   'ClusteringCoefficient': 0.353},
#  'Nicole_Kidman': {'DegreeCentrality': 0.189,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.074,
#   'ClusteringCoefficient': 0.212},
#  'Nina_Dobrev': {'DegreeCentrality': 0.043,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.154},
#  'Bryan_Cranston': {'DegreeCentrality': 0.162,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.064,
#   'ClusteringCoefficient': 0.21},
#  'Owen_Wilson': {'DegreeCentrality': 0.187,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.076,
#   'ClusteringCoefficient': 0.234},
#  'Bridget_Fonda': {'DegreeCentrality': 0.071,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.032,
#   'ClusteringCoefficient': 0.418},
#  'Embeth_Davidtz': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.17},
#  'Nathalie_Emmanuel': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.277},
#  'Dave_Bautista': {'DegreeCentrality': 0.184,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.085,
#   'ClusteringCoefficient': 0.335},
#  'Ella_Purnell': {'DegreeCentrality': 0.04,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.208},
#  'Jackie_Chan': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.281},
#  'Hong_Chau': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.4},
#  'Helen_Mirren': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.057,
#   'ClusteringCoefficient': 0.23},
#  'James_McAvoy': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.059,
#   'ClusteringCoefficient': 0.253},
#  'Anne_Heche': {'DegreeCentrality': 0.081,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.248},
#  'Jason_Bateman': {'DegreeCentrality': 0.146,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.058,
#   'ClusteringCoefficient': 0.235},
#  'Harvey_Keitel': {'DegreeCentrality': 0.134,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.06,
#   'ClusteringCoefficient': 0.327},
#  'Famke_Janssen': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.231},
#  'Marta_Milans': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.333},
#  'Antonio_Banderas': {'DegreeCentrality': 0.164,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.069,
#   'ClusteringCoefficient': 0.249},
#  'Mads_Mikkelsen': {'DegreeCentrality': 0.068,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.251},
#  'Rob_Lowe': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.193},
#  'Steven_Spielberg': {'DegreeCentrality': 0.061,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.362},
#  'Sam_Worthington': {'DegreeCentrality': 0.083,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.193},
#  'Stephen_Lang': {'DegreeCentrality': 0.081,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.204},
#  'Elizabeth_Olsen': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.064,
#   'ClusteringCoefficient': 0.478},
#  'Tom_Holland': {'DegreeCentrality': 0.152,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.072,
#   'ClusteringCoefficient': 0.402},
#  'Karen_Gillan': {'DegreeCentrality': 0.159,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.078,
#   'ClusteringCoefficient': 0.407},
#  'Jon_Favreau': {'DegreeCentrality': 0.232,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.105,
#   'ClusteringCoefficient': 0.277},
#  'Vin_Diesel': {'DegreeCentrality': 0.179,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.083,
#   'ClusteringCoefficient': 0.35},
#  'Benicio_del_Toro': {'DegreeCentrality': 0.192,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.087,
#   'ClusteringCoefficient': 0.273},
#  'Frances_Fisher': {'DegreeCentrality': 0.096,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.212},
#  'Jon_Bernthal': {'DegreeCentrality': 0.126,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.052,
#   'ClusteringCoefficient': 0.239},
#  'Lily_James': {'DegreeCentrality': 0.048,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.222},
#  'Samara_Weaving': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.318},
#  'Tobey_Maguire': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.053,
#   'ClusteringCoefficient': 0.303},
#  'Michelle_Yeoh': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.262},
#  'Martin_Lawrence': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.3},
#  'Alexander_Ludwig': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.203},
#  'Charlie_Day': {'DegreeCentrality': 0.086,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.308},
#  'Gillian_Jacobs': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.19},
#  'Kaitlyn_Dever': {'DegreeCentrality': 0.048,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.24},
#  'Kathryn_Newton': {'DegreeCentrality': 0.033,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.231},
#  'Lucy_Boynton': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.288},
#  'Elisha_Cuthbert': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.255},
#  'Dove_Cameron': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.381},
#  'Gabriel_Basso': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.267},
#  'Gal_Gadot': {'DegreeCentrality': 0.124,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.265},
#  'Henry_Cavill': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.272},
#  'Lauren_Cohan': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.455},
#  'Jeffrey_Dean_Morgan': {'DegreeCentrality': 0.086,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.248},
#  'Katee_Sackhoff': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.476},
#  "Beverly_D'Angelo": {'DegreeCentrality': 0.058,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.225},
#  'Ray_Liotta': {'DegreeCentrality': 0.212,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.087,
#   'ClusteringCoefficient': 0.219},
#  'Joey_King': {'DegreeCentrality': 0.086,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.032,
#   'ClusteringCoefficient': 0.262},
#  'Alexandra_Daddario': {'DegreeCentrality': 0.04,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.233},
#  'Uma_Thurman': {'DegreeCentrality': 0.167,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.07,
#   'ClusteringCoefficient': 0.259},
#  'Christian_Convery': {'DegreeCentrality': 0.035,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.242},
#  'Jack_Dylan_Grazer': {'DegreeCentrality': 0.035,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.308},
#  'Thomas_Jane': {'DegreeCentrality': 0.109,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.042,
#   'ClusteringCoefficient': 0.221},
#  'Robert_Pattinson': {'DegreeCentrality': 0.093,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.197},
#  'Michelle_Monaghan': {'DegreeCentrality': 0.126,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.055,
#   'ClusteringCoefficient': 0.281},
#  'Awkwafina': {'DegreeCentrality': 0.071,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.28},
#  'Madison_Pettis': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.167},
#  'Noel_Gugliemi': {'DegreeCentrality': 0.114,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.262},
#  'Chloë_Grace_Moretz': {'DegreeCentrality': 0.134,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.187},
#  'Natascha_McElhone': {'DegreeCentrality': 0.033,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.269},
#  'Matthew_Lillard': {'DegreeCentrality': 0.071,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.16},
#  'Taron_Egerton': {'DegreeCentrality': 0.048,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.316},
#  'Adam_Driver': {'DegreeCentrality': 0.096,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.036,
#   'ClusteringCoefficient': 0.211},
#  'Ryan_Eggold': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.381},
#  'Josh_Hartnett': {'DegreeCentrality': 0.073,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.308},
#  'Orlando_Bloom': {'DegreeCentrality': 0.106,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.041,
#   'ClusteringCoefficient': 0.261},
#  'Tom_Hardy': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.227},
#  'Michael_B._Jordan': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.276},
#  'Florence_Pugh': {'DegreeCentrality': 0.051,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.289},
#  'Donnie_Yen': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.255},
#  'Ana_de_Armas': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.294},
#  'Nathan_Fillion': {'DegreeCentrality': 0.124,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.248},
#  'Jason_Statham': {'DegreeCentrality': 0.139,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.053,
#   'ClusteringCoefficient': 0.232},
#  'John_Cena': {'DegreeCentrality': 0.109,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.042,
#   'ClusteringCoefficient': 0.23},
#  'Leonardo_DiCaprio': {'DegreeCentrality': 0.192,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.082,
#   'ClusteringCoefficient': 0.254},
#  'Nina_Hartley': {'DegreeCentrality': 0.013,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.003,
#   'ClusteringCoefficient': 0.4},
#  'Halle_Berry': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.056,
#   'ClusteringCoefficient': 0.292},
#  'Carrie-Anne_Moss': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.267},
#  'Jenny_Slate': {'DegreeCentrality': 0.093,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.243},
#  'Monica_Bellucci': {'DegreeCentrality': 0.058,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.336},
#  'Bailee_Madison': {'DegreeCentrality': 0.033,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.346},
#  'Kate_Beckinsale': {'DegreeCentrality': 0.101,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.037,
#   'ClusteringCoefficient': 0.222},
#  'Rory_Culkin': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.235},
#  'Tyler_Hoechlin': {'DegreeCentrality': 0.04,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.15},
#  'Natalie_Dormer': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.288},
#  'Jonathan_Majors': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.218},
#  'Alan_Ruck': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.212},
#  'Jodie_Foster': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.267},
#  'Bonnie_Hunt': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.28},
#  'Elizabeth_Banks': {'DegreeCentrality': 0.177,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.07,
#   'ClusteringCoefficient': 0.234},
#  'Jennifer_Beals': {'DegreeCentrality': 0.035,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.33},
#  'Jeff_Goldblum': {'DegreeCentrality': 0.187,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.084,
#   'ClusteringCoefficient': 0.285},
#  'Riki_Lindhome': {'DegreeCentrality': 0.068,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.236},
#  'Daisy_Ridley': {'DegreeCentrality': 0.061,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.333},
#  'Kaya_Scodelario': {'DegreeCentrality': 0.045,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.216},
#  'Marina_Sirtis': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.288},
#  'Traci_Lords': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.356},
#  'Maisie_Williams': {'DegreeCentrality': 0.033,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.269},
#  'Dina_Meyer': {'DegreeCentrality': 0.035,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.231},
#  'Morena_Baccarin': {'DegreeCentrality': 0.051,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.347},
#  'Anna_Gunn': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.25},
#  'Rose_Leslie': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.25},
#  'Denise_Richards': {'DegreeCentrality': 0.051,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.168},
#  'Kim_Kardashian': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.444},
#  'Rebecca_Ferguson': {'DegreeCentrality': 0.068,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.288},
#  'Finn_Wolfhard': {'DegreeCentrality': 0.051,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.295},
#  'Emilia_Clarke': {'DegreeCentrality': 0.033,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.372},
#  'Alexis_Texas': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 1.0},
#  'Manuel_Ferrara': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.822},
#  'Mia_Malkova': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 1.0},
#  'Dani_Daniels': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 1.0},
#  'Stoya': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.822},
#  'Bob_Odenkirk': {'DegreeCentrality': 0.086,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.228},
#  'Jim_Caviezel': {'DegreeCentrality': 0.076,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.202},
#  'Billy_Zane': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.277},
#  'Mia_Goth': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.305},
#  'Robin_Tunney': {'DegreeCentrality': 0.043,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.191},
#  'Angourie_Rice': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.447},
#  'Debby_Ryan': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 0.167},
#  'Daisy_Head': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.429},
#  'Bella_Ramsey': {'DegreeCentrality': 0.023,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.528},
#  'Felisha_Terrell': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.429},
#  'Alan_Ritchson': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.286},
#  'Courtney_Eaton': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.464},
#  'Laura_San_Giacomo': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.321},
#  'Jennifer_Love_Hewitt': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.362},
#  'Millie_Brady': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.303},
#  'Guy_Ritchie': {'DegreeCentrality': 0.02,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.571},
#  'Jet_Li': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.41},
#  'Thomas_Brodie-Sangster': {'DegreeCentrality': 0.048,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.251},
#  'Steven_Yeun': {'DegreeCentrality': 0.03,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.227},
#  'Danielle_Panabaker': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.333},
#  'Sydney_Sweeney': {'DegreeCentrality': 0.035,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.374},
#  'Asher_Angel': {'DegreeCentrality': 0.015,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 1.0},
#  'Jean_Dujardin': {'DegreeCentrality': 0.018,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.667}}

# %%
def append_actor_url(df_actor_attributes,df_cast_movies, imdb_image_path):
    df_actor_attributes = df_actor_attributes.merge(df_cast_movies[['c_name','c_profile_path']].drop_duplicates\
                    (subset='c_name',keep='first'),left_on='Actor',right_on='c_name').drop(columns='c_name')
    df_actor_attributes['c_profile_path'] = df_actor_attributes['c_profile_path'].apply(lambda x: x+imdb_image_path)
    return df_actor_attributes

# %%
df_actor_attributes
# Out:
#                        Actor  DegreeCentrality  BetweennessCentrality  \
# 0               John Goodman             0.088                  0.004
# 1    Mary Elizabeth Winstead             0.050                  0.002
# 2             Bradley Cooper             0.185                  0.011
# 3               Emile Hirsch             0.060                  0.003
# 4           Hailee Steinfeld             0.100                  0.005
# ..                       ...               ...                    ...
# 315             Aimee Garcia             0.022                  0.000
# 316        Denzel Washington             0.025                  0.001
# 317              Asher Angel             0.019                  0.000
# 318          Kate Beckinsale             0.009                  0.000
# 319                   Jet Li             0.019                  0.000
#
#      EigenvectorCentrality  ClusteringCoefficient
# 0                    0.046                  0.185
# 1                    0.020                  0.133
# 2                    0.160                  0.369
# 3                    0.023                  0.292
# 4                    0.058                  0.234
# ..                     ...                    ...
# 315                  0.012                  0.476
# 316                  0.008                  0.143
# 317                  0.004                  1.000
# 318                  0.002                  0.000
# 319                  0.006                  1.000
#
# [320 rows x 5 columns]

# %%
# Out:
#                        Actor  DegreeCentrality  BetweennessCentrality  \
# 0               John Goodman             0.088                  0.004
# 1    Mary Elizabeth Winstead             0.050                  0.002
# 2             Bradley Cooper             0.185                  0.011
# 3               Emile Hirsch             0.060                  0.003
# 4           Hailee Steinfeld             0.100                  0.005
# ..                       ...               ...                    ...
# 315             Aimee Garcia             0.022                  0.000
# 316        Denzel Washington             0.025                  0.001
# 317              Asher Angel             0.019                  0.000
# 318          Kate Beckinsale             0.009                  0.000
# 319                   Jet Li             0.019                  0.000
#
#      EigenvectorCentrality  ClusteringCoefficient  \
# 0                    0.046                  0.185
# 1                    0.020                  0.133
# 2                    0.160                  0.369
# 3                    0.023                  0.292
# 4                    0.058                  0.234
# ..                     ...                    ...
# 315                  0.012                  0.476
# 316                  0.008                  0.143
# 317                  0.004                  1.000
# 318                  0.002                  0.000
# 319                  0.006                  1.000
#
#                        c_profile_path
# 0    /yyYqoyKHO7hE1zpgEV2XlqYWcNV.jpg
# 1    /vQn6IGsClpyhV6KTba9EDqSK7e2.jpg
# 2     /DPnessSsWqVXRbKm93PtMjB4Us.jpg
# 3    /Ah8BYOB7P8tX9jnQVrnAbL2kxYJ.jpg
# 4    /q4UpZMEuvNCN5lL5L6xa3ICpheJ.jpg
# ..                                ...
# 315  /4z3mkoa8jHpqjzfbhzYMeKe2Mf7.jpg
# 316  /cEU2Vrdo83izpGmOvbVAOz5jCof.jpg
# 317  /lgBt67iggDs0d8QBSyjdk2ytHtK.jpg
# 318   /CzTuSQ7jfqBF3x4SX7NQH79BKf.jpg
# 319  /5a6u17dAf11kLvdRUG6QdoRRURj.jpg
#
# [320 rows x 6 columns]

# %%
actor_graph_metrics_dict
# Out:
# {'John_Goodman': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.046,
#   'ClusteringCoefficient': 0.185},
#  'Mary_Elizabeth_Winstead': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.133},
#  'Bradley_Cooper': {'DegreeCentrality': 0.185,
#   'BetweennessCentrality': 0.011,
#   'EigenvectorCentrality': 0.16,
#   'ClusteringCoefficient': 0.369},
#  'Emile_Hirsch': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.292},
#  'Hailee_Steinfeld': {'DegreeCentrality': 0.1,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.058,
#   'ClusteringCoefficient': 0.234},
#  'Gemma_Arterton': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.333},
#  'Idris_Elba': {'DegreeCentrality': 0.185,
#   'BetweennessCentrality': 0.016,
#   'EigenvectorCentrality': 0.14,
#   'ClusteringCoefficient': 0.283},
#  'Chris_Hemsworth': {'DegreeCentrality': 0.179,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.157,
#   'ClusteringCoefficient': 0.387},
#  'Elsa_Pataky': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.055,
#   'ClusteringCoefficient': 0.562},
#  'Mark_Strong': {'DegreeCentrality': 0.069,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.208},
#  'Richard_Madden': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.164},
#  'Benedict_Cumberbatch': {'DegreeCentrality': 0.229,
#   'BetweennessCentrality': 0.025,
#   'EigenvectorCentrality': 0.173,
#   'ClusteringCoefficient': 0.28},
#  'J.K._Simmons': {'DegreeCentrality': 0.191,
#   'BetweennessCentrality': 0.025,
#   'EigenvectorCentrality': 0.083,
#   'ClusteringCoefficient': 0.15},
#  'Keith_David': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.295},
#  'Channing_Tatum': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.067,
#   'ClusteringCoefficient': 0.196},
#  'Peter_Stormare': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.2},
#  'Kevin_Costner': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.272},
#  'Connie_Nielsen': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.363},
#  'Amber_Heard': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.438},
#  'Eva_Green': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.295},
#  'Lena_Headey': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.224},
#  'Gina_Gershon': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.143},
#  'Jacqueline_Bisset': {'DegreeCentrality': 0.016,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.002,
#   'ClusteringCoefficient': 0.3},
#  'Hayden_Christensen': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.308},
#  'Kate_Bosworth': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.105},
#  'Andrew_Garfield': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.34},
#  'Clancy_Brown': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.056,
#   'ClusteringCoefficient': 0.235},
#  'Kathryn_Hahn': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.156},
#  'Mila_Kunis': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.179},
#  'Ariana_Greenblatt': {'DegreeCentrality': 0.1,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.088,
#   'ClusteringCoefficient': 0.403},
#  'Ralph_Fiennes': {'DegreeCentrality': 0.179,
#   'BetweennessCentrality': 0.022,
#   'EigenvectorCentrality': 0.085,
#   'ClusteringCoefficient': 0.16},
#  'Tilda_Swinton': {'DegreeCentrality': 0.194,
#   'BetweennessCentrality': 0.016,
#   'EigenvectorCentrality': 0.154,
#   'ClusteringCoefficient': 0.316},
#  'Dakota_Johnson': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.135},
#  'Bruce_Willis': {'DegreeCentrality': 0.166,
#   'BetweennessCentrality': 0.013,
#   'EigenvectorCentrality': 0.093,
#   'ClusteringCoefficient': 0.224},
#  'Frank_Grillo': {'DegreeCentrality': 0.132,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.129,
#   'ClusteringCoefficient': 0.513},
#  'Britt_Robertson': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.141},
#  'Dennis_Quaid': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.156},
#  'Gerard_Butler': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.218},
#  'Willem_Dafoe': {'DegreeCentrality': 0.182,
#   'BetweennessCentrality': 0.019,
#   'EigenvectorCentrality': 0.093,
#   'ClusteringCoefficient': 0.185},
#  'Alison_Brie': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.203},
#  'Aaron_Paul': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.134},
#  'Pierce_Brosnan': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.132},
#  'Sam_Neill': {'DegreeCentrality': 0.085,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.064,
#   'ClusteringCoefficient': 0.356},
#  'Rosamund_Pike': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.164},
#  'Enrique_Arce': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 0.286},
#  'Charlize_Theron': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.011,
#   'EigenvectorCentrality': 0.057,
#   'ClusteringCoefficient': 0.149},
#  'Seth_MacFarlane': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.418},
#  'Amanda_Seyfried': {'DegreeCentrality': 0.085,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.174},
#  'Giovanni_Ribisi': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.295},
#  'Ewan_McGregor': {'DegreeCentrality': 0.097,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.191},
#  'Christopher_Lloyd': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.294},
#  'Ryan_Reynolds': {'DegreeCentrality': 0.154,
#   'BetweennessCentrality': 0.014,
#   'EigenvectorCentrality': 0.071,
#   'ClusteringCoefficient': 0.171},
#  'Emily_Blunt': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.205},
#  'John_Krasinski': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.178},
#  'Noah_Jupe': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.206},
#  'Cillian_Murphy': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.286},
#  'Djimon_Hounsou': {'DegreeCentrality': 0.172,
#   'BetweennessCentrality': 0.027,
#   'EigenvectorCentrality': 0.088,
#   'ClusteringCoefficient': 0.158},
#  'Elle_Fanning': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.153},
#  'Timothée_Chalamet': {'DegreeCentrality': 0.138,
#   'BetweennessCentrality': 0.015,
#   'EigenvectorCentrality': 0.058,
#   'ClusteringCoefficient': 0.138},
#  'Jude_Law': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.283},
#  'Anna_Kendrick': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.16},
#  'Linda_Cardellini': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.132,
#   'ClusteringCoefficient': 0.572},
#  'Sam_Elliott': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.219},
#  'Emma_Roberts': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.003,
#   'ClusteringCoefficient': 0.067},
#  'Kevin_Hart': {'DegreeCentrality': 0.097,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.14},
#  'Paula_Patton': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 0.267},
#  'Jake_Gyllenhaal': {'DegreeCentrality': 0.091,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.057,
#   'ClusteringCoefficient': 0.281},
#  'James_Marsden': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.163},
#  'Cole_Hauser': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.25},
#  'Brad_Pitt': {'DegreeCentrality': 0.169,
#   'BetweennessCentrality': 0.019,
#   'EigenvectorCentrality': 0.077,
#   'ClusteringCoefficient': 0.199},
#  'Tommy_Lee_Jones': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.206},
#  'Donald_Sutherland': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.143},
#  'Norman_Reedus': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.273},
#  'Adrien_Brody': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.458},
#  'Jennifer_Garner': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.183},
#  'Steve_Carell': {'DegreeCentrality': 0.085,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.157},
#  'Anne_Hathaway': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.205},
#  'Johnny_Depp': {'DegreeCentrality': 0.097,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.131},
#  'Jennifer_Connelly': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.279},
#  'Rosa_Salazar': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.212},
#  "Dylan_O'Brien": {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.21},
#  'Sadie_Sink': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.067},
#  'Chris_Pine': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.166},
#  'Laurence_Fishburne': {'DegreeCentrality': 0.11,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.156},
#  'Emma_Stone': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.14},
#  'Dermot_Mulroney': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.167},
#  'Ali_Wong': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.229},
#  'Keanu_Reeves': {'DegreeCentrality': 0.097,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.217},
#  'Colleen_Camp': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.171},
#  'Mackenzie_Davis': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.154},
#  'Michael_Keaton': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.232},
#  'Scott_Adkins': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.235},
#  'Dakota_Fanning': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.385},
#  'Luke_Grimes': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.19},
#  'Clint_Eastwood': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.667},
#  'John_Leguizamo': {'DegreeCentrality': 0.069,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.182},
#  'Kristen_Stewart': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.179},
#  'Bill_Pullman': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.152},
#  'Jennifer_Morrison': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.194},
#  'Mckenna_Grace': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.198},
#  'Kate_Winslet': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.147},
#  'Saoirse_Ronan': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.314},
#  'Margot_Robbie': {'DegreeCentrality': 0.116,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.052,
#   'ClusteringCoefficient': 0.177},
#  'Robert_De_Niro': {'DegreeCentrality': 0.125,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.056,
#   'ClusteringCoefficient': 0.24},
#  'Anya_Taylor-Joy': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.171},
#  'Rami_Malek': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.216},
#  'Morgan_Freeman': {'DegreeCentrality': 0.113,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.049,
#   'ClusteringCoefficient': 0.163},
#  'Lance_Reddick': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.248},
#  'Sylvester_Stallone': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.052,
#   'ClusteringCoefficient': 0.298},
#  'Danny_DeVito': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.185},
#  'Annabelle_Wallis': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.199},
#  'Grace_Caroline_Currey': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.607},
#  'Natalie_Portman': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.132,
#   'ClusteringCoefficient': 0.559},
#  'Tessa_Thompson': {'DegreeCentrality': 0.157,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.146,
#   'ClusteringCoefficient': 0.449},
#  'Oscar_Isaac': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.059,
#   'ClusteringCoefficient': 0.198},
#  'Evangeline_Lilly': {'DegreeCentrality': 0.103,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.116,
#   'ClusteringCoefficient': 0.708},
#  'Paul_Rudd': {'DegreeCentrality': 0.163,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.144,
#   'ClusteringCoefficient': 0.4},
#  'Chris_Evans': {'DegreeCentrality': 0.176,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.153,
#   'ClusteringCoefficient': 0.388},
#  'Michelle_Pfeiffer': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.121,
#   'ClusteringCoefficient': 0.555},
#  'Glen_Powell': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.137},
#  'Jack_Black': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.179},
#  'Jason_Momoa': {'DegreeCentrality': 0.1,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.298},
#  'Nicole_Kidman': {'DegreeCentrality': 0.1,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.171},
#  'Nicolas_Cage': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.147},
#  'Rainn_Wilson': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.066},
#  'Hiroyuki_Sanada': {'DegreeCentrality': 0.138,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.129,
#   'ClusteringCoefficient': 0.468},
#  'Nathalie_Emmanuel': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.255},
#  'Dave_Bautista': {'DegreeCentrality': 0.201,
#   'BetweennessCentrality': 0.013,
#   'EigenvectorCentrality': 0.168,
#   'ClusteringCoefficient': 0.34},
#  'Ella_Purnell': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.236},
#  'Amy_Adams': {'DegreeCentrality': 0.069,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.355},
#  'Jeremy_Renner': {'DegreeCentrality': 0.138,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.13,
#   'ClusteringCoefficient': 0.483},
#  'Colin_Farrell': {'DegreeCentrality': 0.069,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.113},
#  'Hong_Chau': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.333},
#  'Famke_Janssen': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.182},
#  'Ron_Perlman': {'DegreeCentrality': 0.069,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.143},
#  'Marta_Milans': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.295},
#  'Robert_Patrick': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.248},
#  'Christian_Slater': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.561},
#  'Brendan_Gleeson': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.167},
#  'Michael_Fassbender': {'DegreeCentrality': 0.094,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.32},
#  'Bill_Skarsgård': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.292},
#  'Mads_Mikkelsen': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.4},
#  'James_McAvoy': {'DegreeCentrality': 0.11,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.051,
#   'ClusteringCoefficient': 0.225},
#  'Sam_Worthington': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.165},
#  'Sigourney_Weaver': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.199},
#  'Stephen_Lang': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.181},
#  'Robert_Downey_Jr.': {'DegreeCentrality': 0.166,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.153,
#   'ClusteringCoefficient': 0.439},
#  'Scarlett_Johansson': {'DegreeCentrality': 0.182,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.161,
#   'ClusteringCoefficient': 0.393},
#  'James_Spader': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.051,
#   'ClusteringCoefficient': 0.771},
#  'Samuel_L._Jackson': {'DegreeCentrality': 0.273,
#   'BetweennessCentrality': 0.033,
#   'EigenvectorCentrality': 0.192,
#   'ClusteringCoefficient': 0.241},
#  'Aaron_Taylor-Johnson': {'DegreeCentrality': 0.097,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.076,
#   'ClusteringCoefficient': 0.353},
#  'Elizabeth_Olsen': {'DegreeCentrality': 0.125,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.136,
#   'ClusteringCoefficient': 0.638},
#  'Paul_Bettany': {'DegreeCentrality': 0.122,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.113,
#   'ClusteringCoefficient': 0.463},
#  'Andy_Serkis': {'DegreeCentrality': 0.103,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.074,
#   'ClusteringCoefficient': 0.314},
#  'Josh_Brolin': {'DegreeCentrality': 0.213,
#   'BetweennessCentrality': 0.016,
#   'EigenvectorCentrality': 0.172,
#   'ClusteringCoefficient': 0.322},
#  'Brie_Larson': {'DegreeCentrality': 0.16,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.14,
#   'ClusteringCoefficient': 0.401},
#  'Tom_Holland': {'DegreeCentrality': 0.179,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.154,
#   'ClusteringCoefficient': 0.378},
#  'Karen_Gillan': {'DegreeCentrality': 0.191,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.164,
#   'ClusteringCoefficient': 0.365},
#  'Jon_Favreau': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.137,
#   'ClusteringCoefficient': 0.48},
#  'Marisa_Tomei': {'DegreeCentrality': 0.147,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.138,
#   'ClusteringCoefficient': 0.467},
#  'Angela_Bassett': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.127,
#   'ClusteringCoefficient': 0.414},
#  'Vin_Diesel': {'DegreeCentrality': 0.182,
#   'BetweennessCentrality': 0.018,
#   'EigenvectorCentrality': 0.157,
#   'ClusteringCoefficient': 0.391},
#  'Chris_Pratt': {'DegreeCentrality': 0.179,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.162,
#   'ClusteringCoefficient': 0.407},
#  'Peter_Dinklage': {'DegreeCentrality': 0.185,
#   'BetweennessCentrality': 0.024,
#   'EigenvectorCentrality': 0.118,
#   'ClusteringCoefficient': 0.224},
#  'Benicio_del_Toro': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.106,
#   'ClusteringCoefficient': 0.431},
#  'Jon_Bernthal': {'DegreeCentrality': 0.069,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.036,
#   'ClusteringCoefficient': 0.19},
#  'Lily_James': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.176},
#  'Olivia_Wilde': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.209},
#  'Samara_Weaving': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.242},
#  'Tobey_Maguire': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.031,
#   'ClusteringCoefficient': 0.604},
#  'Steven_Spielberg': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.667},
#  'Dove_Cameron': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.4},
#  'Gal_Gadot': {'DegreeCentrality': 0.11,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.056,
#   'ClusteringCoefficient': 0.284},
#  'Henry_Cavill': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.029,
#   'ClusteringCoefficient': 0.34},
#  'Lauren_Cohan': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.622},
#  'Carla_Gugino': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.028,
#   'ClusteringCoefficient': 0.405},
#  'Jeffrey_Dean_Morgan': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.308},
#  'Peyton_List': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.003,
#   'ClusteringCoefficient': 0.25},
#  'Alexandra_Daddario': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.107},
#  'Zac_Efron': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.112},
#  'Christian_Convery': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.244},
#  'Kaitlyn_Dever': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.333},
#  'Jack_Dylan_Grazer': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.275},
#  'Emma_Watson': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.227},
#  'Luke_Evans': {'DegreeCentrality': 0.091,
#   'BetweennessCentrality': 0.008,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.19},
#  'Thomas_Jane': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.222},
#  'Michelle_Monaghan': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.2},
#  'Ray_Liotta': {'DegreeCentrality': 0.085,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.035,
#   'ClusteringCoefficient': 0.171},
#  'Matthew_McConaughey': {'DegreeCentrality': 0.085,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.051,
#   'ClusteringCoefficient': 0.245},
#  'Awkwafina': {'DegreeCentrality': 0.085,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.222},
#  'Noel_Gugliemi': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.383},
#  'Taron_Egerton': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.021,
#   'ClusteringCoefficient': 0.231},
#  'Sandra_Bullock': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.286},
#  'Adam_Driver': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.038,
#   'ClusteringCoefficient': 0.193},
#  'Ryan_Eggold': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.333},
#  'Aubrey_Plaza': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.192},
#  'Sarah_Gadon': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.056},
#  'Kevin_Bacon': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.054,
#   'ClusteringCoefficient': 0.289},
#  'Juno_Temple': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.027,
#   'ClusteringCoefficient': 0.3},
#  'Michael_B._Jordan': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.222},
#  'Florence_Pugh': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.192},
#  'Rachel_Weisz': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.238},
#  'Gillian_Jacobs': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.067},
#  'Alexander_Ludwig': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.194},
#  'Harrison_Ford': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.04,
#   'ClusteringCoefficient': 0.27},
#  'Ryan_Gosling': {'DegreeCentrality': 0.06,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.04,
#   'ClusteringCoefficient': 0.327},
#  'Ana_de_Armas': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.235},
#  'Adam_Sandler': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.174},
#  'Drew_Barrymore': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.4},
#  'Jackie_Sandler': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.276},
#  'Owen_Wilson': {'DegreeCentrality': 0.094,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.043,
#   'ClusteringCoefficient': 0.221},
#  'Salma_Hayek': {'DegreeCentrality': 0.069,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.182},
#  'John_Cena': {'DegreeCentrality': 0.125,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.073,
#   'ClusteringCoefficient': 0.205},
#  'Leslie_Mann': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.209},
#  'Kathryn_Newton': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.258},
#  'Lucy_Boynton': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.333},
#  'Mel_Gibson': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.205},
#  'Michelle_Yeoh': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.059,
#   'ClusteringCoefficient': 0.27},
#  'Russell_Crowe': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.079,
#   'ClusteringCoefficient': 0.239},
#  'Chloë_Grace_Moretz': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.133},
#  'Jenny_Slate': {'DegreeCentrality': 0.094,
#   'BetweennessCentrality': 0.006,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.189},
#  'Antonio_Banderas': {'DegreeCentrality': 0.088,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.214},
#  'Joey_King': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.295},
#  'Angelina_Jolie': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.237},
#  'Jennifer_Aniston': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.176},
#  'Tyler_Hoechlin': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.109},
#  'Tom_Hardy': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.283},
#  'Steve_Zahn': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.2},
#  'Jonathan_Majors': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.222},
#  'Alan_Ruck': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.25},
#  'Nathan_Fillion': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.342},
#  'Bonnie_Hunt': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.429},
#  'Jason_Bateman': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.016,
#   'ClusteringCoefficient': 0.308},
#  'Daisy_Ridley': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.041,
#   'ClusteringCoefficient': 0.312},
#  'Elizabeth_Banks': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.247},
#  'Gary_Oldman': {'DegreeCentrality': 0.103,
#   'BetweennessCentrality': 0.009,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.169},
#  'Charles_Dance': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.037,
#   'ClusteringCoefficient': 0.17},
#  'Brian_Cox': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.179},
#  'Helen_Mirren': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.032,
#   'ClusteringCoefficient': 0.253},
#  'Elijah_Wood': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.19},
#  'Indira_Varma': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.231},
#  'Maisie_Williams': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.269},
#  'Mark_Wahlberg': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.039,
#   'ClusteringCoefficient': 0.163},
#  'Al_Pacino': {'DegreeCentrality': 0.063,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.342},
#  'Nicholas_Hoult': {'DegreeCentrality': 0.113,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.052,
#   'ClusteringCoefficient': 0.194},
#  'Evan_Peters': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.025,
#   'ClusteringCoefficient': 0.492},
#  'Meagan_Good': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.288},
#  'Kurt_Russell': {'DegreeCentrality': 0.15,
#   'BetweennessCentrality': 0.011,
#   'EigenvectorCentrality': 0.079,
#   'ClusteringCoefficient': 0.268},
#  'Morena_Baccarin': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.022,
#   'ClusteringCoefficient': 0.362},
#  'Matt_Damon': {'DegreeCentrality': 0.129,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.09,
#   'ClusteringCoefficient': 0.282},
#  'Rose_Leslie': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.381},
#  'Lucy_Liu': {'DegreeCentrality': 0.082,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.378},
#  'Daniel_Craig': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.253},
#  'Kate_Hudson': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.265},
#  'Maria_Bello': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.143},
#  'Dawn_Olivieri': {'DegreeCentrality': 0.016,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.005,
#   'ClusteringCoefficient': 0.3},
#  'Melanie_Lynskey': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.333},
#  'Orlando_Bloom': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.33},
#  'Rebecca_Ferguson': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.047,
#   'ClusteringCoefficient': 0.245},
#  'Finn_Wolfhard': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.222},
#  'Nina_Dobrev': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.111},
#  'Leonardo_DiCaprio': {'DegreeCentrality': 0.1,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.044,
#   'ClusteringCoefficient': 0.337},
#  'Rooney_Mara': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.023,
#   'ClusteringCoefficient': 0.198},
#  'Austin_Butler': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.423},
#  'Christopher_Walken': {'DegreeCentrality': 0.091,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.046,
#   'ClusteringCoefficient': 0.318},
#  'Tom_Cruise': {'DegreeCentrality': 0.085,
#   'BetweennessCentrality': 0.005,
#   'EigenvectorCentrality': 0.037,
#   'ClusteringCoefficient': 0.219},
#  'Bryan_Cranston': {'DegreeCentrality': 0.103,
#   'BetweennessCentrality': 0.007,
#   'EigenvectorCentrality': 0.041,
#   'ClusteringCoefficient': 0.159},
#  'Mimi_Rogers': {'DegreeCentrality': 0.013,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 0.167},
#  'Mia_Goth': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.236},
#  'Bill_Nighy': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.145},
#  'Haley_Joel_Osment': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.179},
#  'Angourie_Rice': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.048,
#   'ClusteringCoefficient': 0.373},
#  'Debby_Ryan': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.003,
#   'ClusteringCoefficient': 0.133},
#  'Kaya_Scodelario': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.289},
#  'Jason_Statham': {'DegreeCentrality': 0.078,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.034,
#   'ClusteringCoefficient': 0.307},
#  'Katheryn_Winnick': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.143},
#  'Kiefer_Sutherland': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.267},
#  'Bob_Odenkirk': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.181},
#  'Courteney_Cox': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.4},
#  'Paul_Walker': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 1.0},
#  'Shia_LaBeouf': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.2},
#  'Milla_Jovovich': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.017,
#   'ClusteringCoefficient': 0.175},
#  'Emilia_Clarke': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.019,
#   'ClusteringCoefficient': 0.364},
#  'Bella_Ramsey': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.009,
#   'ClusteringCoefficient': 0.528},
#  'Sean_Bean': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.308},
#  'Courtney_Eaton': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 0.333},
#  'John_Travolta': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.033,
#   'ClusteringCoefficient': 0.409},
#  'Bryce_Dallas_Howard': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.286},
#  'Penélope_Cruz': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.324},
#  'Ian_McShane': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.308},
#  'Jeff_Goldblum': {'DegreeCentrality': 0.144,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.094,
#   'ClusteringCoefficient': 0.253},
#  'Daniel_Radcliffe': {'DegreeCentrality': 0.066,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.03,
#   'ClusteringCoefficient': 0.181},
#  'Frances_McDormand': {'DegreeCentrality': 0.075,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.041,
#   'ClusteringCoefficient': 0.301},
#  'Riki_Lindhome': {'DegreeCentrality': 0.047,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.257},
#  'Kirsten_Dunst': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.25},
#  'Robert_Pattinson': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.026,
#   'ClusteringCoefficient': 0.221},
#  'Billy_Zane': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.536},
#  'Charlie_Day': {'DegreeCentrality': 0.072,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.036,
#   'ClusteringCoefficient': 0.269},
#  'Rob_Lowe': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 0.067},
#  'Aaron_Eckhart': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.01,
#   'ClusteringCoefficient': 0.227},
#  'Harvey_Keitel': {'DegreeCentrality': 0.1,
#   'BetweennessCentrality': 0.004,
#   'EigenvectorCentrality': 0.05,
#   'ClusteringCoefficient': 0.343},
#  'Rosario_Dawson': {'DegreeCentrality': 0.125,
#   'BetweennessCentrality': 0.01,
#   'EigenvectorCentrality': 0.059,
#   'ClusteringCoefficient': 0.226},
#  'Halle_Berry': {'DegreeCentrality': 0.053,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.018,
#   'ClusteringCoefficient': 0.265},
#  'Charlie_Hunnam': {'DegreeCentrality': 0.05,
#   'BetweennessCentrality': 0.002,
#   'EigenvectorCentrality': 0.02,
#   'ClusteringCoefficient': 0.192},
#  'Woody_Harrelson': {'DegreeCentrality': 0.119,
#   'BetweennessCentrality': 0.014,
#   'EigenvectorCentrality': 0.045,
#   'ClusteringCoefficient': 0.121},
#  'Millie_Brady': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.013,
#   'ClusteringCoefficient': 0.273},
#  'Jackie_Chan': {'DegreeCentrality': 0.028,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.444},
#  'Sharon_Stone': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.007,
#   'ClusteringCoefficient': 0.267},
#  'Giancarlo_Esposito': {'DegreeCentrality': 0.056,
#   'BetweennessCentrality': 0.003,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 0.196},
#  'Paul_Dano': {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.267},
#  'Steven_Yeun': {'DegreeCentrality': 0.034,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.015,
#   'ClusteringCoefficient': 0.218},
#  'Thomas_Brodie-Sangster': {'DegreeCentrality': 0.041,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.397},
#  'Sydney_Sweeney': {'DegreeCentrality': 0.038,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.011,
#   'ClusteringCoefficient': 0.455},
#  "Beverly_D'Angelo": {'DegreeCentrality': 0.031,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.014,
#   'ClusteringCoefficient': 0.267},
#  'Bridget_Fonda': {'DegreeCentrality': 0.044,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.024,
#   'ClusteringCoefficient': 1.0},
#  'Aimee_Garcia': {'DegreeCentrality': 0.022,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.012,
#   'ClusteringCoefficient': 0.476},
#  'Denzel_Washington': {'DegreeCentrality': 0.025,
#   'BetweennessCentrality': 0.001,
#   'EigenvectorCentrality': 0.008,
#   'ClusteringCoefficient': 0.143},
#  'Asher_Angel': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.004,
#   'ClusteringCoefficient': 1.0},
#  'Kate_Beckinsale': {'DegreeCentrality': 0.009,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.002,
#   'ClusteringCoefficient': 0.0},
#  'Jet_Li': {'DegreeCentrality': 0.019,
#   'BetweennessCentrality': 0.0,
#   'EigenvectorCentrality': 0.006,
#   'ClusteringCoefficient': 1.0}}

# %% [markdown]
# ## Show

# %%
def _cache_d3_network_plot(df_d3_masked,
                           actor_graph_metrics_dict,
                           edge_distance=100,
                           node_size=10,
                           fontsize=8,
                           graph_metric=None):

    d3 = D3Blocks()
    d3.d3graph(df_d3_masked,title='dsfsdf')
    d3.D3graph.set_edge_properties(directed=False,edge_distance=edge_distance)

    d3.D3graph.set_node_properties(color='cluster',size=node_size,edge_size=0.2,fontsize=fontsize)
    if graph_metric:
        
        for k,v in actor_graph_metrics_dict.items():
            try:
                d3.D3graph.node_properties[k]['size']=v[graph_metric]
            except:
                pass
    

    d3.D3graph.show(filepath='/Users/saho/Documents/sam/imdb_actor_graph/experimentl_html/test.html')
    return

# %%
x = _cache_d3_network_plot(df_d3_masked,actor_graph_metrics_dict,graph_metric='ClusteringCoefficient')
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Set directed=True to see the markers!
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Number of unique nodes: 320
# [d3blocks] >INFO> Slider range is set to [0, 8]
# [d3blocks] >INFO> Write to path: [/var/folders/l9/6wvd07bx0t59jfdht0vhh5h40000gq/T/tmpbx57m6ma/d3graph.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/var/folders/l9/6wvd07bx0t59jfdht0vhh5h40000gq/T/tmpbx57m6ma/d3graph.html]
# [d3blocks] >INFO> Set directed=True to see the markers!
# [d3blocks] >INFO> Keep only edges with weight>0
# [d3blocks] >INFO> Number of unique nodes: 320
# [d3blocks] >INFO> Slider range is set to [0, 8]
# [d3blocks] >INFO> Write to path: [/Users/saho/Documents/sam/imdb_actor_graph/experimentl_html/test.html]
# [d3blocks] >INFO> File already exists and will be overwritten: [/Users/saho/Documents/sam/imdb_actor_graph/experimentl_html/test.html]

# %%
def _load_cached_file(save_path):
    with open(save_path, "r") as f:
        file = f.read()
    return file

# %% [markdown]
# # Show Common Movies

# %%
def _get_actor_co_star_dict(df_d3_masked):
    dic_source_target = dict(df_d3_masked.groupby('source')['target'].agg(lambda x: x.to_list()))
    dic_target_source = dict(df_d3_masked.groupby('target')['source'].agg(lambda x: x.to_list()))
    dic_source_target.update(dic_target_source)
    return dic_source_target

# %%
from collections import defaultdict

def _get_actor_co_star_dict(df_d3_masked):
    dic_merged = defaultdict(list)
    
    for source, target in zip(df_d3_masked['source'], df_d3_masked['target']):
        dic_merged[source].append(target)
        dic_merged[target].append(source)
    
    dic_source_target = dict(dic_merged)
    return dic_source_target

# %%
actor_co_star_dict = _get_actor_co_star_dict(df_d3_masked)

# %%
def _find_common_movies(df, actor1, actor2):
    actor1_movies = set(df[df['c_name'] == actor1]['m_movie'])
    actor2_movies = set(df[df['c_name'] == actor2]['m_movie'])
    common_movies = actor1_movies.intersection(actor2_movies)
    return list(common_movies)

# %%
common_movies = _find_common_movies(df_cast_movies,'Chris Evans','Chris Hemsworth')

# %%
def _get_poster_paths(df, common_movies):
    res = []
    for movie in common_movies:
        poster_path = df[df['m_movie'] == movie]['m_poster_path'].unique()[0]
        res.append((movie,poster_path))
    return res

# %%
_get_poster_paths(df_cast_movies,common_movies)
# Out:
# [('Avengers: Infinity War', '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg'),
#  ('Avengers: Endgame', '/or06FN3Dka5tukK1e9sl16pB3iy.jpg')]

# %% [markdown]
# 1. Degree Centrality: Degree centrality measures how connected an actor is by looking at the number of co-stars they have worked with. Actors with a higher degree centrality value have worked with more co-stars.
#
# 2. Betweenness Centrality: Betweenness centrality quantifies the extent to which an actor acts as a bridge or intermediary between other actors in the graph. In real terms, an actor who has starred in a number of different franchises is likely to have a high betweeness centrality.
#
# 3. Eigenvector Centrality: Eigenvector centrality measures the influence of an actor based on both their direct connections and the connections of their co-stars. Actors with high eigenvector centrality are not only connected to many other actors but are also connected to other influential actors.
#
# 4. Clustering Coefficient: The clustering coefficient measures the tendency of actors to form tightly-knit groups or clusters. It quantifies how likely an actor's co-stars are also connected to each other. Actors with high clustering coefficients are part of cohesive groups within the network.
#
# These metrics provide insights into various aspects of an actor's centrality, influence, connectedness, and clustering behavior within the actor graph. By analyzing these metrics, you can gain a better understanding of the importance and role of each actor in the network of collaborations.

# %% [markdown]
# # Gender Analysis

# %%
df_cast_movies[['c_gender','c_name','m_revenue']]
# Out:
#        c_gender         c_name     m_revenue
# 0           2.0    Johnny Depp  1.045714e+09
# 1           1.0  Penélope Cruz  1.045714e+09
# 2           2.0    Ian McShane  1.045714e+09
# 3           2.0    Gary Oldman  1.004558e+09
# 4           2.0  Aaron Eckhart  1.004558e+09
# ...         ...            ...           ...
# 11368       2.0    Charlie Day  0.000000e+00
# 11369       NaN    Jenny Slate  0.000000e+00
# 11370       NaN     Isabel May  0.000000e+00
# 11371       2.0   Keanu Reeves  1.068063e+07
# 11372       1.0   Aimee Garcia  0.000000e+00
#
# [11373 rows x 3 columns]
